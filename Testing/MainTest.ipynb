# %%
import os
import io
import json

import numpy as np

from scipy.stats import spearmanr
from gensim.models.keyedvectors import KeyedVectors

import Constant

# Path a carpeta principal
MAIN_FOLDER = Constant.MAIN_FOLDER

# Path a carpeta con los embeddings
EMBEDDING_FOLDER = Constant.EMBEDDING_FOLDER

# Lista con los nombres de los archivos de los embeddings
embedding_name_list = os.listdir(EMBEDDING_FOLDER)

print(">>> Embeddings a evaluar:")
for embedding in embedding_name_list:
    print("  > " + embedding)

def get_wordvector(file, cant=None):
    wordvector_file = EMBEDDING_FOLDER / file

    return KeyedVectors.load_word2vec_format(wordvector_file, limit=cant)
# Out:
# D:\Documents\Memoria - Eval. Word Embeddings\Testing
# D:\Documents\Memoria - Eval. Word Embeddings
# D:\Documents\Memoria - Eval. Word Embeddings\Embeddings
# D:\Documents\Memoria - Eval. Word Embeddings\Datasets
# D:\Documents\Memoria - Eval. Word Embeddings\Resultados
# D:\Documents\Memoria - Eval. Word Embeddings\TempResultados
# >>> Embeddings a evaluar:
#   > _fasttext_sbwc.vec
#   > _fasttext_suc.vec
#   > _fasttext_wiki.vec
#   > _glove_sbwc.vec
#   > _w2v_sbwc.txt

# %%
# Realizacion de test

import SimilarityTest

# Test de similaridad
print(">>> Test de similaridad\n")
for embedding in embedding_name_list:
    print(">>> Testing " + embedding + "\n")
    
    print(">>> Cargando vectores...", end='')
    wordvector = get_wordvector(embedding, 10000)
    wordvector_name = embedding.split('.')[0]
    print("listo\n")
    
    result = SimilarityTest.similarityTest(wordvector, wordvector_name)
# Out:
# >>> Test de similaridad
#
# >>> Testing _fasttext_sbwc.vec
#
# >>> Cargando vectores...listo
#
# >>> Test individuales
# >>> Archivo test: rg65_es.txt
# >>> Opening file rg65_es.txt
# >>> Not found words:63
#     ['cordel', 'gallo', 'caldera', 'autógrafo', 'hechicero', 'loma', 'estufa', 'monje', 'manicomio', 'gallo', 'vaso', 'mago', 'cojín', 'joya', 'monje', 'esclavo', 'chaval', 'monje', 'oráculo', 'sabio', 'cojín', 'loma', 'chaval', 'hechicero', 'gallo', 'pájaro', 'caldera', 'grulla', 'gallo', 'loma', 'joya', 'mago', 'oráculo', 'grúa', 'chaval', 'sabio', 'hechicero', 'oráculo', 'sabio', 'pájaro', 'gallo', 'pájaro', 'grulla', 'monje', 'manicomio', 'caldera', 'estufa', 'mago', 'hechicero', 'loma', 'cordel', 'vaso', 'recipiente', 'siervo', 'esclavo', 'autógrafo', 'pollo', 'gallo', 'chaval', 'cojín', 'almohada', 'gema', 'joya']
#      > Cantidad de pares no procesados: 44
#
#
# >>> Archivo test: semeval17_es.txt
# >>> Opening file semeval17_es.txt
# >>> Not found words:309
'mosca', 'hormiga', 'sátira', 'cadencia', 'flauta', 'viscosidad', 'salpicadura', 'hardware', 'shakespeare', 'dickens', 'billete', 'sufragio', 'brillo', 'trucha', 'millonario', 'dígito', 'vendaval', 'manta', 'ia', 'coronación', 'desempate', 'ducha', 'envoltorio', 'demonio', 'ángel', 'criptograma', 'tifón', 'ciclón', 'galleta', 'tranvía', 'ecosistema', 'zinc', 'amazonas', 'bolzano', 'teorema', 'cereza', 'fresa', 'corán', 'neandertal', 'nepotismo', 'júpiter', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ei', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'manuscrito', 'mijo', 'emblema', 'vaso', 'broquel', 'avena', 'monje', 'cañonero', 'moraleja', 'cubo', 'topología', 'molécula', 'vexilología', 'géiser', 'manantial', 'sacarosa', 'carbohidrato', 'artesanía', 'bocadillo', 'subway', 'acústica', 'esgrima', 'gimnasia', 'jpeg', 'brexit', 'polinización', 'estambre', 'arrozal', 'patata', 'apuntes', 'zorro', 'glóbulo', 'brújula', 'elefante', 'secuela', 'largometraje', 'sargento', 'molino', 'semilla', 'helado', 'cerradura', 'plántula', 'granizo', 'serpiente', 'lagartija', 'piña', 'smartphone', 'celsius', 'vaqueros', 'vector', 'cargador', 'manuscrito', 'gmail', 'yahoo', 'condensador', 'diodo', 'platón', 'aristóteles', 'boquilla', 'fluido', 'fonología', 'zara', 'mallas', 'balompié', 'germen', 'patógeno', 'máscara', 'autovía', 'ilustración', 'ampolla', 'antropología', 'arqueología', 'dell', 'dingle', 'zumo', 'cuchara', 'pfizer', 'multimillonario', 'vagabundo', 'infinito', 'criado', 'esclavo', 'sufijo', 'afijo', 'fertilizante', 'hashtag', 'orión', 'constelación', 'nietzsche', 'avalancha', 'yogurt', 'raqueta', 'federer', 'dylan', 'paint', 'photoshop', 'perejil', 'opel', 'martillo', 'renaissance', 'falda', 'instructor', 'conductismo', 'matemático', 'entropía', 'cítrico', 'pomelo', 'musulmán', 'meteorito', 'subrutina', 'compilador', 'hamedan', 'paraguas', 'radiador', 'insignia', 'kf ...
#      > Cantidad de pares no procesados: 276
#
#
# >>> Resultados
#     rg65_es.txt: 0.9277821777906589
#     semeval17_es.txt: 0.7151722688138973
#     all_data: 0.7519942073411788
#
#
# >>> Saving results in _fasttext_sbwc
# >>> Testing _fasttext_suc.vec
#
# >>> Cargando vectores...listo
#
# >>> Test individuales
# >>> Archivo test: rg65_es.txt
# >>> Opening file rg65_es.txt
# >>> Not found words:50
#     ['cordel', 'gallo', 'caldera', 'autógrafo', 'hechicero', 'loma', 'estufa', 'monje', 'manicomio', 'gallo', 'cojín', 'joya', 'monje', 'chaval', 'monje', 'oráculo', 'cojín', 'loma', 'chaval', 'hechicero', 'gallo', 'caldera', 'grulla', 'gallo', 'loma', 'joya', 'oráculo', 'grúa', 'chaval', 'hechicero', 'oráculo', 'gallo', 'grulla', 'monje', 'manicomio', 'caldera', 'estufa', 'hechicero', 'loma', 'cordel', 'recipiente', 'siervo', 'trayecto', 'autógrafo', 'gallo', 'chaval', 'cojín', 'almohada', 'gema', 'joya']
#      > Cantidad de pares no procesados: 42
#
#
# >>> Archivo test: semeval17_es.txt
# >>> Opening file semeval17_es.txt
# >>> Not found words:292
#     ['astronave', 'poliedro', 'guionista', 'basílica', 'mosaico', 'acuarela', 'brocha', 'gauss', 'led', 'apocalipsis', 'playstation', 'wii', 'snowboard', 'esquí', 'puntero', 'diapositiva', 'sensor', 'radiador', 'darwin', 'monitor', 'lechería', 'pesticida', 'neuropsicología', 'parapsicología', 'spider-man', 'gráfica', 'simulación', 'robótica', 'nike', 'adidas', 'traductor', 'biotopo', 'magma', 'centavo', 'ganga', 'maremoto', 'avestruz', 'huerto', 'canela', 'caramelo', 'escoba', 'astrónomo', 'zumo', 'batido', 'persiana', 'cortina', 'delincuente', 'antecedente', 'cuaderno', 'acetilcolina', 'alfabeto', 'bolígrafo', 'manta', 'lagarto', 'cocodrilo', 'lagartija', 'jaque', 'soneto', 'poliéster', 'retaguardia', 'borrasca', 'sultán', 'duna', 'multiplicación', 'glaciación', 'críquet', 'seguidor', 'neurosis', 'rascacielos', 'pértiga', 'malware', 'paraguas', 'wifi', 'wikileaks', 'mojito', 'mojito', 'temario', 'teorema', 'yoyó', 'historiógrafo', 'aleación', 'guardian', 'oasis', 'citoplasma', 'protestante', 'patología', 'hematología', 'telescopio', 'globalismo', 'visa', 'murciélago', 'funda', 'extraterrestre', 'forastero', 'filósofo', 'palomitas', 'hilado', 'pomo', 'u2', 'ronaldo', 'apple', 'iphone', 'menta', 'chicle', 'póster', 'lámpara', 'dinosaurio', 'elefante', 'pradera', 'violín', 'diplomacia', 'meteorito', 'ci', 'mensa', 'temblor', 'hebreo', 'nubosidad', 'enciclopedia', 'taburete', 'mosca', 'hormiga', 'sátira', 'gobernante', 'cadencia', 'flauta', 'viscosidad', 'salpicadura', 'hardware', 'funda', 'shakespeare', 'dickens', 'sufragio', 'trucha', 'millonario', 'dígito', 'vendaval', 'manta', 'coronación', 'vocalista', 'desempate', 'envoltorio', 'criptograma', 'tifón', 'ciclón', 'galleta', 'tranvía', 'ecosistema', 'zinc', 'amazonas', 'bolzano', 'teorema', 'cereza', 'fresa', 'corán', 'neandertal', 'nepotismo', 'júpiter', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'manuscrito', 'mijo', 'emblema', 'escultor', 'ozono', 'broquel', 'avena', 'monje', 'cañonero', 'moraleja', 'topología', 'molécula', 'vexilología', 'géiser', 'manantial', 'sacarosa', 'carbohidrato', 'artesanía', 'bocadillo', 'subway', 'acústica', 'esgrima', 'gimnasia', 'jpeg', 'pdf', 'brexit', 'polinización', 'estambre', 'arrozal', 'patata', 'apuntes', 'zorro', 'glóbulo', 'brújula', 'elefante', 'secuela', 'largometraje', 'molino', 'cerradura', 'plántula', 'granizo', 'lagartija', 'piña', 'smartphone', 'celsius', 'vaqueros', 'vector', 'cargador', 'manuscrito', 'gmail', 'yahoo', 'condensador', 'diodo', 'platón', 'aristóteles', 'boquilla', 'fluido', 'fonología', 'zara', 'mallas', 'balompié', 'germen', 'patógeno', 'autovía', 'ilustración', 'ampolla', 'antropología', 'arqueología', 'dell', 'dingle', 'zumo', 'cuchara', 'pfizer', 'multimillonario', 'vagabundo', 'infinito', 'sufijo', 'afijo', 'fertilizante', 'hashtag', 'orión', 'constelación', 'nietzsche', 'chelsea', 'avalancha', 'yogurt', 'raqueta', 'federer', 'paint', 'photoshop', 'perejil', 'opel', 'renaissance', 'falda', 'instructor', 'recesión', 'conductismo', 'matemático', 'entropía', 'cítrico', 'pomelo', 'musulmán', 'meteorito', 'subrutina', 'compilador', 'hamedan', 'paraguas', 'radiador', 'insignia', 'kfc', "mcdonald's", 'joystick', 'zapatillas', 'rebeca', 'oscars', 'backgammon', 'mariposa', 'valla', 'nihilismo', 'asteroide', 'revuelta', 'boeing', 'cameo', 'cítrico']
#      > Cantidad de pares no procesados: 225
#
#
# >>> Empezando test en conjunto
# >>> Not found words:342
#     ['cordel', 'gallo', 'caldera', 'autógrafo', 'hechicero', 'loma', 'estufa', 'monje', 'manicomio', 'gallo', 'cojín', 'joya', 'monje', 'chaval', 'monje', 'oráculo', 'cojín', 'loma', 'chaval', 'hechicero', 'gallo', 'caldera', 'grulla', 'gallo', 'loma', 'joya', 'oráculo', 'grúa', 'chaval', 'hechicero', 'oráculo', 'gallo', 'grulla', 'monje', 'manicomio', 'caldera', 'estufa', 'hechicero', 'loma', 'cordel', 'recipiente', 'siervo', 'trayecto', 'autógrafo', 'gallo', 'chaval', 'cojín', 'almohada', 'gema', 'joya', 'astronave', 'poliedro', 'guionista', 'basílica', 'mosaico', 'acuarela', 'brocha', 'gauss', 'led', 'apocalipsis', 'playstation', 'wii', 'snowboard', 'esquí', 'puntero', 'diapositiva', 'sensor', 'radiador', 'darwin', 'monitor', 'lechería', 'pesticida', 'neuropsicología', 'parapsicología', 'spider-man', 'gráfica', 'simulación', 'robótica', 'nike', 'adidas', 'traductor', 'biotopo', 'magma', 'centavo', 'ganga', 'maremoto', 'avestruz', 'huerto', 'canela', 'caramelo', 'escoba', 'astrónomo', 'zumo', 'batido', 'persiana', 'cortina', 'delincuente', 'antecedente', 'cuaderno', 'acetilcolina', 'alfabeto', 'bolígrafo', 'manta', 'lagarto', 'cocodrilo', 'lagartija', 'jaque', 'soneto', 'poliéster', 'retaguardia', 'borrasca', 'sultán', 'duna', 'multiplicación', 'glaciación', 'críquet', 'seguidor', 'neurosis', 'rascacielos', 'pértiga', 'malware', 'paraguas', 'wifi', 'wikileaks', 'mojito', 'mojito', 'temario', 'teorema', 'yoyó', 'historiógrafo', 'aleación', 'guardian', 'oasis', 'citoplasma', 'protestante', 'patología', 'hematología', 'telescopio', 'globalismo', 'visa', 'murciélago', 'funda', 'extraterrestre', 'forastero', 'filósofo', 'palomitas', 'hilado', 'pomo', 'u2', 'ronaldo', 'apple', 'iphone', 'menta', 'chicle', 'póster', 'lámpara', 'dinosaurio', 'elefante', 'pradera', 'violín', 'diplomacia', 'meteorito', 'ci', 'mensa', 'temblor', 'hebreo', 'nubosidad', 'enciclopedia', 'taburete', 'mosca', 'hormiga', 'sátira', 'gobernante', 'cadencia', 'flauta', 'viscosidad', 'salpicadura', 'hardware', 'funda', 'shakespeare', 'dickens', 'sufragio', 'trucha', 'millonario', 'dígito', 'vendaval', 'manta', 'coronación', 'vocalista', 'desempate', 'envoltorio', 'criptograma', 'tifón', 'ciclón', 'galleta', 'tranvía', 'ecosistema', 'zinc', 'amazonas', 'bolzano', 'teorema', 'cereza', 'fresa', 'corán', 'neandertal', 'nepotismo', 'júpiter', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'manuscrito', 'mijo', 'emblema', 'escultor', 'ozono', 'broquel', 'avena', 'monje', 'cañonero', 'moraleja', 'topología', 'molécula', 'vexilología', 'géiser', 'manantial', 'sacarosa', 'carbohidrato', 'artesanía', 'bocadillo', 'subway', 'acústica', 'esgrima', 'gimnasia', 'jpeg', 'pdf', 'brexit', 'polinización', 'estambre', 'arrozal', 'patata', 'apuntes', 'zorro', 'glóbulo', 'brújula', 'elefante', 'secuela', 'largometraje', 'molino', 'cerradura', 'plántula', 'granizo', 'lagartija', 'piña', 'smartphone', 'celsius', 'vaqueros', 'vector', 'cargador', 'manuscrito', 'gmail', 'yahoo', 'condensador', 'diodo', 'platón', 'aristóteles', 'boquilla', 'fluido', 'fonología', 'zara', 'mallas', 'balompié', 'germen', 'patógeno', 'autovía', 'ilustración', 'ampolla', 'antropología', 'arqueología', 'dell', 'dingle', 'zumo', 'cuchara', 'pfizer', 'multimillonario', 'vagabundo', 'infinito', 'sufijo', 'afijo', 'fertilizante', 'hashtag', 'orión', 'constelación', 'nietzsche', 'chelsea', 'avalancha', 'yogurt', 'raqueta', 'federer', 'paint', 'photoshop', 'perejil', 'opel', 'renaissance', 'falda', 'instructor', 'recesión', 'conductismo', 'matemático', 'entropía', 'cítrico', 'pomelo', 'musulmán', 'meteorito', 'subrutina', 'compilador', 'hamedan', 'paraguas', 'radiador', 'insignia', 'kfc', "mcdonald's", 'joystick', 'zapatillas', 'rebeca', 'oscars', 'backgammon', 'mariposa', 'valla', 'nihilismo', 'asteroide', 'revuelta', 'boeing', 'cameo', 'cítrico']
#      > Cantidad de pares no procesados: 267
#
#
# >>> Resultados
#     rg65_es.txt: 0.9234582683599286
#     semeval17_es.txt: 0.7514293334256128
#     all_data: 0.7716196490006261
#
#
# >>> Saving results in _fasttext_suc
# >>> Testing _fasttext_wiki.vec
#
# >>> Cargando vectores...listo
#
# >>> Test individuales
# >>> Archivo test: rg65_es.txt
# >>> Opening file rg65_es.txt
# >>> Not found words:48
#     ['cordel', 'sonrisa', 'caldera', 'autógrafo', 'hechicero', 'estufa', 'sonrisa', 'asilo', 'asilo', 'manicomio', 'vaso', 'cojín', 'joya', 'esclavo', 'asilo', 'sonrisa', 'chaval', 'oráculo', 'cojín', 'chaval', 'hechicero', 'caldera', 'grulla', 'joya', 'oráculo', 'grúa', 'chaval', 'hechicero', 'oráculo', 'grulla', 'asilo', 'manicomio', 'caldera', 'estufa', 'hechicero', 'cordel', 'vaso', 'recipiente', 'sonrisa', 'sonrisa', 'siervo', 'esclavo', 'autógrafo', 'chaval', 'cojín', 'almohada', 'gema', 'joya']
#      > Cantidad de pares no procesados: 37
#
#
# >>> Archivo test: semeval17_es.txt
# >>> Opening file semeval17_es.txt
# >>> Not found words:271
#     ['astronave', 'poliedro', 'mosaico', 'acuarela', 'brocha', 'gauss', 'tuberculosis', 'led', 'apocalipsis', 'snowboard', 'puntero', 'diapositiva', 'sensor', 'radiador', 'monitor', 'lechería', 'pesticida', 'peste', 'neuropsicología', 'parapsicología', 'spider-man', 'simulación', 'robótica', 'nike', 'adidas', 'biotopo', 'magma', 'centavo', 'ganga', 'maremoto', 'avestruz', 'huerto', 'canela', 'caramelo', 'escoba', 'zumo', 'batido', 'persiana', 'cortina', 'delincuente', 'antecedente', 'cuaderno', 'acetilcolina', 'bolígrafo', 'manta', 'lagarto', 'cocodrilo', 'lagartija', 'jaque', 'soneto', 'poliéster', 'retaguardia', 'borrasca', 'duna', 'multiplicación', 'glaciación', 'críquet', 'seguidor', 'celda', 'deberes', 'neurosis', 'pértiga', 'malware', 'gusano', 'paraguas', 'wifi', 'wikileaks', 'sequía', 'mojito', 'mojito', 'temario', 'yoyó', 'juguete', 'historiógrafo', 'aleación', 'magistrado', 'guardian', 'oasis', 'citoplasma', 'patología', 'hematología', 'globalismo', 'visa', 'murciélago', 'extraterrestre', 'forastero', 'palomitas', 'hilado', 'pomo', 'u2', 'ronaldo', 'iphone', 'menta', 'chicle', 'póster', 'unicef', 'xenofobia', 'racismo', 'lámpara', 'dinosaurio', 'elefante', 'pradera', 'diplomacia', 'negociación', 'meteorito', 'ci', 'mensa', 'temblor', 'existencias', 'nubosidad', 'pronóstico', 'ceca', 'taburete', 'lata', 'botella', 'mosca', 'hormiga', 'sátira', 'cadencia', 'viscosidad', 'salpicadura', 'dickens', 'billete', 'sufragio', 'brillo', 'trucha', 'dólar', 'millonario', 'dígito', 'vendaval', 'manta', 'obama', 'desempate', 'ducha', 'envoltorio', 'criptograma', 'tifón', 'ciclón', 'galleta', 'ecosistema', 'zinc', 'bolzano', 'cereza', 'fresa', 'corán', 'neandertal', 'nepotismo', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ei', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'matrícula', 'mijo', 'vaso', 'ozono', 'broquel', 'avena', 'cañonero', 'moraleja', 'cubo', 'topología', 'vexilología', 'géiser', 'manantial', 'sacarosa', 'carbohidrato', 'artesanía', 'bocadillo', 'subway', 'jpeg', 'brexit', 'polinización', 'estambre', 'arr
ronaldo', 'iphone', 'menta', 'chicle', 'póster', 'unicef', 'xenofobia', 'racismo', 'lámpara', 'dinosaurio', 'elefante', 'pradera', 'diplomacia', 'negociación', 'meteorito', 'ci', 'mensa', 'temblor', 'existencias', 'nubosidad', 'pronóstico', 'ceca', 'taburete', 'lata', 'botella', 'mosca', 'hormiga', 'sátira', 'cadencia', 'viscosidad', 'salpicadura', 'dickens', 'billete', 'sufragio', 'brillo', 'trucha', 'dólar', 'millonario', 'dígito', 'vendaval', 'manta', 'obama', 'desempate', 'ducha', 'envoltorio', 'criptograma', 'tifón', 'ciclón', 'galleta', 'ecosistema', 'zinc', 'bolzano', 'cereza', 'fresa', 'corán', 'neandertal', 'nepotismo', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ei', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'matrícula', 'mijo', 'vaso', 'ozono', 'broquel', 'avena', 'cañonero', 'moraleja', 'cubo', 'topología', 'vexilología', 'géiser', 'manantial', 'sacarosa', 'carbohidrato', 'artesanía', 'bocadillo', 'subway', 'jpeg', 'brexit', 'polinización', 'estambre', 'arrozal', 'patata', 'apuntes', 'glóbulo', 'brújula', 'elefante', 'helado', 'desayuno', 'cerradura', 'plántula', 'granizo', 'tristeza', 'camión', 'lagartija', 'piña', 'smartphone', 'celsius', 'vaqueros', 'cargador', 'gmail', 'yahoo', 'condensador', 'diodo', 'fraude', 'platón', 'aristóteles', 'boquilla', 'fluido', 'fonología', 'zara', 'mallas', 'balompié', 'germen', 'patógeno', 'ampolla', 'dingle', 'zumo', 'cuchara', 'pfizer', 'medicamento', 'camión', 'multimillonario', 'vagabundo', 'infinito', 'criado', 'esclavo', 'sufijo', 'afijo', 'fertilizante', 'hashtag', 'orión', 'nietzsche', 'avalancha', 'yogurt', 'raqueta', 'federer', 'paint', 'photoshop', 'perejil', 'opel', 'martillo', 'renaissance', 'falda', 'instructor', 'recesión', 'conductismo', 'entropía', 'cítrico', 'pomelo', 'sospechoso', 'meteorito', 'subrutina', 'compilador', 'hamedan', 'paraguas', 'radiador', 'kfc', "mcdonald's", 'joystick', 'zapatillas', 'camisa', 'rebeca', 'profeta', 'oscars', 'backgammon', 'valla', 'nihilismo', 'cameo', 'trimestre', 'cítrico']
#      > Cantidad de pares no procesados: 243
#
#
# >>> Resultados
#     rg65_es.txt: 0.8614079627157265
#     semeval17_es.txt: 0.7429263382605876
#     all_data: 0.7583263995213297
#
#
# >>> Saving results in _fasttext_wiki
# >>> Testing _glove_sbwc.vec
#
# >>> Cargando vectores...listo
#
# >>> Test individuales
# >>> Archivo test: rg65_es.txt
# >>> Opening file rg65_es.txt
# >>> Not found words:63
#     ['cordel', 'gallo', 'caldera', 'autógrafo', 'hechicero', 'loma', 'estufa', 'monje', 'manicomio', 'gallo', 'vaso', 'mago', 'cojín', 'joya', 'monje', 'esclavo', 'chaval', 'monje', 'oráculo', 'sabio', 'cojín', 'loma', 'chaval', 'hechicero', 'gallo', 'pájaro', 'caldera', 'grulla', 'gallo', 'loma', 'joya', 'mago', 'oráculo', 'grúa', 'chaval', 'sabio', 'hechicero', 'oráculo', 'sabio', 'pájaro', 'gallo', 'pájaro', 'grulla', 'monje', 'manicomio', 'caldera', 'estufa', 'mago', 'hechicero', 'loma', 'cordel', 'vaso', 'recipiente', 'siervo', 'esclavo', 'autógrafo', 'pollo', 'gallo', 'chaval', 'cojín', 'almohada', 'gema', 'joya']
#      > Cantidad de pares no procesados: 44
#
#
# >>> Archivo test: semeval17_es.txt
# >>> Opening file semeval17_es.txt
# >>> Not found words:309
#     ['astronave', 'poliedro', 'mosaico', 'acuarela', 'brocha', 'gauss', 'led', 'apocalipsis', 'playstation', 'wii', 'snowboard', 'puntero', 'diapositiva', 'sensor', 'radiador', 'darwin', 'monitor', 'lechería', 'pesticida', 'peste', 'neuropsicología', 'parapsicología', 'spider-man', 'simulación', 'robótica', 'nike', 'adidas', 'traductor', 'biotopo', 'magma', 'puntuación', 'centavo', 'ganga', 'maremoto', 'avestruz', 'huerto', 'canela', 'caramelo', 'escoba', 'galaxia', 'astrónomo', 'zumo', 'batido', 'persiana', 'cortina', 'antecedente', 'cuaderno', 'acetilcolina', 'iris', 'alfabeto', 'bolígrafo', 'manta', 'lagarto', 'cocodrilo', 'lagartija', 'jaque', 'soneto', 'poliéster', 'retaguardia', 'borrasca', 'sultán', 'duna', 'multiplicación', 'glaciación', 'críquet', 'seguidor', 'evangelio', 'celda', 'neurosis', 'mono', 'rascacielos', 'pértiga', 'malware', 'gusano', 'paraguas', 'wifi', 'wikileaks', 'mojito', 'mojito', 'temario', 'teorema', 'yoyó', 'juguete', 'historiógrafo', 'aleación', 'guardian', 'oasis', 'citoplasma', 'protestante', 'patología', 'hematología', 'telescopio', 'globalismo', 'visa', 'murciélago', 'vampiro', 'extraterrestre', 'forastero', 'mago', 'palomitas', 'galaxia', 'hilado', 'pomo', 'u2', 'menta', 'chicle', 'póster', 'lámpara', 'genio', 'dinosaurio', 'elefante', 'pradera', 'violín', 'meteorito', 'ci', 'mensa', 'temblor', 'hebreo', 'nubosidad', 'pronóstico', 'enciclopedia', 'ceca', 'taburete', 'lata', 'mosca', 'hormiga', 'sátira', 'cadencia', 'flauta', 'viscosidad', 'salpicadura', 'hardware', 'shakespeare', 'dickens', 'billete', 'sufragio', 'brillo', 'trucha', 'millonario', 'dígito', 'vendaval', 'manta', 'ia', 'coronación', 'desempate', 'ducha', 'envoltorio', 'demonio', 'ángel', 'criptograma', 'tifón', 'ciclón', 'galleta', 'tranvía', 'ecosistema', 'zinc', 'amazonas', 'bolzano', 'teorema', 'cereza', 'fresa', 'corán', 'neandertal', 'nepotismo', 'júpiter', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ei', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'manuscrito', 'mijo', 'emblema', 'vaso', 'broquel', 'avena', 'monje', 'cañonero', 'moraleja', 'cubo
#      > Cantidad de pares no procesados: 276
#
#
# >>> Resultados
#     rg65_es.txt: 0.9622649656047578
#     semeval17_es.txt: 0.7304182117048944
#     all_data: 0.7698096809187175
#
#
# >>> Saving results in _glove_sbwc
# >>> Testing _w2v_sbwc.txt
#
# >>> Cargando vectores...listo
#
# >>> Test individuales
# >>> Archivo test: rg65_es.txt
# >>> Opening file rg65_es.txt
# >>> Not found words:69
#     ['cordel', 'gallo', 'fruta', 'caldera', 'autógrafo', 'hechicero', 'loma', 'estufa', 'fruta', 'monje', 'manicomio', 'gallo', 'vaso', 'mago', 'cojín', 'joya', 'monje', 'esclavo', 'chaval', 'monje', 'oráculo', 'sabio', 'cojín', 'loma', 'chaval', 'hechicero', 'gallo', 'pájaro', 'colina', 'caldera', 'grulla', 'gallo', 'colina', 'loma', 'joya', 'mago', 'oráculo', 'grúa', 'chaval', 'sabio', 'hechicero', 'oráculo', 'sabio', 'pájaro', 'gallo', 'pájaro', 'grulla', 'fruta', 'monje', 'manicomio', 'caldera', 'estufa', 'mago', 'hechicero', 'colina', 'loma', 'cordel', 'vaso', 'recipiente', 'siervo', 'esclavo', 'autógrafo', 'pollo', 'gallo', 'chaval', 'cojín', 'almohada', 'gema', 'joya']
#      > Cantidad de pares no procesados: 48
#
#
# >>> Archivo test: semeval17_es.txt
# >>> Opening file semeval17_es.txt
# >>> Not found words:355
#     ['astronave', 'poliedro', 'basílica', 'mosaico', 'acuarela', 'brocha', 'gauss', 'led', 'apocalipsis', 'playstation', 'wii', 'snowboard', 'esquí', 'puntero', 'diapositiva', 'sensor', 'radiador', 'darwin', 'monitor', 'lechería', 'miel', 'pesticida', 'peste', 'neuropsicología', 'parapsicología', 'spider-man', 'ecuador', 'ecuador', 'gráfica', 'simulación', 'robótica', 'nike', 'adidas', 'traductor', 'biotopo', 'biología', 'magma', 'puntuación', 'centavo', 'ganga', 'maremoto', 'avestruz', 'huerto', 'canela', 'caramelo', 'escoba', 'galaxia', 'astrónomo', 'zumo', 'batido', 'persiana', 'cortina', 'delincuente', 'antecedente', 'cuaderno', 'acetilcolina', 'iris', 'alfabeto', 'bolígrafo', 'manta', 'lagarto', 'cocodrilo', 'lagartija', 'ajedrez', 'jaque', 'soneto', 'poliéster', 'retaguardia', 'borrasca', 'sultán', 'duna', 'multiplicación', 'glaciación', 'críquet', 'seguidor', 'biblia', 'evangelio', 'celda', 'neurosis', 'mono', 'rascacielos', 'pértiga', 'malware', 'gusano', 'atleta', 'paraguas', 'wifi', 'wikileaks', 'mojito', 'mojito', 'temario', 'teorema', 'yoyó', 'juguete', 'historiógrafo', 'aleación', 'guardian', 'times', 'oasis', 'citoplasma', 'protestante', 'patología', 'hematología', 'telescopio', 'globalismo', 'visa', 'murciélago', 'vampiro', 'funda', 'extraterrestre', 'forastero', 'mago', 'palomitas', 'galaxia', 'delta', 'hilado', 'pomo', 'u2', 'ronaldo', 'ap
io', 'demonio', 'ángel', 'criptograma', 'tifón', 'ciclón', 'galleta', 'tranvía', 'ecosistema', 'zinc', 'amazonas', 'bolzano', 'teorema', 'jersey', 'cereza', 'fresa', 'islam', 'corán', 'neandertal', 'nepotismo', 'tanque', 'júpiter', 'bronquitis', 'acetaminofeno', 'islamofobia', 'ei', 'ganchillo', 'mutante', 'sociobiología', 'lápiz', 'eczema', 'dermatitis', 'álgebra', 'pistón', 'beca', 'manuscrito', 'mijo', 'emblema', 'vaso', 'mansión', 'broquel', 'avena', 'monje', 'cañonero', 'moraleja', 'cubo', 'topología', 'molécula', 'vexilología', 'géiser', 'manantial', 'sacarosa', 'carbohidrato', 'artesanía', 'bocadillo', 'subway', 'acústica', 'esgrima', 'gimnasia', 'nube', 'jpeg', 'pdf', 'brexit', 'polinización', 'estambre', 'arrozal', 'patata', 'apuntes', 'zorro', 'glóbulo', 'brújula', 'elefante', 'secuela', 'largometraje', 'sargento', 'molino', 'semilla', 'helado', 'cerradura', 'plántula', 'granizo', 'tristeza', 'serpiente', 'lagartija', 'piña', 'smartphone', 'celsius', 'microsoft', 'vaqueros', 'vector', 'cargador', 'manuscrito', 'gmail', 'yahoo', 'condensador', 'diodo', 'platón', 'aristóteles', 'boquilla', 'fluido', 'fonología', 'zara', 'mallas', 'balompié', 'germen', 'patógeno', 'máscara', 'autovía', 'ilustración', 'ampolla', 'antropología', 'arqueología', 'dell', 'dingle', 'zumo', 'cuchara', 'pfizer', 'medicamento', 'multimillonario', ...
#      > Cantidad de pares no procesados: 300
#
#
# >>> Resultados
#     rg65_es.txt: 0.9360421927310023
#     semeval17_es.txt: 0.7456052967887197
#     all_data: 0.7832983257366716
#
#
# >>> Saving results in _w2v_sbwc

# %%
import AnalogyTest

# Test de analogias
print(">>> Test de analogias")
for embedding in embedding_name_list:
    print("\n>>> Testing " + embedding + "\n")
    
    print(">>> Cargando vectores...", end='')
    wordvector = get_wordvector(embedding, 10000)
    wordvector_name = embedding.split('.')[0]
    print(" listo\n")
    
    AnalogyTest.analogyTest(wordvector, wordvector_name, all_score=True)
# Out:
# >>> Test de analogias
#
# >>> Testing _fasttext_sbwc.vec
#
# >>> Cargando vectores...listo
#
# >>> Testing : _español_D01 [prefijo_anti-].txt
# >>> Testing : _español_D02 [prefijo_des-].txt
# >>> Testing : _español_D03 [prefijo_in-].txt
# >>> Testing : _español_D04 [sufijo_-able].txt
# >>> Testing : _español_D05 [sufijo_-ción].txt
# >>> Testing : _español_D06 [sufijo_-ísimo].txt
# >>> Testing : _español_D07 [sufijo_-ita].txt
# >>> Testing : _español_D08 [sufijo_-ito].txt
# >>> Testing : _español_D09 [sufijo_-mente].txt
# >>> Testing : _español_D10 [sufijo_-miento].txt
# >>> Testing : _español_E01 [pais - capital].txt
# >>> Testing : _español_E02 [pais - idioma].txt
# >>> Testing : _español_E04 [nombre - nacionalidad].txt
# >>> Testing : _español_E05 [nombre - ocupacion].txt
# >>> Testing : _español_E10 [hombre - mujer].txt
# >>> Testing : _español_E11 [pais - gentilicio].txt
# >>> Testing : _español_I067 [gerund - parti].txt
# >>> Testing : _español_I096 [inf - gerund].txt
# >>> Testing : _español_I097 [inf - parti].txt
# >>> Testing : _español_I162 [pret_perf__1_sing - futuro_simp__1_sing].tx
], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I096 [inf - gerund].txt', [['3CosAdd', '0.8833333333333333'], ['3CosMul', '0.9083333333333333'], ['PairDir', '0.0'], ['cos', '0.46111255685488384'], ['euc', '0.48359337747097014'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I097 [inf - parti].txt', [['3CosAdd', '0.5604838709677419'], ['3CosMul', '0.6451612903225806'], ['PairDir', '0.0'], ['cos', '0.33376412329474286'], ['euc', '0.42176691755171747'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I162 [pret_perf__1_sing - futuro_simp__1_sing].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_I254 [presente__1_sing - futuro_simp__1_sing].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_I260 [presente__1_sing - pret_perf__1_sing].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_I265 [presente__1_sing - presente__1_plur].txt', [['3CosAdd', '0.6666666666666666'], ['3CosMul', '0.6666666666666666'], ['PairDir', '0.0'], ['cos', '0.35445745289325714'], ['euc', '0.4262649317582448'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I269 [presente__1_sing - presente__3_sing].txt', [['3CosAdd', '0.11904761904761904'], ['3CosMul', '0.14285714285714285'], ['PairDir', '0.0'], ['cos', '0.09033947140865382'], ['euc', '0.3228231895537603'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I466 [sustantivo - plural(s)].txt', [['3CosAdd', '0.6226215644820295'], ['3CosMul', '0.6342494714587738'], ['PairDir', '0.0'], ['cos', '0.12336531959415141'], ['euc', '0.3375151562514315'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I467 [sustantivo - plural(es)].txt', [['3CosAdd', '0.581646423751687'], ['3CosMul', '0.5964912280701754'], ['PairDir', '0.0'], ['cos', '0.11653105768001344'], ['euc', '0.3343044705236489'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L07 [sinonimos - intensidad].txt', [['3CosAdd', '0.17647058823529413'], ['3CosMul', '0.19934640522875818'], ['PairDir', '0.0'], ['cos', '0.09223331656387636'], ['euc', '0.3210526506106059'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L08 [sinonimos - exacto].txt', [['3CosAdd', '0.25384615384615383'], ['3CosMul', '0.26615384615384613'], ['PairDir', '0.0'], ['cos', '0.08607903807932767'], ['euc', '0.3181817565514491'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L09 [antonimos - grado].txt', [['3CosAdd', '0.21212121212121213'], ['3CosMul', '0.2012987012987013'], ['PairDir', '0.0'], ['cos', '0.04368068667298013'], ['euc', '0.30156287744447785'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L10 [antonimos - binario].txt', [['3CosAdd', '0.3817460317460317'], ['3CosMul', '0.3634920634920635'], ['PairDir', '0.0'], ['cos', '0.018674416749623588'], ['euc', '0.28897680044174195'], ['ncos', '-1.0'], ['neuc', '0.0']]]
# >>> Testing _fasttext_suc.vec
#
# >>> Cargando vectores...listo
#
# >>> Testing : _español_D01 [prefijo_anti-].txt
# >>> Testing : _español_D02 [prefijo_des-].txt
# >>> Testing : _español_D03 [prefijo_in-].txt
# >>> Testing : _español_D04 [sufijo_-able].txt
# >>> Testing : _español_D05 [sufijo_-ción].txt
# >>> Testing : _español_D06 [sufijo_-ísimo].txt
# >>> Testing : _español_D07 [sufijo_-ita].txt
# >>> Testing : _español_D08 [sufijo_-ito].txt
# >>> Testing : _español_D09 [sufijo_-mente].txt
# >>> Testing : _español_D10 [sufijo_-miento].txt
# >>> Testing : _español_E01 [pais - capital].txt
# >>> Testing : _español_E02 [pais - idioma].txt
# >>> Testing : _español_E04 [nombre - nacionalidad].txt
# >>> Testing : _español_E05 [nombre - ocupacion].txt
# >>> Testing : _español_E10 [hombre - mujer].txt
# >>> Testing : _español_E11 [pais - gentilicio].txt
# >>> Testing : _español_I067 [gerund - parti].txt
# >>> Testing : _español_I096 [inf - gerund].txt
# >>> Testing : _español_I097 [inf - parti].txt
# >>> Testing : _español_I162 [pret_perf__1_sing - futuro_simp__1_sing].tx
# >>> Testing : _español_D04 [sufijo_-able].txt
# >>> Testing : _español_D05 [sufijo_-ción].txt
# >>> Testing : _español_D06 [sufijo_-ísimo].txt
# >>> Testing : _español_D07 [sufijo_-ita].txt
# >>> Testing : _español_D08 [sufijo_-ito].txt
# >>> Testing : _español_D09 [sufijo_-mente].txt
# >>> Testing : _español_D10 [sufijo_-miento].txt
# >>> Testing : _español_E01 [pais - capital].txt
# >>> Testing : _español_E02 [pais - idioma].txt
# >>> Testing : _español_E04 [nombre - nacionalidad].txt
# >>> Testing : _español_E05 [nombre - ocupacion].txt
# >>> Testing : _español_E10 [hombre - mujer].txt
# >>> Testing : _español_E11 [pais - gentilicio].txt
# >>> Testing : _español_I067 [gerund - parti].txt
# >>> Testing : _español_I096 [inf - gerund].txt
# >>> Testing : _español_I097 [inf - parti].txt
# >>> Testing : _español_I162 [pret_perf__1_sing - futuro_simp__1_sing].txt
# >>> Testing : _español_I254 [presente__1_sing - futuro_simp__1_sing].txt
# >>> Testing : _español_I260 [presente__1_sing - pret_perf__1_sing].txt
# >>> Testing : _español_I265 [presente__1_sing - presente__1_plur].txt
# >>> Testing : _español_I269 [presente__1_sing - presente__3_sing].txt
# >>> Testing : _español_I466 [sustantivo - plural(s)].txt
# >>> Testing : _español_I467 [sustantivo - plural(es)].txt
# >>> Testing : _español_L07 [sinonimos - intensidad].txt
# >>> Testing : _español_L08 [sinonimos - exacto].txt
# >>> Testing : _español_L09 [antonimos - grado].txt
# >>> Testing : _español_L10 [antonimos - binario].txt
# >>> Results
#     ['_español_D01 [prefijo_anti-].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D02 [prefijo_des-].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D03 [prefijo_in-].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D04 [sufijo_-able].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.11500778794288635'], ['euc', '0.3337220549583435'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D05 [sufijo_-ción].txt', [['3CosAdd', '0.3333333333333333'], ['3CosMul', '0.3333333333333333'], ['PairDir', '0.0'], ['cos', '0.07536282856017351'], ['euc', '0.311875581741333'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D06 [sufijo_-ísimo].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D07 [sufijo_-ita].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D08 [sufijo_-ito].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D09 [sufijo_-mente].txt', [['3CosAdd', '0.16666666666666666'], ['3CosMul', '0.16666666666666666'], ['PairDir', '0.0'], ['cos', '0.1117674857378006'], ['euc', '0.3144361575444539'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D10 [sufijo_-miento].txt', [['3CosAdd', '0.5'], ['3CosMul', '0.5'], ['PairDir', '0.0'], ['cos', '0.14247296750545502'], ['euc', '0.3400670289993286'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E01 [pais - capital].txt', [['3CosAdd', '0.8029100529100529'], ['3CosMul', '0.8055555555555556'], ['PairDir', '0.0'], ['cos', '0.4303886093711727'], ['euc', '0.4668115651796734'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E02 [pais - idioma].txt', [['3CosAdd', '0.38095238095238093'], ['3CosMul', '0.40476190476190477'], ['PairDir', '0.0'], ['cos', '0.3942771510235847'], ['euc', '0.4492514182177801'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E04 [nombre - nacionalidad].txt', [['3CosAdd', '0.30718954248366015'], ['3CosMul', '0.3431372549019608'], ['PairDir', '0.0'], ['cos', '0.2777501620044871'], ['euc', '0.3974393341276381'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E05 [nombre - ocupacion].txt', [['3CosAdd', '0.3416666666666667'], ['3CosMul', '0.38333333333333336'], ['PairDir', '0.0'], ['cos', '0.2928349501142899'], ['euc', '0.40492965703209244'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_
# >>> Testing : _español_D05 [sufijo_-ción].txt
# >>> Testing : _español_D06 [sufijo_-ísimo].txt
# >>> Testing : _español_D07 [sufijo_-ita].txt
# >>> Testing : _español_D08 [sufijo_-ito].txt
# >>> Testing : _español_D09 [sufijo_-mente].txt
# >>> Testing : _español_D10 [sufijo_-miento].txt
# >>> Testing : _español_E01 [pais - capital].txt
# >>> Testing : _español_E02 [pais - idioma].txt
# >>> Testing : _español_E04 [nombre - nacionalidad].txt
# >>> Testing : _español_E05 [nombre - ocupacion].txt
# >>> Testing : _español_E10 [hombre - mujer].txt
# >>> Testing : _español_E11 [pais - gentilicio].txt
# >>> Testing : _español_I067 [gerund - parti].txt
# >>> Testing : _español_I096 [inf - gerund].txt
# >>> Testing : _español_I097 [inf - parti].txt
# >>> Testing : _español_I162 [pret_perf__1_sing - futuro_simp__1_sing].txt
# >>> Testing : _español_I254 [presente__1_sing - futuro_simp__1_sing].txt
# >>> Testing : _español_I260 [presente__1_sing - pret_perf__1_sing].txt
# >>> Testing : _español_I265 [presente__1_sing - presente__1_plur].txt
# >>> Testing : _español_I269 [presente__1_sing - presente__3_sing].txt
# >>> Testing : _español_I466 [sustantivo - plural(s)].txt
# >>> Testing : _español_I467 [sustantivo - plural(es)].txt
# >>> Testing : _español_L07 [sinonimos - intensidad].txt
# >>> Testing : _español_L08 [sinonimos - exacto].txt
# >>> Testing : _español_L09 [antonimos - grado].txt
# >>> Testing : _español_L10 [antonimos - binario].txt
# >>> Results
#     ['_español_D01 [prefijo_anti-].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D02 [prefijo_des-].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.03438052783409754'], ['euc', '0.3006201187769572'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D03 [prefijo_in-].txt', [['3CosAdd', '0.16666666666666666'], ['3CosMul', '0.16666666666666666'], ['PairDir', '0.0'], ['cos', '0.08587240427732468'], ['euc', '0.3062777916590373'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D04 [sufijo_-able].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.09717341636617978'], ['euc', '0.32817838589350384'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D05 [sufijo_-ción].txt', [['3CosAdd', '0.36666666666666664'], ['3CosMul', '0.3333333333333333'], ['PairDir', '0.0'], ['cos', '0.08995332634076476'], ['euc', '0.3238248586654663'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D06 [sufijo_-ísimo].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D07 [sufijo_-ita].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D08 [sufijo_-ito].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D09 [sufijo_-mente].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.10683042649179697'], ['euc', '0.3238373001416524'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D10 [sufijo_-miento].txt', [['3CosAdd', '0.16666666666666666'], ['3CosMul', '0.16666666666666666'], ['PairDir', '0.0'], ['cos', '0.18451284989714622'], ['euc', '0.3622557918230693'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E01 [pais - capital].txt', [['3CosAdd', '0.9066666666666666'], ['3CosMul', '0.8916666666666667'], ['PairDir', '0.0'], ['cos', '0.4730623995761077'], ['euc', '0.48628802051146824'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E02 [pais - idioma].txt', [['3CosAdd', '0.31666666666666665'], ['3CosMul', '0.366025641025641'], ['PairDir', '0.0'], ['cos', '0.450629001416457'], ['euc', '0.479492291330527'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E04 [nombre - nacionalidad].txt', [['3CosAdd', '0.37777777777777777'], ['3CosMul', '0.35555555555555557'], ['PairDir', '0.0'], ['cos', '0.28605845007631514'], ['euc', '0.4015874180528853'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_
# >>> Testing : _español_D03 [prefijo_in-].txt
# >>> Testing : _español_D04 [sufijo_-able].txt
# >>> Testing : _español_D05 [sufijo_-ción].txt
# >>> Testing : _español_D06 [sufijo_-ísimo].txt
# >>> Testing : _español_D07 [sufijo_-ita].txt
# >>> Testing : _español_D08 [sufijo_-ito].txt
# >>> Testing : _español_D09 [sufijo_-mente].txt
# >>> Testing : _español_D10 [sufijo_-miento].txt
# >>> Testing : _español_E01 [pais - capital].txt
# >>> Testing : _español_E02 [pais - idioma].txt
# >>> Testing : _español_E04 [nombre - nacionalidad].txt
# >>> Testing : _español_E05 [nombre - ocupacion].txt
# >>> Testing : _español_E10 [hombre - mujer].txt
# >>> Testing : _español_E11 [pais - gentilicio].txt
# >>> Testing : _español_I067 [gerund - parti].txt
# >>> Testing : _español_I096 [inf - gerund].txt
# >>> Testing : _español_I097 [inf - parti].txt
# >>> Testing : _español_I162 [pret_perf__1_sing - futuro_simp__1_sing].txt
# >>> Testing : _español_I254 [presente__1_sing - futuro_simp__1_sing].txt
# >>> Testing : _español_I260 [presente__1_sing - pret_perf__1_sing].txt
# >>> Testing : _español_I265 [presente__1_sing - presente__1_plur].txt
# >>> Testing : _español_I269 [presente__1_sing - presente__3_sing].txt
# >>> Testing : _español_I466 [sustantivo - plural(s)].txt
# >>> Testing : _español_I467 [sustantivo - plural(es)].txt
# >>> Testing : _español_L07 [sinonimos - intensidad].txt
# >>> Testing : _español_L08 [sinonimos - exacto].txt
# >>> Testing : _español_L09 [antonimos - grado].txt
# >>> Testing : _español_L10 [antonimos - binario].txt
# >>> Results
#     ['_español_D01 [prefijo_anti-].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D02 [prefijo_des-].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.06480084359645844'], ['euc', '0.31258314847946167'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D03 [prefijo_in-].txt', [['3CosAdd', '0.16666666666666666'], ['3CosMul', '0.16666666666666666'], ['PairDir', '0.0'], ['cos', '-0.01224709302186966'], ['euc', '0.273900310198466'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D04 [sufijo_-able].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.16594050824642181'], ['euc', '0.3522183299064636'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D05 [sufijo_-ción].txt', [['3CosAdd', '0.45'], ['3CosMul', '0.45'], ['PairDir', '0.0'], ['cos', '0.1262299135327339'], ['euc', '0.33721410632133486'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D06 [sufijo_-ísimo].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D07 [sufijo_-ita].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D08 [sufijo_-ito].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_D09 [sufijo_-mente].txt', [['3CosAdd', '0.16666666666666666'], ['3CosMul', '0.16666666666666666'], ['PairDir', '0.0'], ['cos', '0.10407323638598125'], ['euc', '0.3256973425547282'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_D10 [sufijo_-miento].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.16666666666666666'], ['PairDir', '0.0'], ['cos', '0.1352371796965599'], ['euc', '0.34183307488759357'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E01 [pais - capital].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_E02 [pais - idioma].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.23344646394252777'], ['euc', '0.3808025121688843'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E04 [nombre - nacionalidad].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_E05 [nombre - ocupacion].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_E10 [hombre - mujer].txt', [['3CosAdd', '0.8625'], ['3CosMul', '0.8666666666666667'], ['PairDir', '0.0'], ['cos', '0.3740070259043326'], ['euc', '0.43128046169877055'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_E11 [pais - gentilicio].txt', [['3CosAdd', '0.0'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.16934746503829956'], ['euc', '0.3199548125267029'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I067 [gerund - parti].txt', [['3CosAdd', '0.6139705882352942'], ['3CosMul', '0.6948529411764706'], ['PairDir', '0.0'], ['cos', '0.39170134774244886'], ['euc', '0.4484138320035794'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I096 [inf - gerund].txt', [['3CosAdd', '0.9714285714285714'], ['3CosMul', '0.9904761904761905'], ['PairDir', '0.0'], ['cos', '0.45199645289352963'], ['euc', '0.4786303738753001'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I097 [inf - parti].txt', [['3CosAdd', '0.48185483870967744'], ['3CosMul', '0.5685483870967742'], ['PairDir', '0.0'], ['cos', '0.30872364231923244'], ['euc', '0.41281457593844784'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I162 [pret_perf__1_sing - futuro_simp__1_sing].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_I254 [presente__1_sing - futuro_simp__1_sing].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_I260 [presente__1_sing - pret_perf__1_sing].txt', [['3CosAdd', 'Nan'], ['3CosMul', 'Nan'], ['PairDir', 'Nan'], ['cos', 'Nan'], ['euc', 'Nan'], ['ncos', 'Nan'], ['neuc', 'Nan']]]
#     ['_español_I265 [presente__1_sing - presente__1_plur].txt', [['3CosAdd', '1.0'], ['3CosMul', '1.0'], ['PairDir', '0.0'], ['cos', '0.6725665330886841'], ['euc', '0.5829509496688843'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I269 [presente__1_sing - presente__3_sing].txt', [['3CosAdd', '0.03333333333333333'], ['3CosMul', '0.0'], ['PairDir', '0.0'], ['cos', '0.07958527499188979'], ['euc', '0.3198867638905843'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I466 [sustantivo - plural(s)].txt', [['3CosAdd', '0.5016611295681063'], ['3CosMul', '0.5415282392026578'], ['PairDir', '0.0'], ['cos', '0.12565707401758933'], ['euc', '0.33864996645801754'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_I467 [sustantivo - plural(es)].txt', [['3CosAdd', '0.5555555555555556'], ['3CosMul', '0.5952380952380952'], ['PairDir', '0.0'], ['cos', '0.12899397873878202'], ['euc', '0.3375686658753289'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L07 [sinonimos - intensidad].txt', [['3CosAdd', '0.29044117647058826'], ['3CosMul', '0.27941176470588236'], ['PairDir', '0.0'], ['cos', '0.09459728824046632'], ['euc', '0.32259610602084327'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L08 [sinonimos - exacto].txt', [['3CosAdd', '0.28804347826086957'], ['3CosMul', '0.2898550724637681'], ['PairDir', '0.0'], ['cos', '0.08563507961482991'], ['euc', '0.3167154113019722'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L09 [antonimos - grado].txt', [['3CosAdd', '0.21212121212121213'], ['3CosMul', '0.22077922077922077'], ['PairDir', '0.0'], ['cos', '0.0452246375054875'], ['euc', '0.303962077929344'], ['ncos', '-1.0'], ['neuc', '0.0']]]
#     ['_español_L10 [antonimos - binario].txt', [['3CosAdd', '0.36185383244206776'], ['3CosMul', '0.3413547237076649'], ['PairDir', '0.0'], ['cos', '0.012707219175496777'], ['euc', '0.2851244294600903'], ['ncos', '-1.0'], ['neuc', '0.0']]]

# %%
import CrossMatchTest

# Test de cross match
pair_method_corpus = []
for embedding in embedding_name_list:
    _embedding = embedding.strip().split('.')[0]
    _embedding = _embedding.split('_')
    
    pair_method_corpus.append([embedding, _embedding[1], _embedding[2]])
    
test_pairing_corpus = []
test_pairing_method = []
for i in range(len(pair_method_corpus)):
    for j in range(len(pair_method_corpus)):
        if j <= i:
            continue
            
        if pair_method_corpus[i][1] == pair_method_corpus[j][1]:
            test_pairing_method.append([pair_method_corpus[i][0], pair_method_corpus[j][0]])
            
        if pair_method_corpus[i][2] == pair_method_corpus[j][2]:
            test_pairing_corpus.append([pair_method_corpus[i][0], pair_method_corpus[j][0]])

print("Cross-match test:")

"""
Paper original utiliza:
repetition = 500
sample_size = 100000
sub_sample_size = 200
"""
repetition = 1
sample_size = 100000
sub_sample_size = 200
F_constant = CrossMatchTest.getFConstant(sub_sample_size)

for pair in test_pairing_method + test_pairing_corpus:
    print(pair)
    
    print("Cargando embedding " + pair[0], end='...')
    wordvector1 = get_wordvector(pair[0], 500000)
    wordvector1_name = pair[0]
    wordvector1.init_sims()
    print("listo")
    
    print("Cargando embedding " + pair[1], end='...')
    wordvector2 = get_wordvector(pair[1], 500000)
    wordvector2_name = pair[1]
    wordvector2.init_sims()
    print("listo")
    
    CrossMatchTest.crossMatchTest(wordvector1, pair[0], wordvector2, pair[1], sample_size, sub_sample_size, repetition, F_constant)
    
    print("\n")
# Out:
# Cross-match test:
# ['_fasttext_sbwc.vec', '_fasttext_suc.vec']

# %%
import OutlierDetectionTest

# Test de outlier detection
print(">>> Test de outlier detection\n")
for embedding in embedding_name_list:
    print(">>> Testing " + embedding + "\n")
    
    print(">>> Cargando vectores...", end='')
    wordvector = get_wordvector(embedding, 10000)
    wordvector_name = embedding.split('.')[0]
    print("listo\n")
    
    OutlierDetectionTest.outlierDetectionTest(wordvector, wordvector_name)
# Out:
# >>> Test de outlier detection
#
# >>> Testing _fasttext_sbwc.vec
#
# >>> Cargando vectores...listo
#
# >>> Test 1 of 436
# >>> Original set:
#     ['esterházy', 'borjigin', 'bernoulli', 'strauss', 'qizilbash', 'amati']
#     ['sinonimia', 'mario']
# >>> In-vocabulary set:
#     []
#     ['mario']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 2 of 436
# >>> Original set:
#     ['makati', 'tacloban', 'zamboanga', 'baguio', 'cebú', 'davao', 'manila']
#     ['kalayaan']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 3 of 436
# >>> Original set:
#     ['trillian', 'kopete', 'irssi', 'pidgin', 'mirc', 'chatzilla']
#     ['asterisk', 'iphoto', 'yacc']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 4 of 436
# >>> Original set:
#     ['líridas', 'perseidas', 'oriónidas', 'leónidas', 'gemínidas', 'dracónidas', 'cuadrántidas']
#     ['tormenta', 'divergencia']
# >>> In-vocabulary set:
#     []
#     ['tormenta']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 5 of 436
# >>> Original set:
#     ['volta', 'ashanti']
#     ['vantaa', 'viterbo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 6 of 436
# >>> Original set:
#     ['oro', 'simbu', 'central', 'sandaun']
#     ['raión', 'sarek']
# >>> In-vocabulary set:
#     ['oro', 'central']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 7 of 436
# >>> Original set:
#     ['kilimanjaro', 'dolomitas', 'kebnekaise', 'ahaggar']
#     ['svcd', 'stack']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 8 of 436
# >>> Original set:
#     ['dongcheng', 'xicheng', 'hailar', 'haidian', 'fengtai']
#     ['intramuros', 'kazimierz', 'fíbula', 'anillo']
# >>> In-vocabulary set:
#     []
#     ['anillo']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 9 of 436
# >>> Original set:
#     ['manhattan', 'londres', 'múnich', 'stuttgart', 'daca']
#     ['nkongsamba', 'buellton', 'raión', 'voivodato']
# >>> In-vocabulary set:
#     ['manhattan', 'londres', 'múnich']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 10 of 436
# >>> Original set:
#     ['golmud', 'dunhuang', 'kashgar', 'qufu', 'khotan', 'dali', 'yining', 'shihezi']
#     ['fusui', 'ripollés', 'venecia', 'viterbo']
# >>> In-vocabulary set:
#     []
#     ['venecia']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 11 of 436
# >>> Original set:
#     ['galicia', 'cataluña', 'canarias', 'asturias', 'andalucía', 'aragón']
#     ['azawad']
# >>> In-vocabulary set:
#     ['galicia', 'cataluña', 'canarias', 'asturias', 'andalucía', 'aragón']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 12 of 436
# >>> Original set:
#     ['gouda', 'parmesano', 'edam', 'emmental', 'camembert', 'roquefort', 'mascarpone', 'stilton']
#     ['smetana', 'lebkuchen', 'muffin', 'fanta']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 13 of 436
# >>> Original set:
#     ['achicoria', 'hinojo', 'espinaca']
#     ['çorba', 'caña']
# >>> In-vocabulary set:
#     []
#     ['caña']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 14 of 436
# >>> Original set:
#     ['dreamworks', 'disney', 'pixar']
#     ['cinecittà', 'uraniborg', 'radioastron']
# >>> In-vocabulary set:
#     ['disney']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 15 of 436
# >>> Original set:
#     ['openssh', 'otrs', 'wordpress', 'mysql', 'netbsd', 'freebsd', 'mariadb']
#     ['ransomware', 'cortina', 'pañuelo', 'túnez']
# >>> In-vocabulary set:
#     []
#     ['túnez']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 16 of 436
# >>> Original set:
#     ['sacavém', 'barrancos', 'quarteira', 'fátima', 'sagres']
#     ['departamento', 'azawad']
# >>> In-vocabulary set:
#     []
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 17 of 436
# >>> Original set:
#     ['pigazzano', 'magenta', 'coreca', 'alvito', 'lari']
#     ['camopi', 'corvey']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 18 of 436
# >>> Original set:
#     ['ondícula', 'factorial', 'estatúder', 'radicación']
#     ['dslr']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 19 of 436
# >>> Original set:
#     ['moab', 'jdam']
#     ['febrero']
# >>> In-vocabulary set:
#     []
#     ['febrero']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 20 of 436
# >>> Original set:
#     ['kanazawa', 'nara', 'kagoshima', 'nagano', 'akita', 'nagasaki', 'naha']
#     ['miyama', 'minamishimabara', 'manga', 'alva', 'trujillo']
# >>> In-vocabulary set:
#     []
#     ['manga', 'trujillo']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 21 of 436
# >>> Original set:
#     ['derbyshire', 'essex', 'hampshire', 'yorkshire', 'cornualles', 'kent', 'surrey', 'devon']
#     ['medway']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 22 of 436
# >>> Original set:
#     ['grado', '±', 'óbelo', 'menos', 'nabla', 'virgulilla', 'más']
#     ['demótica']
# >>> In-vocabulary set:
#     ['grado', 'menos', 'más']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 23 of 436
# >>> Original set:
#     ['maine', 'mayflower', 'hms']
#     ['ucronía', 'peplum']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 24 of 436
# >>> Original set:
#     ['matsue', 'mito', 'tottori', 'matsumoto', 'kōfu', 'odawara', 'yamagata', 'fukui']
#     ['minamishimabara', 'sakuragawa', 'goldendale', 'manga', 'bitinia']
# >>> In-vocabulary set:
#     ['mito']
#     ['manga']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 25 of 436
# >>> Original set:
#     ['mordor', 'rohan', 'comarca', 'arnor', 'gondor', 'muspelheim', 'valinor', 'númenor']
#     ['duat', 'pete', 'mario']
# >>> In-vocabulary set:
#     ['comarca']
#     ['mario']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 26 of 436
# >>> Original set:
#     ['grevenmacher', 'vianden', 'diekirch', 'wiltz', 'remich', 'echternach', 'luxemburgo']
#     ['raión']
# >>> In-vocabulary set:
#     ['luxemburgo']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 27 of 436
# >>> Original set:
#     ['amravati', 'kurnool', 'anantapur', 'karimnagar', 'ladakh', 'kutch', 'adilabad', 'nellore']
#     ['mahesana', 'garhwal', 'vantaa', 'intramuros', 'kazimierz']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 28 of 436
# >>> Original set:
#     ['inkscape', 'freehand', 'dia', 'coreldraw']
#     ['lightwave', 'sdl']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 29 of 436
# >>> Original set:
#     ['mukoyōshi', 'hijastra', 'hermanastra', 'hijastro', 'hermanastro', 'madrastra', 'padrastro']
#     ['abuelo', 'tío', 'deísmo']
# >>> In-vocabulary set:
#     []
#     ['abuelo', 'tío']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 30 of 436
# >>> Original set:
#     ['adelebsen', 'detern', 'delligsen', 'gieboldehausen', 'nörten', 'ottersberg']
#     ['bariano', 'ibb', 'azawad']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 31 of 436
# >>> Original set:
#     ['metropolitano', 'archimandrita', 'exarca', 'arzobispo', 'obispo', 'preboste']
#     ['løgmaður', 'sicario', 'magnate']
# >>> In-vocabulary set:
#     ['metropolitano', 'arzobispo', 'obispo']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 32 of 436
# >>> Original set:
#     ['bonn', 'kassel', 'múnich', 'darmstadt', 'heidelberg', 'mannheim', 'wiesbaden', 'schwerin']
#     ['capitolio', 'reichstag']
# >>> In-vocabulary set:
#     ['múnich']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 33 of 436
# >>> Original set:
#     ['berna', 'edimburgo', 'ginebra', 'bonn', 'hannover', 'múnich', 'zúrich']
#     ['voivodato']
# >>> In-vocabulary set:
#     ['ginebra', 'múnich']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 34 of 436
# >>> Original set:
#     ['anna', 'laura', 'olga', 'barbara', 'melissa', 'sara', 'eva', 'maria']
#     ['jan', 'abraham', 'esterházy', 'borjigin', 'kraus']
# >>> In-vocabulary set:
#     ['anna', 'laura', 'sara', 'eva', 'maria']
#     ['jan', 'abraham']
# OP and OD list:
# [5, 5]
# [1, 1]
# >>> Test 35 of 436
# >>> Original set:
#     ['gol', 'contrarreforma', 'precipitaciones', 'cruzadas', 'tormenta']
#     ['reconstrucción']
# >>> In-vocabulary set:
#     ['gol', 'precipitaciones', 'tormenta']
#     ['reconstrucción']
# OP and OD list:
# [3]
# [1]
# >>> Test 36 of 436
# >>> Original set:
#     ['navidad']
#     ['maslenitsa', '2015', 'varsovia']
# >>> In-vocabulary set:
#     ['navidad']
#     ['varsovia']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 37 of 436
# >>> Original set:
#     ['kajeti', 'imereti', 'guria', 'tiflis']
#     ['ayaria']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 38 of 436
# >>> Original set:
#     ['bolhrad', 'odesa', 'kiliya', 'artsyz', 'reni', 'ananiev', 'izmail', 'vylkove']
#     ['somme', 'departamento']
# >>> In-vocabulary set:
#     []
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 39 of 436
# >>> Original set:
#     ['chernóbil', 'jotyn', 'brody', 'rajiv', 'alupka', 'hálych', 'bajchisarái', 'izmail']
#     ['gurzuf', 'bezliúdivka', 'siegen']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 40 of 436
# >>> Original set:
#     ['cet', 'gmt', 'et']
#     ['medway', 'salford']
# >>> In-vocabulary set:
#     ['gmt', 'et']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 41 of 436
# >>> Original set:
#     ['adam', 'atabeg', 'brfxxccxxmnpcccclllmmnprxvclmnckssqlbb11116', 'albert', 'dani', 'ivan', 'emil', 'gabriel']
#     ['andrea', 'apellido', 'borjigin', 'bernoulli']
# >>> In-vocabulary set:
#     ['adam', 'albert', 'gabriel']
#     ['andrea', 'apellido']
# OP and OD list:
# [1, 3]
# [0, 1]
# >>> Test 42 of 436
# >>> Original set:
#     ['berat', 'delvinë', 'korçë', 'bulqizë', 'skrapar', 'dibër', 'vlorë']
#     ['schmiden', 'kazimierz', 'torque']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 43 of 436
# >>> Original set:
#     ['laconia', 'acaya', 'ftiótide', 'andros', 'beocia', 'argólida', 'ioánina']
#     ['larisa', 'heraclión']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 44 of 436
# >>> Original set:
#     ['hollywood', 'cherrapunji', 'planoise', 'harlem', 'vrahovice', 'benetice']
#     ['mozilla', 'deísmo']
# >>> In-vocabulary set:
#     ['hollywood']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 45 of 436
# >>> Original set:
#     ['niká']
#     ['oxímoron', 'norma', 'realidad']
# >>> In-vocabulary set:
#     []
#     ['norma', 'realidad']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 46 of 436
# >>> Original set:
#     ['sherlock']
#     ['bakugan', 'another']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 47 of 436
# >>> Original set:
#     ['baltimore', 'richmond', 'alexandria', 'norfolk', 'chesapeake']
#     ['grenada', 'hamburg', 'milan']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 48 of 436
# >>> Original set:
#     ['caballero', 'estudiante', 'dramaturgo', 'profeta', 'apicultura', 'samurái', 'autor']
#     ['satsuma', 'realidad']
# >>> In-vocabulary set:
#     ['caballero', 'estudiante', 'autor']
#     ['realidad']
# OP and OD list:
# [3]
# [1]
# >>> Test 49 of 436
# >>> Original set:
#     ['sollentuna', 'haninge', 'solna', 'danderyd', 'malmö', 'huddinge', 'botkyrka', 'täby']
#     ['sundsvall', 'mixco']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 50 of 436
# >>> Original set:
#     ['pkm']
#     ['culebrina']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 51 of 436
# >>> Original set:
#     ['linköping', 'kalmar', 'gotemburgo', 'karlstad', 'västerås', 'lund', 'visby', 'umeå']
#     ['parramatta', 'kibera', 'este', 'savinia']
# >>> In-vocabulary set:
#     []
#     ['este']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 52 of 436
# >>> Original set:
#     ['barriles', 'galones', 'pinta', 'l', 'cc', 'bushel', 'arqueo']
#     ['oersted', 'magnitud']
# >>> In-vocabulary set:
#     ['l', 'cc']
#     ['magnitud']
# OP and OD list:
# [2]
# [1]
# >>> Test 53 of 436
# >>> Original set:
#     ['chumphon', 'sukhothai', 'krabi', 'buriram', 'kanchanaburi', 'chaiyaphum']
#     ['kokemäki', 'aljezur', 'belgrado']
# >>> In-vocabulary set:
#     []
#     ['belgrado']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 54 of 436
# >>> Original set:
#     ['semipresidencialista', 'califato', 'teocracia', 'presidencialista', 'dictadura']
#     ['autocracia']
# >>> In-vocabulary set:
#     ['dictadura']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 55 of 436
# >>> Original set:
#     ['filemaker', 'wordpress', 'plone', 'moodle', 'phpbb', 'mambo']
#     ['iphoto', 'ransomware', 'sábana', 'mantel', 'carbohidratos', 'túnez']
# >>> In-vocabulary set:
#     []
#     ['túnez']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 56 of 436
# >>> Original set:
#     ['eurotúnel', 'gotardo', 'simplon', 'marmaray']
#     ['metrô', 'führerbunker']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 57 of 436
# >>> Original set:
#     ['sed', 'nano', 'vi', 'kate', 'emacs', 'gedit']
#     ['coreldraw', 'maxima', 'ktorrent', 'gnumeric', 'latex']
# >>> In-vocabulary set:
#     ['vi', 'kate']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 58 of 436
# >>> Original set:
#     ['nano', 'pico', 'kilo', 'mega', 'micro', 'centi', 'tera', 'giga']
#     ['maslenitsa']
# >>> In-vocabulary set:
#     ['pico']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 59 of 436
# >>> Original set:
#     ['ajedrez', 'go', 'backgammon', 'chaturanga', 'monopoly', 'othello', 'damas']
#     ['pañuelo']
# >>> In-vocabulary set:
#     ['ajedrez', 'go']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 60 of 436
# >>> Original set:
#     ['ubuntu', 'debian', 'knoppix', 'kubuntu', 'gentoo', 'fedora', 'slackware']
#     ['distribución', 'glibc']
# >>> In-vocabulary set:
#     []
#     ['distribución']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 61 of 436
# >>> Original set:
#     ['győr', 'debrecen', 'miskolc', 'székesfehérvár', 'pécs', 'szeged', 'sopron', 'nyíregyháza']
#     ['sirte', 'intramuros']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 62 of 436
# >>> Original set:
#     ['wimbledon']
#     ['eurocopa']
# >>> In-vocabulary set:
#     []
#     ['eurocopa']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 63 of 436
# >>> Original set:
#     ['gpib', 'pop3', 'hdmi', 'dicom', 'can']
#     ['leecher', 'rtcp', 'olimpiadas', 'gmt']
# >>> In-vocabulary set:
#     ['can']
#     ['gmt']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 64 of 436
# >>> Original set:
#     ['joomla', 'drupal', 'django', 'asp.net', 'asp']
#     ['unity', 'pong', 'gopher', 'allmusic']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 65 of 436
# >>> Original set:
#     ['cien', 'cuatro', 'doce', 'xiv', 'dos', 'diez', '8', 'seis']
#     ['docena']
# >>> In-vocabulary set:
#     ['cien', 'cuatro', 'doce', 'xiv', 'dos', 'diez', 'seis']
#     ['docena']
# OP and OD list:
# [6]
# [0]
# >>> Test 66 of 436
# >>> Original set:
#     ['svt', 'kamaz', 'ibm', 'juventus', 'avtovaz', 'commodore']
#     ['virgin', 'lucasfilm', 'burbuja.com', 'monopsonio']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 67 of 436
# >>> Original set:
#     ['carmen', 'rigoletto', 'aida']
#     ['reggaeton', 'satsuma', 'realidad', 'pulgarcita']
# >>> In-vocabulary set:
#     ['carmen']
#     ['realidad']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 68 of 436
# >>> Original set:
#     ['imagine']
#     ['álbum', 'almanaque', 'trípode']
# >>> In-vocabulary set:
#     []
#     ['álbum']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 69 of 436
# >>> Original set:
#     ['gotinga', 'marburgo', 'aalen', 'fulda', 'greifswald', 'wetzlar', 'luneburgo', 'stralsund']
#     ['somme', 'departamento', 'país']
# >>> In-vocabulary set:
#     []
#     ['departamento', 'país']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 70 of 436
# >>> Original set:
#     ['samotracia', 'calcis', 'larisa', 'egina', 'heraclión', 'volos', 'rodas']
#     ['menabe', 'i']
# >>> In-vocabulary set:
#     []
#     ['i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 71 of 436
# >>> Original set:
#     ['alcíone', 'tabit', 'procyon', 'dubhe', 'polaris']
#     ['mesarthim']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 72 of 436
# >>> Original set:
#     ['graz', 'salzburgo', 'utrecht', 'innsbruck', 'linz', 'ámsterdam', 'róterdam']
#     ['ullapool']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 73 of 436
# >>> Original set:
#     ['nottingham', 'cambridge', 'york', 'leicester', 'exeter', 'norwich', 'oxford', 'derby']
#     ['dupnitsa', 'kodyma', 'azawad', 'põlva', 'jõhvi']
# >>> In-vocabulary set:
#     ['cambridge', 'york', 'oxford']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 74 of 436
# >>> Original set:
#     ['metegol', 'dardos', 'mikado', 'fingerboard', 'carrom', 'petanca', 'taba']
#     ['villancico', 'ajedrez', 'othello']
# >>> In-vocabulary set:
#     []
#     ['ajedrez']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 75 of 436
# >>> Original set:
#     ['dunam', 'barn', 'ha', 'acres', 'áreas']
#     ['cinco', 'seis', 'magnitud']
# >>> In-vocabulary set:
#     ['ha', 'áreas']
#     ['cinco', 'seis', 'magnitud']
# OP and OD list:
# [0, 0, 2]
# [0, 0, 1]
# >>> Test 76 of 436
# >>> Original set:
#     ['kibutz']
#     ['paratipo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 77 of 436
# >>> Original set:
#     ['eisenach', 'suhl', 'weimar', 'aalen', 'calw', 'bottrop', 'rastatt']
#     ['bachenberg', 'goriška', 'podravska']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 78 of 436
# >>> Original set:
#     ['tokelau', 'molucas', 'bermudas', 'dodecaneso']
#     ['vesterålen', 'highlands']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 79 of 436
# >>> Original set:
#     ['schwimmwagen']
#     ['f2012', 'f2007']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 80 of 436
# >>> Original set:
#     ['uno', 'canasta', 'whist', 'bacará', 'blackjack', 'skat', 'durak']
#     ['rummikub', 'damas', 'pañuelo']
# >>> In-vocabulary set:
#     ['uno']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 81 of 436
# >>> Original set:
#     ['vosgos', 'andes', 'jura', 'cárpatos']
#     ['svcd', 'vcd']
# >>> In-vocabulary set:
#     ['andes']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 82 of 436
# >>> Original set:
#     ['pándavas', 'danaides', 'erinias', 'sith']
#     ['pete']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 83 of 436
# >>> Original set:
#     ['akatsuki', 'jedi']
#     ['mario', 'valarin']
# >>> In-vocabulary set:
#     []
#     ['mario']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 84 of 436
# >>> Original set:
#     ['twiins', 'dioscuros', 'rómulo']
#     ['pándavas', 'rapsoda', 'mosquetero']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 85 of 436
# >>> Original set:
#     ['berna', 'ginebra', 'aarau', 'basilea', 'lausana', 'zúrich', 'coira']
#     ['merrill', 'ladysmith', 'buellton', 'alva']
# >>> In-vocabulary set:
#     ['ginebra', 'basilea']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 86 of 436
# >>> Original set:
#     ['düsseldorf', 'maguncia', 'dresde', 'hannover', 'múnich', 'stuttgart', 'erfurt', 'wiesbaden']
#     ['cheyenne', 'haarlem', 'tiflis', 'põlva', 'kaarma']
# >>> In-vocabulary set:
#     ['múnich']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 87 of 436
# >>> Original set:
#     ['nissan', 'panasonic', 'honda', 'mazda', 'konami', 'yamaha', 'namco']
#     ['virgin', 'michelin', 'benelux']
# >>> In-vocabulary set:
#     ['honda']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 88 of 436
# >>> Original set:
#     ['troy', 'schenectady', 'yonkers', 'binghamton', 'siracusa', 'buffalo']
#     ['grenada', 'hamburg', 'maywood']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 89 of 436
# >>> Original set:
#     ['taraclia', 'basarabeasca', 'cantemir', 'șoldănești', 'călărași', 'briceni', 'cahul']
#     ['usingen', 'breinigerberg', 'schmiden', 'intramuros']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 90 of 436
# >>> Original set:
#     ['victoria', 'bakerloo', 'metropolitan', 'central', 'district', 'circle']
#     ['amstel']
# >>> In-vocabulary set:
#     ['victoria', 'central']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 91 of 436
# >>> Original set:
#     ['lillehammer', 'jessheim', 'vikersund', 'åmot', 'leknes', 'askvoll', 'hønefoss', 'steinkjer']
#     ['piteå', 'lund', 'colunga', 'anjalankoski', 'hatogaya']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 92 of 436
# >>> Original set:
#     ['rijeka', 'šibenik', 'dubrovnik', 'zagreb', 'zadar', 'osijek', 'split']
#     ['nkongsamba', 'buellton', 'departamento', 'tarn', 'voivodato', 'país']
# >>> In-vocabulary set:
#     []
#     ['departamento', 'país']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 93 of 436
# >>> Original set:
#     ['tiburón', 'newtown', 'plymouth', 'vail', 'concord', 'gilbert', 'uxbridge']
#     ['carrollton', 'tarn']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 94 of 436
# >>> Original set:
#     ['ayutthaya']
#     ['slatina', 'bangkok']
# >>> In-vocabulary set:
#     []
#     ['bangkok']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 95 of 436
# >>> Original set:
#     ['ahorcamiento', 'guillotina', 'fusilamiento', 'decapitación', 'lapidación']
#     ['desmembramiento', 'winnenden']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 96 of 436
# >>> Original set:
#     ['arvaikheer', 'sainshand', 'uliastay', 'bulgan', 'dalanzadgad', 'kharkhorin']
#     ['i']
# >>> In-vocabulary set:
#     []
#     ['i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 97 of 436
# >>> Original set:
#     ['madison', 'racine', 'oshkosh', 'appleton', 'kenosha']
#     ['colby', 'augusta', 'friendship', 'livingston', 'este', 'subotica']
# >>> In-vocabulary set:
#     []
#     ['este']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 98 of 436
# >>> Original set:
#     ['beloit', 'manitowoc', 'wausau']
#     ['onalaska', 'colby', 'englewood', 'buffalo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 99 of 436
# >>> Original set:
#     ['alma', 'portage', 'menomonie', 'ashland']
#     ['cudahy', 'friendship', 'englewood', 'goriška', 'subotica']
# >>> In-vocabulary set:
#     ['alma']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 100 of 436
# >>> Original set:
#     ['chittagong', 'chandpur', 'kushtia', 'habiganj', 'daca', 'noakhali', 'bandarban']
#     ['menabe']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 101 of 436
# >>> Original set:
#     ['dupnitsa', 'kyustendil', 'lovech', 'montana', 'kardzhali', 'blagoevgrad', 'lom', 'sneek']
#     ['reading', 'kodyma', 'azawad']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 102 of 436
# >>> Original set:
#     ['wok', 'caldero', 'freidora', 'tandoor', 'cezve', 'pava']
#     ['exprimidor', 'enclavamiento', '3210']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 103 of 436
# >>> Original set:
#     ['mythbusters', 'smackdown', 'zoboomafoo', 'cheburashka']
#     ['reportaje', 'origin']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 104 of 436
# >>> Original set:
#     ['magdeburgo', 'worms', 'augsburgo', 'eisenach', 'marburgo', 'erfurt', 'heidelberg', 'halle']
#     ['somme', 'departamento', 'país', 'voivodato']
# >>> In-vocabulary set:
#     []
#     ['departamento', 'país']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 105 of 436
# >>> Original set:
#     ['lisboa', 'washington', 'parís', 'shanghái', 'estocolmo', 'ámsterdam', 'estambul']
#     ['departamento', 'tarn', 'voivodato']
# >>> In-vocabulary set:
#     ['lisboa', 'washington', 'parís', 'estocolmo', 'estambul']
#     ['departamento']
# OP and OD list:
# [5]
# [1]
# >>> Test 106 of 436
# >>> Original set:
#     ['alūksne', 'balvi', 'aizkraukle', 'cēsis', 'dobele', 'krāslava', 'kuldīga', 'bauska']
#     ['condados']
# >>> In-vocabulary set:
#     []
#     ['condados']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 107 of 436
# >>> Original set:
#     ['wikinoticias', 'wikilibros', 'wikipedia', 'wikiquote', 'wikisource', 'wikileaks', 'wikcionario']
#     ['wikimapia', 'pornhub', 'freedesktop.org']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 108 of 436
# >>> Original set:
#     ['tomar', 'viseu', 'ílhavo', 'évora', 'aveiro', 'braga', 'albufeira']
#     ['manga', 'alva', 'somme', 'raión', 'voivodato']
# >>> In-vocabulary set:
#     ['tomar']
#     ['manga']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 109 of 436
# >>> Original set:
#     ['fambaa', 'dragón', 'huargos', 'blurrg', 'águilas', 'mûmakil', 'thestrals']
#     ['predator', 'dalek', 'enterprise', 'thingol']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 110 of 436
# >>> Original set:
#     ['hada', 'dragón', 'gnomo', 'centauro', 'unicornio', 'dríade', 'cíclope', 'minotauro']
#     ['enterprise', 'mario', 'slovio', 'novial']
# >>> In-vocabulary set:
#     []
#     ['mario']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 111 of 436
# >>> Original set:
#     ['cerbero', 'ortro', 'goofy', 'snoopy', 'pluto']
#     ['silvestre', 'marsupilami', 'neolengua']
# >>> In-vocabulary set:
#     []
#     ['silvestre']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 112 of 436
# >>> Original set:
#     ['bizerta', 'médenine', 'kairuán', 'gabès', 'susa', 'hammamet', 'sfax', 'monastir']
#     ['vantaa']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 113 of 436
# >>> Original set:
#     ['roc', 'quetzalcóatl', 'nejbet', 'piolín', 'basileus', 'garudá', 'arpía']
#     ['marsupilami', 'yggdrasil', 'ents', 'warp', 'simlish']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 114 of 436
# >>> Original set:
#     ['ftp', 'tcp', 'udp', 'http', 'leecher', 'ip', 'irc', 'dns']
#     ['can']
# >>> In-vocabulary set:
#     ['http']
#     ['can']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 115 of 436
# >>> Original set:
#     ['diy', 'rip']
#     ['coartada']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 116 of 436
# >>> Original set:
#     ['liberec', 'pardubice', 'pilsen', 'olomouc', 'ostrava', 'brno']
#     ['departamento', 'tarn']
# >>> In-vocabulary set:
#     []
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 117 of 436
# >>> Original set:
#     ['monmouthshire', 'denbighshire', 'gwynedd', 'flintshire', 'powys', 'ceredigion', 'anglesey', 'pembrokeshire']
#     ['llandudno', 'gibraltar']
# >>> In-vocabulary set:
#     []
#     ['gibraltar']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 118 of 436
# >>> Original set:
#     ['pantanal', 'chaco', 'eslavonia']
#     ['stack', 'gamay', 'vcd']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 119 of 436
# >>> Original set:
#     ['barca', 'gabarra']
#     ['afinación', 'disfagia', 'valarin', 'neolengua']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 120 of 436
# >>> Original set:
#     ['elefant', 'jagdpanther', 'hetzer', 'jagdtiger']
#     ['möbelwagen']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 121 of 436
# >>> Original set:
#     ['éowyn', 'boromir', 'faramir', 'aragorn', 'éomer', 'théoden', 'isildur']
#     ['gremlin', 'warp', 'skynet']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 122 of 436
# >>> Original set:
#     ['asturias', 'navarra', 'cantabria']
#     ['pesoz', 'põlva', 'vormsi']
# >>> In-vocabulary set:
#     ['asturias', 'navarra', 'cantabria']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 123 of 436
# >>> Original set:
#     ['augur', 'gladiador', 'vestal', 'hoplita', 'centurión', 'druida', 'trovador', 'bardo']
#     ['párroco', 'guitarrista', 'mensajero']
# >>> In-vocabulary set:
#     []
#     ['guitarrista']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 124 of 436
# >>> Original set:
#     ['pekín', 'atenas', 'curitiba', 'londres', 'madrid', 'varsovia', 'estambul']
#     ['goldendale', 'manga', 'país', 'voivodato']
# >>> In-vocabulary set:
#     ['pekín', 'atenas', 'londres', 'madrid', 'varsovia', 'estambul']
#     ['manga', 'país']
# OP and OD list:
# [6, 6]
# [1, 1]
# >>> Test 125 of 436
# >>> Original set:
#     ['zaria', 'dutse', 'jalingo', 'makurdi', 'osogbo', 'ikeja']
#     ['intramuros', 'kazimierz']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 126 of 436
# >>> Original set:
#     ['níðhöggr', 'garm', 'auðumbla', 'sköll', 'sleipnir', 'fenrir', 'jörmungandr', 'hati']
#     ['sæhrimnir', 'ymir', 'trol', 'alkonost', 'catreo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 127 of 436
# >>> Original set:
#     ['electroquímica', 'farmacia', 'biotecnología', 'bioquímica', 'climatología']
#     ['criptografía', 'criptoanálisis', 'bandeirantes', 'cultura']
# >>> In-vocabulary set:
#     []
#     ['cultura']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 128 of 436
# >>> Original set:
#     ['năvodari', 'cernavodă', 'sulina', 'râșnov', 'siret', 'buftea', 'sinaia', 'huedin']
#     ['bran', 'aghireşu', 'vantaa']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 129 of 436
# >>> Original set:
#     ['húngaro', 'estonio', 'turco', 'suajili', 'georgiano', 'esperanto', 'euskera', 'finés']
#     ['mari', 'clarividencia', 'maleza']
# >>> In-vocabulary set:
#     ['húngaro', 'turco']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 130 of 436
# >>> Original set:
#     ['padre', 'abuelo', 'hermano', 'tío', 'hijo', 'hija', 'madre']
#     ['teísmo', 'deísmo', 'lisu']
# >>> In-vocabulary set:
#     ['padre', 'abuelo', 'hermano', 'tío', 'hijo', 'hija', 'madre']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 131 of 436
# >>> Original set:
#     ['madha', 'vaticano', 'llivia', 'lesoto']
#     ['voivodato', 'departamento']
# >>> In-vocabulary set:
#     ['vaticano']
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 132 of 436
# >>> Original set:
#     ['hiryu', 'soryu', 'shinano']
#     ['grúa', 'histórica', 'scharnhorst']
# >>> In-vocabulary set:
#     []
#     ['histórica']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 133 of 436
# >>> Original set:
#     ['superhéroe', 'mago', 'supervillano', 'auror']
#     ['pete', 'valarin', 'sindarin']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 134 of 436
# >>> Original set:
#     ['lactulosa', 'sucralosa', 'maltosa', 'maltitol', 'isomalta', 'sacarosa', 'celobiosa', 'trehalosa']
#     ['glicerol', 'vitamina', 'oxireno']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 135 of 436
# >>> Original set:
#     ['dúnadan', 'sindar', 'noldor', 'eldar', 'falmari', 'edain', 'vanyar', 'rohirrim']
#     ['pete', 'neolengua']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 136 of 436
# >>> Original set:
#     ['nagoya', 'kōbe', 'sapporo', 'kioto', 'yokohama', 'hiroshima', 'osaka', 'fukuoka']
#     ['miyawaka', 'tsushima', 'alva', 'bitinia']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 137 of 436
# >>> Original set:
#     ['ntsb', 'nasa', 'usaid', 'cia']
#     ['usda', 'bundesnachrichtendienst', 'volkspolizei', 'ruc']
# >>> In-vocabulary set:
#     ['nasa', 'cia']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 138 of 436
# >>> Original set:
#     ['filemaker', 'dbase', 'phpmyadmin', 'zodb', 'mongodb', 'rrdtool', 'hbase']
#     ['onedrive', 'picasa', 'pared']
# >>> In-vocabulary set:
#     []
#     ['pared']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 139 of 436
# >>> Original set:
#     ['pluscuamperfecto', 'psd', 'futuro', 'presente']
#     ['imperativo', 'gerundio', 'calidad', 'conmutativa', 'exe', 'com']
# >>> In-vocabulary set:
#     ['futuro', 'presente']
#     ['calidad', 'com']
# OP and OD list:
# [2, 2]
# [1, 1]
# >>> Test 140 of 436
# >>> Original set:
#     ['spa', 'nürburgring', 'hockenheimring', 'imola', 'chn', 'sepang', 'suzuka']
#     ['lupa']
# >>> In-vocabulary set:
#     ['spa']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 141 of 436
# >>> Original set:
#     ['kandi', 'cotonú', 'abomey', 'ouidah', 'natitingou', 'parakou', 'djougou']
#     ['x']
# >>> In-vocabulary set:
#     []
#     ['x']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 142 of 436
# >>> Original set:
#     ['uzi', 'mp40', 'thompson', 'sten']
#     ['culebrina']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 143 of 436
# >>> Original set:
#     ['gobustán', 'vändåtberget']
#     ['highlands', 'calvario']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 144 of 436
# >>> Original set:
#     ['firecat']
#     ['toalla', 'mantel']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 145 of 436
# >>> Original set:
#     ['legitimidad', 'colectivismo', 'pluralismo', 'liberalismo', 'conservador']
#     ['ética', 'pereza', 'aeronáutica', 'conquiliología', 'turntablism']
# >>> In-vocabulary set:
#     ['legitimidad', 'conservador']
#     ['ética']
# OP and OD list:
# [0]
# [0]
# >>> Test 146 of 436
# >>> Original set:
#     ['menia', 'asuán', 'alejandría', 'guiza']
#     ['departamento', 'azawad']
# >>> In-vocabulary set:
#     []
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 147 of 436
# >>> Original set:
#     ['adivinación', 'pintor', 'escultor', 'itil']
#     ['experimento', 'respiración']
# >>> In-vocabulary set:
#     ['pintor', 'escultor']
#     ['experimento']
# OP and OD list:
# [2]
# [1]
# >>> Test 148 of 436
# >>> Original set:
#     ['coo', 'vicepresidente', 'cfo', 'cto', 'ceo']
#     ['chanyu', 'mago', 'apellido', 'strauss', 'bernoulli', 'amati']
# >>> In-vocabulary set:
#     ['vicepresidente']
#     ['apellido']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 149 of 436
# >>> Original set:
#     ['semmering', 'seefeld', 'ischgl', 'jungholz', 'sölden', 'altach']
#     ['slatina', 'stykkishólmsbær', 'sandgerði', 'aljezur']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 150 of 436
# >>> Original set:
#     ['cumbria', 'essex', 'hampshire', 'cornualles', 'kent', 'surrey', 'devon']
#     ['condados', 'monmouthshire', 'azawad', 'torbay']
# >>> In-vocabulary set:
#     []
#     ['condados']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 151 of 436
# >>> Original set:
#     ['pingu']
#     ['coraline', 'frankenweenie', 'fantasía']
# >>> In-vocabulary set:
#     []
#     ['fantasía']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 152 of 436
# >>> Original set:
#     ['joomla', 'tumblr', 'blogger', 'wordpress', 'drupal', 'typo3', 'livejournal', 'flock']
#     ['eclipse', 'compilador']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 153 of 436
# >>> Original set:
#     ['tiempo', 'presión', 'masa', 'capacitancia', 'resistencia']
#     ['extensión']
# >>> In-vocabulary set:
#     ['tiempo', 'presión', 'masa', 'resistencia']
#     ['extensión']
# OP and OD list:
# [3]
# [0]
# >>> Test 154 of 436
# >>> Original set:
#     ['ddt', 'bórax', 'aldrina', 'permetrina', 'lindano', 'nicotina', 'dieldrina']
#     ['venlafaxina']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 155 of 436
# >>> Original set:
#     ['estigia', 'anfítrite', 'némesis', 'europa', 'metis', 'calipso', 'tique', 'arpía']
#     ['salmacis', 'éter', 'caos']
# >>> In-vocabulary set:
#     ['europa']
#     ['caos']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 156 of 436
# >>> Original set:
#     ['musashi', 'tirpitz', 'hms']
#     ['swath', 'género']
# >>> In-vocabulary set:
#     []
#     ['género']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 157 of 436
# >>> Original set:
#     ['sed', 'vi', 'cat', 'chdir', 'awk', 'grep', 'mv', 'chmod']
#     ['netstat', 'avg', 'freehand']
# >>> In-vocabulary set:
#     ['vi']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 158 of 436
# >>> Original set:
#     ['pichilemu', 'valparaíso', 'iquique', 'concepción', 'antofagasta', 'temuco']
#     ['sirte']
# >>> In-vocabulary set:
#     ['valparaíso', 'concepción']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 159 of 436
# >>> Original set:
#     ['infinitivo', 'participio', 'optativo', 'indicativo', 'imperativo', 'condicional', 'subjuntivo', 'gerundio']
#     ['ferromagnetismo', 'conmutativa', 'com']
# >>> In-vocabulary set:
#     []
#     ['com']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 160 of 436
# >>> Original set:
#     ['sark', 'guernsey', 'jersey', 'herm', 'jethou', 'brecqhou']
#     ['somme', 'azawad']
# >>> In-vocabulary set:
#     ['jersey']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 161 of 436
# >>> Original set:
#     ['kfc', 'subway']
#     ['quora', 'fila']
# >>> In-vocabulary set:
#     []
#     ['fila']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 162 of 436
# >>> Original set:
#     ['yogur', 'queso', 'kumis', 'caseína', 'nata', 'mascarpone', 'kéfir']
#     ['gugelhupf', 'torte', 'toalla', 'pañuelo', 'fabada']
# >>> In-vocabulary set:
#     ['queso']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 163 of 436
# >>> Original set:
#     ['maastricht', 'utrecht', 'arnhem', 'haarlem', 'groninga', 'ámsterdam', 'róterdam']
#     ['auchonvillers', 'authuille', 'borghi', 'ullapool', 'raión', 'voivodato']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 164 of 436
# >>> Original set:
#     ['scrabble', 'shōgi', 'go', 'othello', 'hex']
#     ['jenga', 'damas', 'bingo']
# >>> In-vocabulary set:
#     ['go']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 165 of 436
# >>> Original set:
#     ['q.e.d.']
#     ['eurabia', 'sutherland', 'enlace']
# >>> In-vocabulary set:
#     []
#     ['enlace']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 166 of 436
# >>> Original set:
#     ['ealing', 'howth', 'cartago', 'cefisia', 'kibera']
#     ['bariano', 'ullapool', 'corvey']
# >>> In-vocabulary set:
#     ['cartago']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 167 of 436
# >>> Original set:
#     ['jquery', 'webkit', 'opengl', 'glibc', 'sdl', 'openssl']
#     ['depurador', 'coreldraw', 'ktorrent', 'ilife']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 168 of 436
# >>> Original set:
#     ['lld', 'magister', 'profesor', 'docente']
#     ['artek']
# >>> In-vocabulary set:
#     ['profesor', 'docente']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 169 of 436
# >>> Original set:
#     ['ciclista', 'ascetismo', 'pesca', 'dopaje', 'gastronomía', 'caza']
#     ['eduardiana', 'locura', 'imitar']
# >>> In-vocabulary set:
#     ['ciclista', 'pesca', 'gastronomía', 'caza']
#     ['locura']
# OP and OD list:
# [4]
# [1]
# >>> Test 170 of 436
# >>> Original set:
#     ['sochi', 'sarátov', 'kaliningrado', 'novosibirsk', 'volgogrado', 'podolsk', 'vladivostok', 'paltoga']
#     ['viterbo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 171 of 436
# >>> Original set:
#     ['mutualidad', 'aktiengesellschaft']
#     ['bloomberg', 'sukhoi']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 172 of 436
# >>> Original set:
#     ['jämtland', 'uppland', 'bohuslän', 'escania', 'småland', 'lappland', 'gotland', 'dalarna']
#     ['bitinia', 'raión', 'sarek']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 173 of 436
# >>> Original set:
#     ['ixtapaluca', 'apaxco', 'jaltenco', 'cozumel', 'tequixquiac', 'zumpango', 'ecatepec', 'naucalpan']
#     ['condados', 'i']
# >>> In-vocabulary set:
#     []
#     ['condados', 'i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 174 of 436
# >>> Original set:
#     ['km', 'pies', 'pársec', 'mi', 'ua', 'm', 'pulgada']
#     ['cent']
# >>> In-vocabulary set:
#     ['km', 'pies', 'mi', 'm']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 175 of 436
# >>> Original set:
#     ['outaouais', 'laval', 'montérégie', 'lanaudière']
#     ['göppingen']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 176 of 436
# >>> Original set:
#     ['rts', 'dr', 'tf1']
#     ['digestión', 'fotosíntesis']
# >>> In-vocabulary set:
#     ['dr']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 177 of 436
# >>> Original set:
#     ['karachi', 'londres', 'múnich', 'colonia', 'hyderabad', 'sídney', 'daca']
#     ['alhambra', 'goldendale', 'buellton', 'voivodato', 'departamento']
# >>> In-vocabulary set:
#     ['londres', 'múnich', 'colonia']
#     ['departamento']
# OP and OD list:
# [3]
# [1]
# >>> Test 178 of 436
# >>> Original set:
#     ['pogradec', 'korçë', 'gjirokastër', 'sarandë', 'krujë', 'fier', 'vlorë', 'kukës']
#     ['tropojë', 'kurbin', 'armiansk']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 179 of 436
# >>> Original set:
#     ['angus', 'fife', 'orcadas', 'edimburgo', 'glasgow', 'shetland', 'aberdeen']
#     ['powys', 'anglesey', 'sarek']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 180 of 436
# >>> Original set:
#     ['arcadia', 'ftiótide', 'mesenia', 'pieria', 'beocia', 'fócida', 'eubea', 'euritania']
#     ['veria', 'volos', 'venecia']
# >>> In-vocabulary set:
#     []
#     ['venecia']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 181 of 436
# >>> Original set:
#     ['bambi', 'dumbo', 'avatar']
#     ['rotoscopio', 'linograbado', 'hipérbole', 'electrostática']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 182 of 436
# >>> Original set:
#     ['fingolfin', 'fëanor', 'finwë', 'thranduil', 'galadriel', 'legolas', 'celeborn']
#     ['saruman', 'gandalf', 'zhengtong']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 183 of 436
# >>> Original set:
#     ['eindhoven', 'maastricht', 'utrecht', 'arnhem', 'zwolle', 'haarlem', 'leiden']
#     ['mixco', 'vianden']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 184 of 436
# >>> Original set:
#     ['gnome', 'cde', 'xfce', 'mate', 'gpe', 'cinnamon', 'lxde']
#     ['freedos', 'twitch', 'vod']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 185 of 436
# >>> Original set:
#     ['zarzuela', 'singspiel', 'opereta', 'intermezzo']
# ...
# >>> Original set:
#     ['berna', 'lugano', 'ginebra', 'winterthur', 'basilea', 'lausana', 'zúrich', 'lucerna']
#     ['vinuesa', 'mixco', 'grevenmacher', 'mersch']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 377 of 436
# >>> Original set:
#     ['danzig', 'bremen', 'colonia', 'lübeck', 'osnabrück', 'greifswald', 'rostock', 'stralsund']
#     ['potidea', 'corvey']
# >>> In-vocabulary set:
#     ['colonia']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 378 of 436
# >>> Original set:
#     ['discogs', 'omim', 'emedicine', 'wikidata', 'musicbrainz']
#     ['quora', 'demoarts', 'wxwidgets', 'iweb']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 379 of 436
# >>> Original set:
#     ['encke', 'quirón']
#     ['mcnaught']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 380 of 436
# >>> Original set:
#     ['madsen', 'dpm', 'bar', 'rpd', 'bren', 'rpk']
#     ['vickers', 'sgm', 'bombardas']
# >>> In-vocabulary set:
#     ['bar']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 381 of 436
# >>> Original set:
#     ['weststellingwerf', 'ferwerderadiel', 'smallingerland', 'ooststellingwerf', 'leeuwarderadeel', 'opsterland']
#     ['aljezur', 'raión', 'grevenmacher', 'vianden']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 382 of 436
# >>> Original set:
#     ['alemania', 'austria', 'eslovaquia', 'colombia', 'sudán', 'albania', 'serbia']
#     ['moresnet', 'plutocracia', 'viterbo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 383 of 436
# >>> Original set:
#     ['angus', 'fife', 'orcadas', 'clackmannanshire', 'glasgow', 'shetland']
#     ['clydebank', 'milán', 'alvesta']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 384 of 436
# >>> Original set:
#     ['tipografía', 'actor', 'blasón', 'origami']
#     ['gastronomía', 'lingüística', 'marina', 'autobusero']
# >>> In-vocabulary set:
#     ['actor']
#     ['lingüística', 'marina']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 385 of 436
# >>> Original set:
#     ['esternocleidomastoideo', 'miocardio', 'bíceps', 'deltoides', 'trapecio']
#     ['registán', 'letoon']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 386 of 436
# >>> Original set:
#     ['deutschlandlied', 'hatikva']
#     ['ligeia', 'olimpiadas', 'utc']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 387 of 436
# >>> Original set:
#     ['central']
#     ['kde']
# >>> In-vocabulary set:
#     ['central']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 388 of 436
# >>> Original set:
#     ['nápoles', 'milán', 'palermo', 'roma', 'siligo', 'turín', 'venecia', 'florencia']
#     ['middlebury', 'woodstock', 'somme', 'siilinjärvi', 'pornainen']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 389 of 436
# >>> Original set:
#     ['flcl']
#     ['rakugo', 'wikinoticias', 'wikipedia']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 390 of 436
# >>> Original set:
#     ['urumchi', 'kunming', 'nanchang', 'suzhou', 'lanzhou', 'zhengzhou', 'lhasa', 'changsha']
#     ['qiannan', 'minhang']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 391 of 436
# >>> Original set:
#     ['m39']
#     ['culebrina']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 392 of 436
# >>> Original set:
#     ['ruidoso', 'milan', 'tampico', 'maywood', 'lombard', 'wilmette', 'wellington']
#     ['dalfsen', 'borough', 'departamento']
# >>> In-vocabulary set:
#     []
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 393 of 436
# >>> Original set:
#     ['tromsø', 'drammen', 'trondheim', 'bergen', 'lillehammer', 'kristiansand', 'stavanger', 'narvik']
#     ['menabe']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 394 of 436
# >>> Original set:
#     ['suffolk', 'cumbria', 'northamptonshire', 'oxfordshire', 'berkshire', 'hertfordshire', 'surrey', 'norfolk']
#     ['tarn', 'herefordshire', 'northumberland']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 395 of 436
# >>> Original set:
#     ['shanksville', 'punxsutawney', 'indiana', 'gettysburg', 'doylestown', 'carlisle', 'centralia']
#     ['norristown', 'sanford', 'rota']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 396 of 436
# >>> Original set:
#     ['teaneck', 'wayne', 'montclair', 'edison', 'lakewood', 'wyckoff']
#     ['sayreville', 'sanford', 'departamento']
# >>> In-vocabulary set:
#     []
#     ['departamento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 397 of 436
# >>> Original set:
#     ['haibei', 'changji', 'ganzi', 'bayingolin', 'ngawa']
#     ['jixi', 'shannan', 'tangshan', 'yarkanda', 'minhang', 'songjiang']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 398 of 436
# >>> Original set:
#     ['tetris', 'minecraft', 'starcraft']
#     ['garageband', 'ilife', 'iphoto', 'ransomware', 'lucene']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 399 of 436
# >>> Original set:
#     ['broadway', 'whitehall']
#     ['bowery', 'gotardo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 400 of 436
# >>> Original set:
#     ['decán', 'tambora', 'teide', 'chimborazo', 'cotopaxi']
#     ['stack', 'bodega', 'vcd']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 401 of 436
# >>> Original set:
#     ['automoción', 'minería', 'shopping', 'horticultura', 'robótica', 'manufactura']
#     ['anime', 'sericicultura', 'tormenta']
# >>> In-vocabulary set:
#     ['minería']
#     ['anime', 'tormenta']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 402 of 436
# >>> Original set:
#     ['spandau', 'mitte', 'neukölln', 'pankow', 'lichtenberg']
#     ['wandsbek', 'harburg', 'zelenograd']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 403 of 436
# >>> Original set:
#     ['limburgo', 'henao', 'amberes']
#     ['somme', 'azawad']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 404 of 436
# >>> Original set:
#     ['blasfemia', 'fraude', 'secuestro', 'violencia', 'desertor', 'chantaje']
#     ['discriminación', 'dumping']
# >>> In-vocabulary set:
#     ['fraude', 'secuestro', 'violencia']
#     ['discriminación', 'dumping']
# OP and OD list:
# [1, 3]
# [0, 1]
# >>> Test 405 of 436
# >>> Original set:
#     ['bund', 'reeperbahn']
#     ['riel', 'tyrifjorden']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 406 of 436
# >>> Original set:
#     ['rar', 'pagerank', 'heurística']
#     ['portmanteau']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 407 of 436
# >>> Original set:
#     ['ido', 'novial', 'esperanto', 'volapük', 'lojban', 'interlingua', 'glosa']
#     ['solresol', 'occidental', 'erp', 'entendimiento']
# >>> In-vocabulary set:
#     ['ido']
#     ['occidental', 'entendimiento']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 408 of 436
# >>> Original set:
#     ['vesturland', 'suðurland', 'höfuðborgarsvæði', 'vestfirðir', 'austurland', 'suðurnes']
#     ['odder', 'lemvig', 'sacavém', 'quarteira', 'bangkok', 'condados']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 409 of 436
# >>> Original set:
#     ['mexica', 'elam', 'vándalos', 'olmeca']
#     ['élite', 'civilización', 'mitraísmo', 'teísmo', 'hunos', 'lisu']
# >>> In-vocabulary set:
#     []
#     ['civilización']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 410 of 436
# >>> Original set:
#     ['bangui', 'lobaye', 'ouham', 'ouaka']
#     ['venecia', 'viterbo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 411 of 436
# >>> Original set:
#     ['hidaka', 'iburi', 'tokachi', 'shiribeshi', 'okhotsk', 'sorachi', 'oshima']
#     ['condados', 'sava', 'i']
# >>> In-vocabulary set:
#     []
#     ['i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 412 of 436
# >>> Original set:
#     ['néguev', 'taklamakán', 'namib', 'sahara', 'kalahari']
#     ['highlands', 'umd']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 413 of 436
# >>> Original set:
#     ['worodougou', 'lagunes', 'marahoué', 'bafing', 'fromager']
#     ['menabe']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 414 of 436
# >>> Original set:
#     ['ganzourgou', 'boulgou', 'ziro', 'léraba', 'balé', 'bazéga', 'kadiogo', 'bam']
#     ['menabe', 'x']
# >>> In-vocabulary set:
#     []
#     ['x']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 415 of 436
# >>> Original set:
#     ['ópera', 'madrigal', 'contrapunto', 'sonata', 'fuga', 'cantata', 'oratorio', 'suite']
#     ['cariátide']
# >>> In-vocabulary set:
#     ['ópera', 'fuga']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 416 of 436
# >>> Original set:
#     ['graz', 'salzburgo', 'innsbruck', 'villach', 'linz', 'klagenfurt', 'eisenstadt']
#     ['sava']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 417 of 436
# >>> Original set:
#     ['viborg', 'fionia', 'storstrøm', 'roskilde', 'ribe']
#     ['qaasuitsup', 'qeqqata', 'et']
# >>> In-vocabulary set:
#     []
#     ['et']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 418 of 436
# >>> Original set:
#     ['acrux', 'alnitak', 'alamak', 'cástor', 'menkalinan', 'hadar']
#     ['m102', 'm82', 'sedna']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 419 of 436
# >>> Original set:
#     ['deutschland', 'blücher', 'seydlitz']
#     ['ballenero', 'shōkaku', 'uss']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 420 of 436
# >>> Original set:
#     ['monoclínico', 'cuasicristal', 'tetragonal', 'ortorrómbico', 'hexagonal']
#     ['subgrupo', 'habitante', 'francés']
# >>> In-vocabulary set:
#     []
#     ['francés']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 421 of 436
# >>> Original set:
#     ['java', 'smalltalk', 'lua', 'python', 'ruby', 'dart']
#     ['css', 'markdown', 'sql']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 422 of 436
# >>> Original set:
#     ['c', 'java', 'javascript', 'python', 'perl', 'pascal', 'sql']
#     ['rss', 'clamav', 'svg', 'jpeg']
# >>> In-vocabulary set:
#     ['c']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 423 of 436
# >>> Original set:
#     ['encarnación', 'luque', 'asunción', 'pilar', 'concepción']
#     ['menabe', 'i']
# >>> In-vocabulary set:
#     ['pilar', 'concepción']
#     ['i']
# OP and OD list:
# [2]
# [1]
# >>> Test 424 of 436
# >>> Original set:
#     ['judaísmo', 'cristianismo', 'jainismo', 'hinduismo', 'protestante', 'zoroastrismo', 'islam', 'sijismo']
#     ['hunos', 'escordiscos']
# >>> In-vocabulary set:
#     ['cristianismo']
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 425 of 436
# >>> Original set:
#     ['cyanogenmod', 'bada', 'symbian', 'maemo', 'ios', 'android']
#     ['ingress', 'instagram', 'ransomware', 'túnez', 'comentario']
# >>> In-vocabulary set:
#     []
#     ['comentario']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 426 of 436
# >>> Original set:
#     ['szczecin', 'danzig', 'łódź', 'breslavia', 'varsovia', 'poznań', 'cracovia', 'katowice']
#     ['bariano', 'ullapool']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 427 of 436
# >>> Original set:
#     ['ceuta', 'madha', 'najicheván', 'melilla', 'llivia']
#     ['malaui', 'níger', 'país']
# >>> In-vocabulary set:
#     []
#     ['país']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 428 of 436
# >>> Original set:
#     ['osona', 'barcelonés']
#     ['haukipudas', 'i', 'baabda']
# >>> In-vocabulary set:
#     []
#     ['i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 429 of 436
# >>> Original set:
#     ['hamilton', 'christchurch', 'invercargill', 'kaikoura', 'rotorua', 'tauranga', 'timaru', 'dunedin']
#     ['waikato', 'sirte', 'viterbo']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 430 of 436
# >>> Original set:
#     ['miedo', 'amor', 'envidia', 'ira', 'felicidad', 'odio', 'tristeza', 'esperanza']
#     ['adicción', 'revolución']
# >>> In-vocabulary set:
#     ['miedo', 'amor', 'felicidad', 'odio', 'esperanza']
#     ['revolución']
# OP and OD list:
# [5]
# [1]
# >>> Test 431 of 436
# >>> Original set:
#     ['kroppkaka', 'ostkaka', 'paella', 'kartoffelpuffer']
#     ['tailandia', 'indonesia', 'cataluña', 'yalebi', 'lokum']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 432 of 436
# >>> Original set:
#     ['cuñada', 'cuñado', 'nuera', 'suegro', 'yerno', 'suegra']
#     ['abuelo', 'abuela', 'teísmo']
# >>> In-vocabulary set:
#     []
#     ['abuelo', 'abuela']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 433 of 436
# >>> Original set:
#     ['hafnarfjörður', 'akureyri', 'reikiavik', 'vestmannaeyjar', 'garðabær', 'kópavogur', 'akranes', 'seltjarnarnes']
#     ['condados', 'i', 'armiansk']
# >>> In-vocabulary set:
#     []
#     ['i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 434 of 436
# >>> Original set:
#     ['anosy', 'menabe', 'vakinankaratra', 'analamanga', 'sava']
#     ['condados', 'sandgerði', 'i']
# >>> In-vocabulary set:
#     []
#     ['i']
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 435 of 436
# >>> Original set:
#     ['hobbit', 'elfos', 'enanos', 'balrog', 'ainur', 'valar', 'maia', 'ents']
#     ['predator', 'quirón']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Test 436 of 436
# >>> Original set:
#     ['weilburg', 'heimbach', 'eberstein', 'urach', 'nürburg', 'willingen']
#     ['weinböhla']
# >>> In-vocabulary set:
#     []
#     []
# Test set invalido, conjunto principal muy pequeño o conjunto outlier vacio
#
# >>> Resultados:
#     [['accuraccy', 0.7722222222222221], ['OPP', 0.6666666666666666], ['% main omited', 0.9295716639209226], ['% outlier omited', 0.8922305764411027], ['sets omited', 414]]

# %%
import ConstitucionUtil

# Evaluacion extrinseca
gob_concept_data, open_concept_with_gob_concept, open_concept_as_new_concept, open_concept_as_other, open_concept_nondescript = ConstitucionUtil.getDataset()
# Out:
# ['topic', 'is_open_concept', 'original_constitutional_concept', 'constitutional_concept', 'argument', 'argument_mode']
# complete data: 205357
# gob data: 183342
# 1, count: 37
# 2, count: 44
# 3, count: 12
# 4, count: 21
# cantidad conceptos: 114
#  1 Amistad cívica
#  1 Autonomía / Libertad
#  1 Bien Común / Comunidad
#  1 Ciudadanía
#  1 Democracia
#  1 Desarrollo
#  1 Descentralización
#  1 Dignidad
#  1 Diversidad
#  1 Emprendimiento libre
#  1 Equidad de género
#  1 Estado de Derecho
#  1 Estado laico
#  1 Identidad cultural
#  1 Igualdad
#  1 Inclusión
#  1 Innovación / Creatividad
#  1 Integración
#  1 Justicia
#  1 Multiculturalidad
#  1 Participación
#  1 Patriotismo
#  1 Paz / Convivencia pacífica
#  1 Pluralismo
#  1 Plurinacionalismo
#  1 Probidad
#  1 República
#  1 Respeto
#  1 Respeto / Conservación de la naturaleza o medio ambiente
#  1 Responsabilidad
#  1 Seguridad
#  1 Soberanía
#  1 Solidaridad
#  1 Subsidiaridad
#  1 Tolerancia
#  1 Transparencia y publicidad
#  1 Unidad
#  2 A huelga
#  2 A la educación
#  2 A la honra / Al honor
#  2 A la identidad cultural
#  2 A la información
#  2 A la integración de discapacidad
#  2 A la integridad física y psíquica
#  2 A la nacionalidad
#  2 A la participación
#  2 A la salud
#  2 A la seguridad / Vida sin violencia
#  2 A la seguridad social
#  2 A la vida
#  2 A la vivienda digna
#  2 A sindicalizarse y a la negociación colectiva
#  2 A sufragio / Votar
#  2 Acceso a información pública
#  2 Acceso a la cultura
#  2 Al salario equitativo
#  2 Al trabajo
#  2 De los pueblos indígenas
#  2 De petición ante las autoridades
#  2 De propiedad
#  2 Derecho de asociación
#  2 Derechos del niño, niña y adolecente
#  2 Igualdad
#  2 Igualdad ante la ley
#  2 Igualdad ante las cargas públicas
#  2 Igualdad ante los tributos
#  2 Igualdad de acceso a la justicia / Debido proceso
#  2 Igualdad de género
#  2 Libertad ambulatoria
#  2 Libertad de conciencia
#  2 Libertad de enseñanza
#  2 Libertad de expresión
#  2 Libertad de trabajo
#  2 Libertad personal
#  2 Libre iniciativa económica / Libre empresa
#  2 No discriminación
#  2 Privacidad e intimidad
#  2 Proteccion judicial de los derechos
#  2 Respeto a la naturaleza / Medio ambiente
#  2 Reunión pacífica
#  2 Ser elegido en cargos públicos
#  3 Cumplimiento de las leyes y normas
#  3 Cumplimiento de obligaciones fiscales
#  3 Cumplimiento de tratados y obligaciones internacionales
#  3 De protección y conservación de patrimonio histórico y cultural
#  3 De satisfacer cargas públicas
#  3 Deberes de protección de conservación de la naturaleza
#  3 Ejercicio legítimo y no abusivo de los derechos
#  3 Protección, promoción y respeto de los derechos humanos y fundamentales
#  3 Respeto de derechos de otros
#  3 Respeto por la constitución
#  3 Responsabilidad
#  3 Servicio a la comunidad
#  4 Cambio o reforma constitucional
#  4 Congreso o parlamento
#  4 Contraloría general / Tribunales de cuentas
#  4 Defensor del Pueblo / Ciudadano
#  4 División territorial
#  4 Estado de excepción
#  4 Forma de Estado
#  4 Fuerzas Armadas
#  4 Gobierno local / Municipal
#  4 Gobierno nacional (estructura y funciones)
#  4 Gobierno provincial
#  4 Gobierno regional
#  4 Jefatura de gobierno
#  4 Juicio político /acusación constitucional
#  4 Justicia constitucional
#  4 Justicia electoral
#  4 Ministerio Público / Defensoría Pública
#  4 Plebiscitos, referendos y consultas
#  4 Poder judicial (estructura y funciones)
#  4 Presidencia de la República
#  4 Régimen de gobierno presidencial /Semi-presidencial / Parlamentario
# open data: 22015
# cantidad conceptos: 171
# new concepts
#  1 Familia
#  1 Equidad
#  1 Otro
#  1 Estado garante
#  1 Libertad
#  1 Libertad de culto
#  1 Desarrollo sustentable
#  1 Inclasificable/No corresponde
#  1 Desarrollo integral
#  1 Derechos humanos
#  1 Democracia participativa
#  1 Libertad de conciencia
#  1 Familia basada en matrimonio heterosexual
#  1 Justicia social
#  1 Libertad de expresión
#  1 Seguridad Social
#  1 Propiedad Privada
#  1 Otros  Familia
#  2 Libertad de culto
#  2 Otro
#  2 A un trabajo y salario digno
#  2 A calidad de vida
#  2 Sociales
#  2 Inclasificable/No corresponde
#  2 Derechos Humanos
#  2 Derechos de los Animales
#  2 Al Agua
#  2 A la Libertad
#  2 A decidir sobre la propia vida
#  2 A la identidad cultural de los pueblos indígenas
#  2 Libertad de información y expresión
#  2 A una atención de salud pública de calidad
#  2 A respetar la vida desde la concepcion
#  2 A mantención del patrimonio histórico y cultural
#  3 De voto o sufragio
#  3 De Responsabilidad social y cívica
#  3 Otro
#  3 De Participación ciudadana o cívica
#  3 De probidad y transparencia
#  3 De Respeto y no discriminación
#  3 Inclasificable/No corresponde
#  3 De Unidad Nacional
#  3 De Protección y respeto a la propiedad privada
#  4 Otro
#  4 Congreso o Parlamento Unicameral
#  4 Asamblea Constituyente
#  4 Existencia de Tribunal Constitucional
#  4 Organizaciones de la sociedad civil
#  4 Iniciativa popular de Ley
#  4 Inclasificable/No corresponde
#  4 Autonomía Banco Central
#  4 Autonomía regional
#  4 Asambleas y Cabildos
#  4 Tribunal de Defensa de la Libre Competencia
#  4 Carabineros
#  4 Servicio Nacional de Asuntos Religiosos
#  4 Eliminacion de Tribunal Constitucional
# cant new concept: 57
# Conceptos presentes en los conceptos originales de gobierno
# 1, count: 37
#   Multiculturalidad 94
#     ['Interculturalidad', 'Convivencia en armonía, respetando la diversidad y la identidad cultural de todos los pueblos que viven en Chile, sin absorción de culturas hegemónicas.', 'policy']
#   Probidad 109
#     ['Honradez', 'En una sociedad sumamente individualista hay que pensar en el resto de la sociedad. Actualmente todos tratan de sacar sus beneficios personales, y no pensamos en el resto de la sociedad.', 'policy']
#   Bien Común / Comunidad 152
#     ['Bien Común/ Comunidad Solidaria', 'Asegurar el principio de bien común, relevando el sentido de comunidad, del pensar -en y con- el colectivo, amparados bajo el concepto de solidaridad, entendiéndola como que todas las personas deben colaborar en la medida de sus capacidades para asegurar el bienestar general de la sociedad.', 'policy']
#   Transparencia y publicidad 67
#     ['Transparencia', 'En un país con crisis de desconfianza, debido a la corrupción, no sabemos en quien confiar.  Debe asegurarse la transparencia en todos los niveles para recomponer confianzas.', 'policy']
#   Respeto 84
#     ['Respeto a la vida', 'Respeto la vida, desde la concepción hasta la muerte natural, como condición esencial del ser humano.', 'policy']
#   Participación 41
#     ['Participación Social', 'Democracia participativa con que el Estado busca activamente la participación de los ciudadanos y ciudadanas, estimulando además la educación cívica desde la infancia. Debe garantizar la aplicación de mecanismos participativos efectivos y vinculantes.', 'policy']
#   Justicia 58
#     ['JUSTICIA Y DERECHO', 'Igualdad o equilibrio ante la ley. Régimen político sometido a un sistema de leyes e instituciones ordenadas en torno de una Constitución, la cuál debe ser el fundamento jurídico de las autoridades y funcionarios, que se someten a las normas de ésta', 'policy']
#   Integración 13
#     ['Preferencia por las personas más Vulnerables', 'Foco del Estado en los más vulnerables  Discriminación positiva por los más vulnerables en políticas públicas y destino de los recursos del Estado  Preferencia por los más excluidos.', 'policy']
#   Responsabilidad 21
#     ['Responsabilidad Social', 'Hay que asumir los costos de los problemas sociales', 'policy']
#   Respeto / Conservación de la naturaleza o medio ambiente 221
#     ['NULL', 'La jerarquización de estos valores y principios fue con acuerdo unánime, y se basó en una lógica de prioridades: es decir, se identificó un primer valor sin el cual no sería posible articular el resto de los valores y principios, y así sucesivamente.', 'undefined']
#   Amistad cívica 103
#     ['Fraternidad', 'Expresión de los sentimientos de amor y cariño por el otro.', 'fact']
#   Solidaridad 84
#     ['Solidaridad/ fraternidad', 'Cooperación y hermandad entre los miembros de la sociedad, fomentándola entre los individuos.', 'policy']
#   Paz / Convivencia pacífica 27
#     ['Cultura de paz', 'Rechazamos toda agresión como instrumento de solución a todos los diferendos y conflictos, proponiendo la cooperación entre los pueblos.', 'policy']
#   Subsidiaridad 77
#     ['Estado al Servicio  del Hombre', 'El Estado debe estar al servicio del hombre. El Estado no puede pasar sobre nuestros derechos y libertades.', 'policy']
#   Plurinacionalismo 51
#     ['Estado Plurinacional y muticultural', 'Respeto a los pueblos originarios y a la diversidad', 'policy']
#   Estado laico 72
#     ['Estado Secular', 'Se requiere la independencia total del Estado de cualquier influencia o dogma religioso. Se hace la distinción entre "laicismo", que implica libertad de conciencia individual, y "secularismo", que se refiere a la garantía de autonomía del Estado referido al ámbito religioso.', 'policy']
#   Inclusión 43
#     ['Inclusión', 'Incluye las ideas de Solidaridad y desarrollo inclusivo.', 'policy']
#   Estado de Derecho 59
#     ['ESTADO DE DERECHO', 'Estado de Derecho como un Estado donde se respeta sin condiciones el Derecho vigente: "el derecho objetivo vigente y los derechos subjetivos que existan".   En ese sentido, es un Estado sin un soberano presente que pueda suspender el derecho a su voluntad. Estado de Derecho es condición, por tanto,de seguridad jurídica y mantenimiento del status quo', 'fact']
#   Equidad de género 60
#     ['Equidad de Genero', 'El Estado debe adoptar medidas especiales que aceleren la igualdad entre mujeres y hombres en todos los ámbitos de la vida.', 'policy']
#   Igualdad 132
#     ['Igualdad inclusiva y no-discriminación', 'Principio fundante. Somos iguales en derechos y dignidad. Para ejercerlos, el Estado debe dar los medios que necesite cada uno. Así, el Estado garantiza la no-discriminación, incluyendo la acción positiva, a todas las PcD, NNA, las mujeres, las personas indígenas, LGBTI, toda raza y religión, etc.', 'policy']
#   Identidad cultural 47
#     ['Reconocimiento pueblos originarios', 'Debe reconocerse la  existencia de pueblos originarios en el país  y acabar con las políticas de discriminación y segregación con ellos, apelando a una verdadera integración, pero reconociendo sus diferencias.', 'policy']
#   Descentralización 12
#     ['DESCENTRALIZACIÓN', 'El Estado se debe organizar en Gobiernos Locales con autonomía política, administrativa y económica.', 'policy']
#   Seguridad 25
#     ['Seguridad y justicia', 'No se puede andar tranquilo y no hay solución para la delincuencia. Debe ser para todos y no para quienes tienen más recursos. Hay una injusticia de parte de los candidatos políticos que solo nos visitan para pedir apoyo y luego no se preocupan más de los problemas de la AFC y las comunidades', 'policy']
#   Diversidad 44
#     ['Protección y Respeto a la Diversidad', 'Reconocer, respetar y proteger cualquier diferencia, sea étnica, de preferencia sexual, cultural u otra (no sólo se toleran).', 'fact']
#   Ciudadanía 14
#     ['PERTENENCIA', 'como valor diferenciador y generadora de identidad para las comunidades y vinculo a sus paisajes.', 'fact']
#   Tolerancia 18
#     ['tolerancia', 'debido a que sin ella no puede estar la libertad de expresión y se requiere para plantear de forma sana ideas y propuestas en cualquier contexto.', 'fact']
#   Soberanía 12
#     ['NULL', 'Es propia  del estado de derecho y unitario que tenemos, a pesar que hoy nos encontramos frente a un escenario distinto de estados globalizados.1) Hay diversos tipos de soberanía, nacional y popular, por ejemplo.  Soberanía nacional son las instituciones, soberanía popular son los ciudadanos.   Definir el tipo de soberanía define el tipo de Constitución que tendremos.  En estos momentos tenemos que la generación de  una ley es libertad de los legisladores, hacerla o no hacerla.  La soberanía popular, incorpora dentro de algunos mecanismos contempla la iniciativa legal popular, por ejemplo si juntas una cantidad determinada de firmas, puedes presentar un proyecto de ley  como ciudadano, hay otras manifestaciones en otras áreas, por ejemplo actualmente existe el mandato libre, los elegidos como representantes hacen lo que quieren y no piden la opinión a nadie, para ello existe un mecanismo que se denomina â€œReferendum Revocatorioâ€?, en donde si el político no cumple y se organiza una determinada cantidad de votantes, pueden revocar el mandato del político incumplidor.     2) Existe acuerdo sobre lo dicho, no obstante, la soberanía debe ser analizada en conjunto con otros valores, actualmente se dice  que la â€œsoberanía reside esencialmente en la naciónâ€?, el titular es la nación, es decir generaciones pasadas, presentes y futuras, lo que busca establecer un cierto límite a la voluntad del pueblo, porque la voluntad del pueblo sería más inmediata, pero no parce que el ejercicio de la soberanía en la nación sea la causa o el óbice de que tengamos una democracia representativa porque  justamente la misma constitución  que el ejercicio de esta soberanía que  reside en la nación se realiza por el pueblo y las instituciones, pero como el pueblo que también pertenece a la nación, es titular para ejercer la soberanía?, lo que debe considerarse vincular la soberanía con  otros principios, principalmente participación y justicia.  Porqué participación?, porque las iniciativas ciuda', 'policy']
#   Dignidad 63
#     ['Dignidad  con paz convivencia', 'La dignidad individual y colectiva como base de la convivencia.', 'policy']
#   Autonomía / Libertad 68
#     ['Libertad/Autonomía', 'Las personas libres y autónomas son la base de la sociedad. La autonomía se vincula con el carácter único de las personas y su potencialidad para decidir sobre su proyecto de vida e identidad. También refiere a la autodeterminación de los pueblos originarios la posibilidad de organizarse en el marco del respeto de los derechos humanos.', 'fact']
#   República 15
#     ['Alternancia en los cargos de elección popular', 'Los cargos de elección popular debieran tener una limitación a la reelección para evitar la corrupción  y el desapego con la población lo que produce una baja participación.', 'policy']
#   Unidad 18
#     ['Unidad Igualdad- Transparencia- Inclusión', '1. Solidarizar con las Necesidades propias del concepto persona. 2. Distribución Equitativa del Producto Económico Nacional (Empleos – Sueldos- Otros) 3. Considerar a toda persona como única sin distingo a sus individualidades.', 'policy']
#   Desarrollo 11
#     ['Progresividad', 'El Estado debe generar en cada momento una mejor protección y garantía de los derechos humanos, de forma que siempre estén sujetos a evolución y mejoramiento.', 'policy']
#   Innovación / Creatividad 25
#     ['Innovación/creatividad', 'Valores como motores de desarrollo y evolución en un mundo en constante cambio, generando investigación y reflexiones que cultiven nuestra identidad común', 'undefined']
#   Democracia 7
#     ['Democracia', 'Forma de cómo se llega al poder y se rinde cuentas', 'value']
#   Pluralismo 8
#     ['PLURALISMO Y MULTICULTURALIDAD', 'Consideración, respeto y reconocimiento de todas las ideas, religiones, lenguas y culturas que se presentan en el territorio nacional', 'policy']
#   Emprendimiento libre 7
#     ['Emprendimiento Libre', 'Es un motor activo de las sociedades, especialmente si se toma en consideración el sólido impacto en las comunidades', 'fact']
#   Patriotismo 2
#     ['Patriotismo', 'Sentimiento de nación de todos los ciudadanos.', 'fact']
# 2, count: 44
#   A sindicalizarse y a la negociación colectiva 74
#     ['NULL', '.', 'blank']
#   Igualdad 162
#     ['Derecho a la igualdad y no discriminación', 'Se propone también juntar los dos derechos, Derecho a la igualdad y no discriminación: que incluiría los votados igualdad de género e igualdad ante los tributos y demás vertientes de la igualdad. Se considera fundamental además consagrar expresamente la no discriminación,', 'policy']
#   Igualdad de género 61
#     ['Igualdad de genero y diversidad sexual', 'Derecho fundamental para la sociedad.', 'fact']
#   A la seguridad social 317
#     ['jubilacion digna', 'el estado debe tener un sistema para administrar los recursos  que el sistema garantice un sueldo que permita vivir dignamente', 'policy']
#   Respeto a la naturaleza / Medio ambiente 346
#     ['A vivir en ambiente libre de contaminación', 'El Estado tiene el deber de garantizar el acceso a un medio ambiente libre de contaminación: aire limpio, aguas descontaminadas, alimentos libre de contaminación (pescados, mariscos, vegetales) y un ambiente sin contaminación acústica.', 'policy']
#   A la vida 78
#     ['Existencia y vida', 'DERECHO A LA EXISTENCIA DEL NONATO. SEGURIDAD Y PROTECCION DE LA MADRE. INVOLUCRA UN MEDIO AMBIENTE ADECUADO, SEGURIDAD, EDUCACION', 'fact']
#   A la educación 374
#     ['Educación de calidad', 'Debe ser pilar de la sociedad.  La educación de calidad ayuda a disminuir otras desigualdades.  Es necesaria una mirada a largo plazo y pensar el país que queremos para responder: ¿Educarnos para qué?', 'policy']
#   Libertad de conciencia 86
#     ['Objeción de Conciencia', 'creemos en los valores morales, en convicciones interiores o religiosas, es de suma importancia su consagración actualmente no está explícito en nuestra constitución.', 'policy']
#   A la información 74
#     ['A la Información', 'A la Información: acceso a la información pública real por parte del estado , para que los ciudadanos se puedan desenvolver con conocimiento y autonomía.', 'policy']
#   Libre iniciativa económica / Libre empresa 18
#     ['Libre y equitativa competencia económica', 'Promover la libre empresa pero de manera regularizada', 'policy']
#   Libertad de trabajo 11
#     ['Libertad de trabajo y emprendimiento', 'El Estado  no puede coartar o limitar esta libertad salvo por razones de orden público muy acotadas y justificadas.', 'policy']
#   A la seguridad / Vida sin violencia 119
#     ['A la Seguridad', 'Destacamos la importancia de vivir en un país seguro con protección ante la delincuencia y manteniendo la paz como valor fundamental.', 'fact']
#   Al trabajo 31
#     ['al trabajo y seguridad social', 'garantizar el acceso al trabajo y por consiguiente el deber del estado de desarrollar la seguridad social, materializar jubilaciones dignas, calidad de un ambiente laboral, sueldos dignos, entre otros.', 'policy']
#   Proteccion judicial de los derechos 17
#     ['A la protección judicial de los derechos', 'Asegurar constitucionalmente la protección judicial efectiva de todos los derechos de las personas tanto individual como colectivamente.', 'policy']
#   A la participación 207
#     ['A la participación vinculante', 'Todas las ciudadanas y ciudadanos deben tener derecho a emitir su opinión sin estar sujeto a la opinión de nadie.  La opinión de las mayorías debe ser vinculante para el sistema de tal manera que las mayorías con su participación gobiernen a través de sus representantes con mandatos democráticos.', 'policy']
#   Acceso a la cultura 58
#     ['Derecho de Acceso a la Cultura', 'El estado debe asegurar a través de sus polítcas que la cultura es parte de los derechos de las personas de todo segmento social y económico, asegurando con ello, la formación de un bagaje cultural propio, basado en la identidad cultural que debenmos tener como sociedad chilena.', 'policy']
#   De propiedad 48
#     ['NULL', '.', 'blank']
#   A la vivienda digna 86
#     ['a vivienda', '-derecho a un lugar digno donde vivir, independiente de la situación económica del sujeto.', 'policy']
#   A la salud 89
#     ['Salud, Educación y Vivienda Digna', 'Que sean dignas, oportunas, resolutivas, universales, de excelencia y calidad; para todos los ciudadanos chilenos.', 'policy']
#   A la integridad física y psíquica 121
#     ['NULL', '.', 'blank']
#   No discriminación 149
#     ['Identidad de género', 'El Estado debe resguardar la igualdad de derechos en todos los ámbitos, entre todos los sujetos, sea cual sea la percepción subjetiva que un individuo tiene sobre sí mismo en cuanto a sentirse hombre, mujer, o de un género no binario (sin considerar características físicas o biológicas).', 'policy']
#   Al salario equitativo 41
#     ['Salario equitativo', 'reducir las brechas en los salarios para disminuir desigualdad social para tener acceso a salud, vivienda, educación, etc.', 'policy']
#   A sufragio / Votar 22
#     ['Al sufragio y la participación', 'Derecho a votar sin discriminación. Mayor uso de los plebiscitos en decisiones sociales y de otras instancias de participación ciudadana.', 'policy']
#   A la identidad cultural 46
#     ['Identidad cultural', 'El estado debe asegurar el derecho cultural, identidad cultural e integración de los pueblos indígenas.', 'policy']
#   Ser elegido en cargos públicos 34
#     ['NULL', 'Para promover pensamientos e ideas del pueblo evangélico al país.', 'value']
#   A la integración de discapacidad 28
#     ['NULL', '.', 'blank']
#   Libertad de expresión 60
#     ['libertad de expresión', 'todos tiene derecho a dar su opinión.', 'fact']
#   Privacidad e intimidad 22
#     ['Derecho a la privacidad', 'Nº 5 Este grupo agrega este Derecho, ya que hoy en dìa somos vulnerados en multiples aspectos de la vida diaria, perdiendo incluso el derecho a nuestra privacidad.', 'blank']
#   Igualdad de acceso a la justicia / Debido proceso 101
#     ['Debido proceso y juicio justo', 'Debido proceso y juicio justo', 'policy']
#   A la honra / Al honor 37
#     ['a la dignidad', 'Derecho a una vida digna y a una muerte digna. Concepto de dignidad es difícil de definir, por eso el acuerdo parcial.', 'policy']
#   Igualdad ante la ley 56
#     ['Justicia', '• Como fin fundamental y prioritario del derecho, que se supedite a los principios jurídicos, de seguridad y bien común. Dar a cada cual lo que le corresponde. Distributiva y conmutativa.', 'policy']
#   Derechos del niño, niña y adolecente 68
#     ['Derechos del Niño, Adolescente y Adultos Mayores', 'No existen derechos para estos grupos sobretodo para el Adulto Mayor', 'fact']
#   Acceso a información pública 41
#     ['Derecho al acceso y ejercicio de la información estatal, privada y pública', 'Además del acceso a la información estatal, se debe garantizar el derecho del ejercicio de la comunicación e información privada y comunitaria, independientemente de quién la ejerza.', 'policy']
#   Libertad de enseñanza 61
#     ['Libertad de enseñanza', 'Libertad de elegir como educar a los hijos.', 'policy']
#   De los pueblos indígenas 42
#     ['A la Autonomía de los Pueblos Indígenas, Reconocimiento y Reparación', 'Los pueblos indígenas deben ser  reconocidos como Naciones, con derechos como tales. Lograr esto sería un gran avance para nuestro país, tanto en su florecimiento productivo como en su convivencia pacífica.', 'policy']
#   A huelga 13
#     ['HUELGA REAL', 'Los trabajadores debemos tener acceso a una huelga real y efectiva, porque es un derecho humano y debe consagrarse como tal en nuestra carta fundamental.', 'policy']
#   Libertad personal 61
#     ['Libertad Personal', 'La libertad personas debe regularse para asegurar un ejercicio equilibrado de ésta.', 'policy']
#   Derecho de asociación 31
#     ['Derecho a la Asociación y Sindicalización', 'mejoramiento de condiciones laborales y fortalecer las relaciones comunitarias y sociales que aborden temas de interés colectivo.', 'policy']
#   Igualdad ante las cargas públicas 3
#     ['DEBER DE SOPORTAR LAS CARGAS PÚBLICAS EN LA MEDIDA DE LAS CAPACIDADES INDIVIDUALES', 'Responsabilidad ante la comunidad y el bien social, trato igualitario por parte del Estado en reconocimiento de capacidad económica.', 'policy']
#   Igualdad ante los tributos 30
#     ['Equidad ante los tributos/salario', 'Para salvaguardar la equidad en torno al cumplimiento de obligaciones fiscales que considere el salario de cada ciudadano de manera justa, y proporcional a su actividad productiva, ingresos y salidas de dinero, y jornadas de trabajo.', 'policy']
#   Libertad ambulatoria 13
#     ['Inmigracion', 'Creemos que deberíamos tener una ley de migración en Chile, ya que esta no esta estipulada en la constitución', 'policy']
#   A la nacionalidad 5
#     ['A pertenecer a la nación', 'Que se garanticen los derechos a cualquier individuo que solicite nacionalidad.', 'policy']
#   De petición ante las autoridades 7
#     ['Derecho a la iniciativa ciudadana en proyectos de ley', 'Asegurar el derecho constitucional a la presentación de iniciativas de ley, tanto individual como colectivamente.', 'policy']
#   Reunión pacífica 8
#     ['libertad de reunion', 'ha no ser discriminados por agruparse, ni menos cabados.', 'policy']
# 3, count: 12
#   Cumplimiento de obligaciones fiscales 102
#     ['Deber de pagar los impuestos', 'Es la base para asegurar derechos básicos como educación, salud y protección social para todos', 'fact']
#   Cumplimiento de las leyes y normas 94
#     ['Respeto a las leyes y normas', 'Que las leyes sean adecuadas a los tiempos y que se respeten.', 'policy']
#   Responsabilidad 310
#     ['responsabilidad social', 'responsabilizarnos del entorno social que nos convoca y promover la integración.', 'policy']
#   Deberes de protección de conservación de la naturaleza 442
#     ['Promoción y protección de conservación de la naturaleza y recursos naturales', 'Trabajo constante y efectivo para cuidar la naturaleza y usar responsablemente y con criterio los recursos naturales.', 'policy']
#   Servicio a la comunidad 249
#     ['NULL', '.', 'blank']
#   De satisfacer cargas públicas 28
#     ['Subordinación de las Fuerzas Armadas al poder civil', 'Nunca más las Fuerzas Armadas pueden tomar el control de la población civil. Se debe explicitar y contemplar castigos ejemplares para potenciales quiebres.', 'policy']
#   Ejercicio legítimo y no abusivo de los derechos 92
#     ['Ejercicio responsable de derechos', 'Deber y responsabilidad de no abusar de la práctica  y espíritu de los distintos derechos que los ciudadanos  poseemos.', 'policy']
#   De protección y conservación de patrimonio histórico y cultural 245
#     ['Conservación y Protección del Patrimonio Histórico y Cultural', 'Cada ciudadano de nuestro País debe sentirse responsable de proteger  y Conservar el patrimonio histórico y cultural de nuestra nación.', 'policy']
#   Protección, promoción y respeto de los derechos humanos y fundamentales 191
#     ['NULL', 'Creemos que el Estado debe hacer públicos los derechos fundamentales, y educar a los miembros de la sociedad sobre la existencia y mecanismos de protección de estos derechos.', 'policy']
#   Cumplimiento de tratados y obligaciones internacionales 52
#     ['controlar el ingreso de inmigrantes al país', 'se hace sumamente importante poder incorporar este asunto, debido al gran número de inmigrares , bajan mano de obra en nuestro país', 'policy']
#   Respeto de derechos de otros 3
#     ['Respeto de derechos de otros', 'En la decisión de convivir sanamente, el respeto es un deber fundamental', 'fact']
#   Respeto por la constitución 12
#     ['respeto por la constitución', 'ley fundamental que define el régimen de los derecho y libertades de los ciudadanos y delimita los poderes e instituciones', 'fact']
# 4, count: 21
#   Fuerzas Armadas 248
#     ['DEMOCRATIZACION DE LAS FFAA', 'UNANIMIDAD. 14 ACUERDOS. ESCALAFON UNICO. ASENCION MERITORIA. FIN DE LA DOCTRINA DE SEGURIDAD INTERIOR DEL ESTADO Y ENEMIGO INTERNO Y NO ENVIO A ESCUELA DE LAS AMERICAS. PREEMINENCIA DEL PARLAMENTO Y LA LEY SOBRE LAS ORDENES SUPERIORES. FIN A LA INSTITUCION DE LOS CAPELLANES (ESTADO LAICO).', 'policy']
#   Gobierno local / Municipal 102
#     ['Gobiernos locales', 'Autonimía - Transparencia- Elección Popular', 'policy']
#   Gobierno nacional (estructura y funciones) 1100
#     ['CORFO', 'Promoción de emprendimientos privados con carácter estatal y nacional.', 'policy']
#   Plebiscitos, referendos y consultas 223
#     ['Democracia participativa', 'Instauración de plebiscitos, consultas, iniciativa popular de ley, mandato revocatorio, todos vinculantes.', 'policy']
#   Justicia electoral 70
#     ['Justicia electoral, tricel y servel', 'Además de mantener estos organismos fiscalizadores, proponemos reelección limitada de los cargos de elección popular', 'policy']
#   Cambio o reforma constitucional 112
#     ['Una Nueva Constitución', '- ESTAMOS EN PLENO ACUERDO CON LA NECESIDAD DE HACER UNA NUEVA CONSTITUCIÓN QUE NOS REPRENTE A TODOS.  - QUE SEA PARTICIPATIVA E INTEGRADORA.  - QUE RECONOZCA E INCORPORE LOS CAMBIOS QUE HA EXPERIMENTADO EL PAÍS.', 'policy']
#   Forma de Estado 262
#     ['Estado Autonomía Regional', 'Co-gobierno Regional, Intendente elegido por Presidente y CORES fortalecidos, elegidos por la Región, para desarrollo sustentable.', 'policy']
#   Presidencia de la República 24
#     ['Reelección presidencial', 'En 4 años no se logra cumplir con las políticas de gobierno.', 'fact']
#   Congreso o parlamento 134
#     ['Parlamento', 'Instancia donde se discutan los temas y no solo se vote.', 'policy']
#   Régimen de gobierno presidencial /Semi-presidencial / Parlamentario 215
#     ['Regimen de gobierno presidencial', 'LOS PERÍODOS PRESIDENCIALES HOY SON DEMASIADO CORTOS. SE PROPONEN PERÍODOS DE 4 AÑOS CON REELECCIÓN', 'policy']
#   División territorial 38
#     ['División territorial decentralizada territorial y funcionalmente.', 'La realidad geográfica se contrapone con el modelo unitario existente.  Igualdad con las regiones.', 'fact']
#   Contraloría general / Tribunales de cuentas 103
#     ['Fiscalía de la Gestión Pública', 'Crear esta entidad técnica para controlar el aprovechamiento de los recursos económicos, humanos y técnicos  existentes en el aparato estatal.', 'value']
#   Juicio político /acusación constitucional 113
#     ['Mandato revocable', 'Las autoridades actuan en representación de la sociedad civil, por lo que deben representar los intereses legítimos de la ciudadanía.', 'policy']
#   Justicia constitucional 34
#     ['Justiticia constitucional y electoral', 'Conformación de un órgano que imparta justicia y garantice los procesos constitucionales y electorales oficiales del país.', 'policy']
#   Defensor del Pueblo / Ciudadano 85
#     ['Defensor del pueblo', 'que se contemple la defensoria de los derechos humanos y políticos de parte del Estado.', 'policy']
#   Ministerio Público / Defensoría Pública 69
#     ['Fiscalización', 'Es necesario fiscalizar a los parlamentarios, pero no del mismo conglomerado sino de otras entidades externas.', 'policy']
#   Gobierno regional 4
#     ['Gobierno Regional', 'Necesitan más autonomía, para lograr resolver de mejor forma de resolver sus problemas.', 'value']
#   Poder judicial (estructura y funciones) 124
#     ['Una sola Justicia para Todas/os.', 'Constitucionalmente nuestro Estado de derecho debe garantizar una sola justicia para todas/os las/os ciudadanos sin distinción de clases sociales o pertenencia a una determinada Institución.', 'policy']
#   Estado de excepción 15
#     ['Estados de Excepción constitucional', 'Es necesario que se traten.', 'fact']
#   Jefatura de gobierno 1
#     ['NULL', '.', 'blank']
#   Gobierno provincial 8
#     ['gobernacion', 'que cada una de las instituciones  deben ser  neutral, imparcial, deben trabajar por el bien común.', 'policy']
# total: 10224
#
#
# Nuevos conceptos
# 1, count: 16
#   Familia 262
#     ['LA FAMILIA', 'La familia es el núcleo oficial y fundamental de la sociedad y el Estado debe resguardar su autonomía, así como la de las demás formas de asociación de las personas, siempre que estas sean entre un hombre y una mujer. El Estado debe reconocer y apoyar el esfuerzo de las familias en la crianza y educación de los hijos. Nuestros hijos son el futuro del país y el desarrollo poblacional es importante para sustentar el Chile del futuro.  - Se debe dejar establecido que el rol de los padres lo define, tanto el hombre en su función de padre como la mujer en su papel de madre. Esto se valida en el tratado internacional de DDHH, en su artículo 17, incisos 1° y 2°  - La adopción es el derecho del niño a tener una familia conforme a la definición en el punto de los valores.', 'policy']
#   Equidad 319
#     ['EQUIDAD', 'es distinto a la igualdad, la equidad tiene que ver con colocar los peldaños  necesarios a quien no los tiene, para formar un tipo de piso de justicia social.', 'fact']
#   Estado garante 87
#     ['estado garante, no subsdiario', 'El estado debe asumir la responsabilidad de garantizar las necesidades básicas de la ciudadanía (educación, salud y seguridad social) a través de políticas públicas no subsidiarias.', 'policy']
#   Libertad 318
#     ['Libertad', 'Un valor inalienable de cada ciudadano, que va de la mano con el respeto a la legislación nacional y al derecho de cada compatriota.', 'fact']
#   Libertad de culto 131
#     ['NULL', 'Por ser leyes establecidas por Dios que impulsan a una buena sociedad', 'policy']
#   Desarrollo sustentable 189
#     ['sustentabilidad', 'tomar conciencia del entorno en que vivimos ofreciendo politicas publicas acorde al actual contexto social.', 'policy']
#   Desarrollo integral 77
#     ['Felicidad', 'Queremos una constitución que valore y promueva la felicidad de las personas, su desarrollo y plenitud', 'policy']
#   Derechos humanos 90
#     ['Respeto a los derechos humanos', 'Democracia participativa con rendición de cuentas/ estado de derecho/ garantía a los derechos humanos. 1, 2 y 3 generación/ genero/ medio ambiente y conservación de la naturaleza./ respeto a la multiculturalidad .', 'policy']
#   Democracia participativa 154
#     ['Democracia participativa', 'La participación activa y vinculante de los ciudadanos en todas las instancias institucionales es clave para alcanzar una democracia plena y justa. Para ello el Estado debe brindar todas las condiciones, recursos e infraestructura necesarias para lograr que el pueblo incida en la toma de decisiones', 'policy']
#   Libertad de conciencia 21
#     ['Libertad de conciencia, expresión y religión', 'No reconocer tales principios es negar la capacidad y facultad que tiene el hombre para decidir.', 'policy']
#   Familia basada en matrimonio heterosexual 55
#     ['Familia Heterosexual.', 'Principal pilar de la sociedad.Basada en lo que Dios dejó establecido.', 'fact']
#   Justicia social 110
#     ['equidad social', 'El estado debería proporcionar herramientas para que los individuos Chilenos se encuentren dentro de un mismo margen y no existan diferencias.', 'policy']
#   Libertad de expresión 18
#     ['libertad de expresion', 'Con responsabilidad de medios masivos', 'policy']
#   Seguridad Social 11
#     ['seguridad social', 'Decidimos agregar la palabra "social", pues seguridad es la ausencia de riesgos y no sólo se debe privilegiar una seguridad ciudadana, sino social en el sentido de un Estado que garantice el goce de prestaciones básicas de una sociedad.', 'policy']
#   Propiedad Privada 8
#     ['Propiedad privada', 'Que se respete la propiedad privada, la inviolabilidad del hogar, etc.', 'policy']
#   Otros  Familia 3
#     ['Valores del hogar', 'fomentar los valores que se imparte en la familia, ya que es la “primera escuela”.', 'policy']
# 2, count: 14
#   Libertad de culto 185
#     ['NULL', 'Para resguardar los intereses patrimoniales de la Iglesia Evangélica, su idiosincrasia y además el bienestar pastoral.', 'value']
#   A un trabajo y salario digno 199
#     ['Al Trabajo y Salario Digno', 'Mejores condiciones laborales y remuneraciones acorde al trabajo', 'policy']
#   A calidad de vida 360
#     ['A las necesidades básicas del ser humano', 'Considerando como necesidades básicas la alimentación, salud y vivienda.', 'fact']
#   Sociales 475
#     ['derechos sociales', 'Nueva constitución debe garantizar por parte del Estado los derechos sociales básicos y fundamentales como un todo: salud, educación, vivienda digna y no disgregados.', 'policy']
#   Derechos Humanos 181
#     ['Protección Judicial de los Derechos y Derechos Humanos', 'Ejercicio legitimo y no abusivo de los derechos, protección judicial de los derechos humanos.', 'policy']
#   Derechos de los Animales 41
#     ['Derechos de los animales', 'Reconocemos su valor intrínseco como seres sintientes, cuyos intereses deben ser respetados y también su dignidad. El Estado debe garantizar su protección y bienestar en su calidad de seres vivos dotados de sensibilidad. El estado ha de establecer normas para el resguardo y protección de los animal', 'policy']
#   Al Agua 121
#     ['Al agua y al aire', 'Actualmente el agua es considerado como un bien privado. Al ser el agua y el aire elementos básicos de la naturaleza que permitan la vida, éstos deben considerarse como parte de los derechos.', 'policy']
#   A la Libertad 147
#     ['Libertad', 'en su amplio sentido', 'policy']
#   A decidir sobre la propia vida 222
#     ['NULL', 'No alcanzamos a definir el fundamento.', 'blank']
#   A la identidad cultural de los pueblos indígenas 15
#     ['Identidad cultural de los pueblos indigenas', 'Tenemos el derecho a ejercer nuestra cultura desde el nacimiento libremente.', 'fact']
#   Libertad de información y expresión 55
#     ['A la Información y a la Libertad de Expresión', 'Chile es uno de los países menos informados.  Sobre el 90% de los medios pertenece a un par de consorcios, los cuales entregan digerida y comentadas las noticias. El Estado debe apoyar al periodismo independiente, única forma de fortalecer la democracia informativa.', 'policy']
#   A una atención de salud pública de calidad 147
#     ['A salud pública y digna', 'Debe aumentar el porcentaje de aporte que entrega el estado con respecto a la salud ya que es necesario controlar y diagnosticar a tiempo las patologías que presentan los ciudadanos.', 'policy']
#   A respetar la vida desde la concepcion 26
#     ['NULL', '.', 'blank']
#   A mantención del patrimonio histórico y cultural 9
#     ['Protección del Patrimonio', 'Acceso a la cultura. El patrimonio somos todos nosotros nuestras personas, nuestras comunidades, nuestra cultura, nuestras costumbres, nuestro léxico, nuestra comida, etc. Es tanto lo material como inmaterial. Por eso, el estado debe garantizar la protección del patrimonio.', 'policy']
# 3, count: 7
#   De voto o sufragio 614
#     ['Sufragio', 'Se considera deber dentro de una cultura civica, porque todos debemos plasmar nuestra opinion por alguien para una eleccion', 'policy']
#   De Responsabilidad social y cívica 603
#     ['Cultura Cívica', 'Se debe incluir en el curriculum escolar, desde la educación básica para todos los ciudadanos.', 'policy']
#   De Participación ciudadana o cívica 460
#     ['Participar en el ámbito público', 'Toda persona tendrá el derecho y el deber de participar en la elaboración de soluciones para aquellos problemas que nos conciernen a todos y todas.', 'policy']
#   De probidad y transparencia 287
#     ['TRANSPARENCIA Y PROBIDAD', 'LAS AUTORIDADES DEBEN SER HONESTOS EN SU ACTUAR', 'policy']
#   De Respeto y no discriminación 108
#     ['Respeto', 'Constitución  A las leyes  A escuchar  A los otros', 'undefined']
#   De Unidad Nacional 76
#     ['Unidad', 'Buen trato del estado a las instituciones y organizaciones.', 'policy']
#   De Protección y respeto a la propiedad privada 46
#     ['Proteccion y respeto a la propiedad privada', 'Finalmente a nuestro juicio, respetar la propiedad privada es fundamental para la conservación de la seguridad, paz y buena convivencia ciudadana.', 'value']
# 4, count: 12
#   Congreso o Parlamento Unicameral 291
#     ['Congreso unicameral', 'Institución principal, creadora, reguladora, propositiva,  de las leyes y normas que harán operativa esta nueva constitución. Con la característica de ser UNA sola cámara, que concentre la representación de la ciudadanía.', 'fact']
#   Asamblea Constituyente 757
#     ['ASAMBLEA CONSTITUYENTE', 'LA INSTITUCION COMPUESTA POR CIUDADANOS, ELEGIDA POR  LA MISMA CIUDADANIA, REDACTA UNA NUEVA CONSTITUCION  Y SE VALIDA POR UN PLEBISCITO.', 'fact']
#   Existencia de Tribunal Constitucional 289
#     ['TRIBUNAL CONSTITUCIONAL', 'CUMPLE UNA IMPORTANTE FUNCION VIGILANDO QUE LAS LEYES QUE SE ESTAN ESTUDIANDO EN EL PARLAMENTO NO VAYAN EN CONTRA DE LA CONSTITUCION', 'fact']
#   Organizaciones de la sociedad civil 349
#     ['Consejo económico, social y de medio ambiente', 'Órgano público donde confluye el Estado la sociedad civil organizada y el sector privado que vela y propone políticas que garanticen un medio ambiente sustentable y un desarrollo que ponga en el centro a las personas.', 'policy']
#   Iniciativa popular de Ley 190
#     ['Iniciativa popular de leyes', 'Grupo de ciudadanos que se reúna  para tomar decisiones en relación a leyes', 'fact']
#   Autonomía Banco Central 199
#     ['Banco Central', 'Debe estar claramente establecido en la Constitución su autonomía, independiente del gobierno de turno', 'policy']
#   Autonomía regional 105
#     ['Fortalecimiento de las regiones', 'En tres aspectos: a. Elección democrática de Intendentes y COREs, b. Autonomía financiera, y c. Mayores atribuciones.', 'policy']
#   Asambleas y Cabildos 187
#     ['Parlamento popular y no aristócrata', '- Sueldos acordes a lo que ganan los trabajadores del país.', 'policy']
#   Tribunal de Defensa de la Libre Competencia 65
#     ['NULL', 'Darle rango constitucional. Sin competencia no hay una verdadera economía de mercado. Los oligopolios dañan el emprendimiento y la economía', 'fact']
#   Carabineros 70
#     ['Carabineros', 'Mayor vigilancia preventiva en la comunidad.', 'policy']
#   Servicio Nacional de Asuntos Religiosos 21
#     ['Iglesia', 'Porque es una institución con bases espirituales, morales y valóricas que rigen la convivencia humana.', 'fact']
#   Eliminacion de Tribunal Constitucional 37
#     ['Abolir tribunal constitucional', 'contradice la democracia pues, puede vetar lo que legisla el congreso,es decir la voluntad popular.', 'fact']
# total: 8790
#
#
# Conceptos clasificados como otros
# 1, count: 1
#   Otro 442
#     ['Participación ciudadana vinculante y democratica', 'En nuestra sociedad actual hay una crisis en representación , para reencantar a la comunidad es vital  la participación de la misma y estas opiniones deben incidir directamente en el futuro de nuestro país. Las decisiones se deben acercar a la gente de forma descentralizada', 'policy']
# 2, count: 1
#   Otro 505
#     ['voto obligatorio', 'la nueva constitución debe incluir la obligatoriedad del voto, pues es un DEBER.', 'policy']
# 3, count: 1
#   Otro 58
#     ['deber de ser eficiente', 'para optimizar nuestro tiempo y recuso así ir avanzando con futuros proyectos', 'policy']
# 4, count: 1
#   Otro 530
#     ['Estado de derechos', 'Un estado democrático que garantice el derecho y el cumplimiento de estos mismos para todos los ciudadanos de vivir en una sociedad armónica.', 'policy']
# total: 1535
#
#
# Conceptos inclasificables o que no corresponden
# 1, count: 1
#   Inclasificable/No corresponde 366
#     ['Educación de calidad como bien social', 'Que la educación no sea más considerada como un bien de consumo, sino como un bien social, cuya calidad no dependa de los recursos económicos de las familias.', 'policy']
# 2, count: 1
#   Inclasificable/No corresponde 129
#     ['Estado Laico', 'Independiente de credos religiosos.', 'undefined']
# 3, count: 1
#   Inclasificable/No corresponde 524
#     ['Propiciar una calidad de vida digna', 'El Estado debe generar políticas públicas que permitan que los ciudadanos gocen de salud y educación dignas y el ejercicio en su conjunto de derechos sociales', 'policy']
# 4, count: 1
#   Inclasificable/No corresponde 447
#     ['Respeto a la constitución como institución', 'Siempre y cuando sea aprobada en un plebiscito ciudadano', 'undefined']
# total: 1466
# 22015

# %%
# Task A

# %%
# Task B

import re

wordvector = get_wordvector(embedding_name_list[0])
print("listo")
# Out:
# listo

# %%
# Calculo de vector promedio para conceptos del gobierno
print("Calculo de vector promedio para conceptos del gobierno")
concept_vectors = {}
concept_list_by_topic = {}
cant = 0
for topic in gob_concept_data.keys():
    if not topic in concept_vectors.keys():
        concept_vectors[topic] = np.array([])
        
    if not topic in concept_list_by_topic.keys():
        concept_list_by_topic[topic] = []
        
    print(topic + ") cantidad de conceptos " + str(len(gob_concept_data[topic].keys())))
    
    for concept in gob_concept_data[topic].keys():
        print("  " + concept + ": " + str(len(gob_concept_data[topic][concept])))
        cant += len(gob_concept_data[topic][concept])
            
        all_words = re.sub('[^0-9a-zA-Záéíóú]+', ' ', concept.lower())
        mean_vector = ConstitucionUtil.getMeanVector(all_words, wordvector)
        if mean_vector.size == 0:
            print("    cero size vector")
            continue
        
        
        if concept_vectors[topic].size == 0:
            concept_vectors[topic] = mean_vector
        else:
            concept_vectors[topic] = np.vstack((concept_vectors[topic], mean_vector))
            
        print(mean_vector[:5])
        

for topic in concept_vectors.keys():
    print(topic, end=' ')
    print(concept_vectors[topic].shape)
    print(concept_vectors[topic])
    
print(cant)


# Calculo de vector promedio para conceptos abiertos y evaluacion de similaridad
print("Calculo de vector promedio para conceptos abiertos y evaluacion de similaridad")
for topic in open_concept_with_gob_concept.keys():
    print(topic)
    
    for concept in open_concept_with_gob_concept[topic].keys():
        print("  " + concept)
        
        all_original_concept = ""
        all_argument = ""
        
        for arg in open_concept_with_gob_concept[topic][concept]:
            original_concept, argument, argument_mode = arg
            
            original_concept = re.sub('[^0-9a-zA-Záéíóú]+', ' ', original_concept.lower())
            argument = re.sub('[^0-9a-zA-Záéíóú]+', ' ', argument.lower())
            
            print("    " + original_concept)
            print("    " + argument)
            print("    " + argument_mode)
            
            all_original_concept = all_original_concept + " " + original_concept
            all_argument = all_argument + " " + argument
# Out:
# Calculo de vector promedio para conceptos del gobierno
# 1) cantidad de conceptos 37
#   Justicia: 4199
# [ 0.5888   -0.49338   0.42296  -0.40135   0.093935]
#   Democracia: 4037
# [ 0.12414  -0.38491  -0.11367   0.032327 -0.3044  ]
#   Respeto / Conservación de la naturaleza o medio ambiente: 3930
# [ 0.10508725 -0.26593536 -0.01044863 -0.09110688  0.0455045 ]
#   Autonomía / Libertad: 1862
# [ 0.039505 -0.195895  0.00792  -0.22511  -0.173525]
#   Estado de Derecho: 1608
# [ 0.00579533 -0.27809033 -0.11649767 -0.10569633  0.05256867]
#   Igualdad: 3960
# [ 0.03711   -0.32813   -0.087445  -0.38216   -0.0049224]
#   Participación: 1253
# [-0.017586  0.019099  0.21074  -0.20178   0.1249  ]
#   Unidad: 124
# [-0.055166 -0.49314   0.015381 -0.077278  0.023912]
#   Respeto: 2643
# [ 0.15794  -0.43184  -0.37764  -0.11921   0.013678]
#   Descentralización: 3213
# [-0.12168  -0.054841  0.34909   0.20129  -0.061754]
#   Identidad cultural: 587
# [ 0.186971   0.003652   0.0758215 -0.0906165  0.1217925]
#   Estado laico: 1587
# [ 0.0477955 -0.51281   -0.181335   0.0295405  0.039208 ]
#   Equidad de género: 1775
# [ 0.15109201 -0.30396333  0.06741067 -0.17651333 -0.05861866]
#   Subsidiaridad: 381
# [ 0.079982 -0.35671   0.27597   0.14794  -0.25802 ]
#   Probidad: 1059
# [ 0.45807   0.011224  0.087329  0.11097  -0.099863]
#   República: 211
# [ 0.5805     0.019443   0.26506   -0.0047833  0.23068  ]
#   Diversidad: 774
# [ 0.26815 -0.35303 -0.17922 -0.11518 -0.15665]
#   Dignidad: 2047
# [ 0.3684   -0.12211  -0.45086  -0.085876 -0.22733 ]
#   Transparencia y publicidad: 949
# [ 0.09435167 -0.33358634 -0.05303833 -0.12465633 -0.05696267]
#   Desarrollo: 556
# [-0.0079053  0.021392   0.046154   0.2009     0.029076 ]
#   Innovación / Creatividad: 218
# [ 0.37211502 -0.15995     0.095654    0.063317    0.041529  ]
#   Bien Común / Comunidad: 2892
# [ 0.0372732  -0.13101     0.103866   -0.14953934 -0.12613034]
#   Multiculturalidad: 915
# [ 0.35948  -0.15016  -0.019995  0.028446  0.16497 ]
#   Inclusión: 1285
# [ 0.0095743 -0.30657   -0.12386   -0.22912    0.037672 ]
#   Seguridad: 1337
# [ 0.34387  -0.34189  -0.28068   0.032031 -0.058903]
#   Emprendimiento libre: 273
#     convivencia en armonía respetando la diversidad y la identidad cultural de todos los pueblos que viven en chile sin absorción de culturas hegemónicas
#     policy
#   Probidad
#     honradez
#     en una sociedad sumamente individualista hay que pensar en el resto de la sociedad actualmente todos tratan de sacar sus beneficios personales y no pensamos en el resto de la sociedad
#     policy
#   Bien Común / Comunidad
#     bien común comunidad solidaria
#     asegurar el principio de bien común relevando el sentido de comunidad del pensar en y con el colectivo amparados bajo el concepto de solidaridad entendiéndola como que todas las personas deben colaborar en la medida de sus capacidades para asegurar el bienestar general de la sociedad
#     policy
#   Transparencia y publicidad
#     transparencia
#     en un país con crisis de desconfianza debido a la corrupción no sabemos en quien confiar debe asegurarse la transparencia en todos los niveles para recomponer confianzas
#     policy
#   Respeto
#     respeto a la vida
#     respeto la vida desde la concepción hasta la muerte natural como condición esencial del ser humano
#     policy
#   Participación
#     participación social
#     democracia participativa con que el estado busca activamente la participación de los ciudadanos y ciudadanas estimulando además la educación cívica desde la infancia debe garantizar la aplicación de mecanismos participativos efectivos y vinculantes
#     policy
#   Justicia
#     justicia y derecho
#     igualdad o equilibrio ante la ley régimen político sometido a un sistema de leyes e instituciones ordenadas en torno de una constitución la cuál debe ser el fundamento jurídico de las autoridades y funcionarios que se someten a las normas de ésta
#     policy
#   Integración
#     preferencia por las personas más vulnerables
#     foco del estado en los más vulnerables discriminación positiva por los más vulnerables en políticas públicas y destino de los recursos del estado preferencia por los más excluidos
#     policy
#   Responsabilidad
#     responsabilidad social
#     hay que asumir los costos de los problemas sociales
#     policy
#   Respeto / Conservación de la naturaleza o medio ambiente
#     null
#     la jerarquización de estos valores y principios fue con acuerdo unánime y se basó en una lógica de prioridades es decir se identificó un primer valor sin el cual no sería posible articular el resto de los valores y principios y así sucesivamente
#     undefined
#   Amistad cívica
#     fraternidad
#     expresión de los sentimientos de amor y cari o por el otro
#     fact
#   Solidaridad
#     solidaridad fraternidad
#     cooperación y hermandad entre los miembros de la sociedad fomentándola entre los individuos
#     policy
#   Paz / Convivencia pacífica
#     cultura de paz
#     rechazamos toda agresión como instrumento de solución a todos los diferendos y conflictos proponiendo la cooperación entre los pueblos
#     policy
#   Subsidiaridad
#     estado al servicio del hombre
#     el estado debe estar al servicio del hombre el estado no puede pasar sobre nuestros derechos y libertades
#     policy
#   Plurinacionalismo
#     estado plurinacional y muticultural
#     respeto a los pueblos originarios y a la diversidad
#     policy
#   Estado laico
#     estado secular
#     se requiere la independencia total del estado de cualquier influencia o dogma religioso se hace la distinción entre laicismo que implica libertad de conciencia individual y secularismo que se refiere a la garantía de autonomía del estado referido al ámbito religioso
#     policy
#   Inclusión
#     inclusión
#     incluye las ideas de solidaridad y desarrollo inclusivo
#     policy
#   Estado de Derecho
#     estado de derecho
#     estado de derecho como un estado donde se respeta sin condiciones el derecho vigente el derecho objetivo vigente y los derechos subjetivos que existan en ese sentido es un estado sin un soberano presente que pueda suspender el derecho a su voluntad estado de derecho es condición por tanto de seguridad jurídica y mantenimiento del status quo
#     fact
#   Equidad de género
#     equidad de genero
#     el estado debe adoptar medidas especiales que aceleren la igualdad entre mujeres y hombres en todos los ámbitos de la vida
#     policy
#   Igualdad
#     igualdad inclusiva y no discriminación
#     principio fundante somos iguales en derechos y dignidad para ejercerlos el estado debe dar los medios que necesite cada uno así el estado garantiza la no discriminación incluyendo la acción positiva a todas las pcd nna las mujeres las personas indígenas lgbti toda raza y religión etc
#     policy
#   Identidad cultural
#     reconocimiento pueblos originarios
#     debe reconocerse la existencia de pueblos originarios en el país y acabar con las políticas de discriminación y segregación con ellos apelando a una verdadera integración pero reconociendo sus diferencias
#     policy
#   Descentralización
#     descentralización
#     el estado se debe organizar en gobiernos locales con autonomía política administrativa y económica
#     policy
#   Seguridad
#     seguridad y justicia
#     no se puede andar tranquilo y no hay solución para la delincuencia debe ser para todos y no para quienes tienen más recursos hay una injusticia de parte de los candidatos políticos que solo nos visitan para pedir apoyo y luego no se preocupan más de los problemas de la afc y las comunidades
#     policy
#   Diversidad
#     protección y respeto a la diversidad
#     reconocer respetar y proteger cualquier diferencia sea étnica de preferencia sexual cultural u otra no sólo se toleran
#     fact
#   Ciudadanía
#     pertenencia
#     como valor diferenciador y generadora de identidad para las comunidades y vinculo a sus paisajes
#     fact
#   Tolerancia
#     tolerancia
#     debido a que sin ella no puede estar la libertad de expresión y se requiere para plantear de forma sana ideas y propuestas en cualquier contexto
#     fact
#   Soberanía
#     null
#     es propia del estado de derecho y unitario que tenemos a pesar que hoy nos encontramos frente a un escenario distinto de estados globalizados 1 hay diversos tipos de soberanía nacional y popular por ejemplo soberanía nacional son las instituciones soberanía popular son los ciudadanos definir el tipo de soberanía define el tipo de constitución que tendremos en estos momentos tenemos que la generación de una ley es libertad de los legisladores hacerla o no hacerla la soberanía popular incorpora dentro de algunos mecanismos contempla la iniciativa legal popular por ejemplo si juntas una cantidad determinada de firmas puedes presentar un proyecto de ley como ciudadano hay otras manifestaciones en otras áreas por ejemplo actualmente existe el mandato libre los elegidos como representantes hacen lo que quieren y no piden la opinión a nadie para ello existe un mecanismo que se denomina referendum revocatorio en donde si el político no cumple y se organiza una determinada cantidad de votantes pueden revocar el mandato del político incumplidor 2 existe acuerdo sobre lo dicho no obstante la soberanía debe ser analizada en conjunto con otros valores actualmente se dice que la soberanía reside esencialmente en la nación el titular es la nación es decir generaciones pasadas presentes y futuras lo que busca establecer un cierto límite a la voluntad del pueblo porque la voluntad del pueblo sería más inmediata pero no parce que el ejercicio de la soberanía en la nación sea la causa o el óbice de que tengamos una democracia representativa porque justamente la misma constitución que el ejercicio de esta soberanía que reside en la nación se realiza por el pueblo y las instituciones pero como el pueblo que también pertenece a la nación es titular para ejercer la soberanía lo que debe considerarse vincular la soberanía con otros principios principalmente participación y justicia porqué participación porque las iniciativas ciuda
#     policy
#   Dignidad
#     dignidad con paz convivencia
#     la dignidad individual y colectiva como base de la convivencia
#     policy
#   Autonomía / Libertad
#     libertad autonomía
#     las personas libres y autónomas son la base de la sociedad la autonomía se vincula con el carácter único de las personas y su potencialidad para decidir sobre su proyecto de vida e identidad también refiere a la autodeterminación de los pueblos originarios la posibilidad de organizarse en el marco del respeto de los derechos humanos
#     fact
#   República
#     alternancia en los cargos de elección popular
#     los cargos de elección popular debieran tener una limitación a la reelección para evitar la corrupción y el desapego con la población lo que produce una baja participación
#     policy
#   Unidad
#     unidad igualdad transparencia inclusión
#     1 solidarizar con las necesidades propias del concepto persona 2 distribución equitativa del producto económico nacional empleos sueldos otros 3 considerar a toda persona como única sin distingo a sus individualidades
#     policy
#   Desarrollo
#     progresividad
#     el estado debe generar en cada momento una mejor protección y garantía de los derechos humanos de forma que siempre estén sujetos a evolución y mejoramiento
#     policy
#   Innovación / Creatividad
#     innovación creatividad
#     valores como motores de desarrollo y evolución en un mundo en constante cambio generando investigación y reflexiones que cultiven nuestra identidad común
#     undefined
#   Democracia
#     democracia
#     forma de cómo se llega al poder y se rinde cuentas
#     value
#   Pluralismo
#     pluralismo y multiculturalidad
#     consideración respeto y reconocimiento de todas las ideas religiones lenguas y culturas que se presentan en el territorio nacional
#     policy
#   Emprendimiento libre
#     emprendimiento libre
#     es un motor activo de las sociedades especialmente si se toma en consideración el sólido impacto en las comunidades
#     fact
#   Patriotismo
#     patriotismo
#     sentimiento de nación de todos los ciudadanos
#     fact
# 2
#   A sindicalizarse y a la negociación colectiva
#     null
#
#     blank
#   Igualdad
#     derecho a la igualdad y no discriminación
#     se propone también juntar los dos derechos derecho a la igualdad y no discriminación que incluiría los votados igualdad de género e igualdad ante los tributos y demás vertientes de la igualdad se considera fundamental además consagrar expresamente la no discriminación
#     policy
#   Igualdad de género
#     igualdad de genero y diversidad sexual
#     derecho fundamental para la sociedad
#     fact
#   A la seguridad social
#     jubilacion digna
#     el estado debe tener un sistema para administrar los recursos que el sistema garantice un sueldo que permita vivir dignamente
#     policy
#   Respeto a la naturaleza / Medio ambiente
#     a vivir en ambiente libre de contaminación
#     el estado tiene el deber de garantizar el acceso a un medio ambiente libre de contaminación aire limpio aguas descontaminadas alimentos libre de contaminación pescados mariscos vegetales y un ambiente sin contaminación acústica
#     policy
#   A la vida
#     existencia y vida
#     derecho a la existencia del nonato seguridad y proteccion de la madre involucra un medio ambiente adecuado seguridad educacion
#     fact
#   A la educación
#     educación de calidad
#     debe ser pilar de la sociedad la educación de calidad ayuda a disminuir otras desigualdades es necesaria una mirada a largo plazo y pensar el país que queremos para responder educarnos para qué
#     policy
#   Libertad de conciencia
#     objeción de conciencia
#     creemos en los valores morales en convicciones interiores o religiosas es de suma importancia su consagración actualmente no está explícito en nuestra constitución
#     policy
#   A la información
#     a la información
#     a la información acceso a la información pública real por parte del estado para que los ciudadanos se puedan desenvolver con conocimiento y autonomía
#     policy
#   Libre iniciativa económica / Libre empresa
#     libre y equitativa competencia económica
#     promover la libre empresa pero de manera regularizada
#     policy
#   Libertad de trabajo
#     libertad de trabajo y emprendimiento
#     el estado no puede coartar o limitar esta libertad salvo por razones de orden público muy acotadas y justificadas
#     policy
#   A la seguridad / Vida sin violencia
#     a la seguridad
#     destacamos la importancia de vivir en un país seguro con protección ante la delincuencia y manteniendo la paz como valor fundamental
#     fact
#   Al trabajo
#     al trabajo y seguridad social
#     garantizar el acceso al trabajo y por consiguiente el deber del estado de desarrollar la seguridad social materializar jubilaciones dignas calidad de un ambiente laboral sueldos dignos entre otros
#     policy
#   Proteccion judicial de los derechos
#     a la protección judicial de los derechos
#     asegurar constitucionalmente la protección judicial efectiva de todos los derechos de las personas tanto individual como colectivamente
#     policy
#   A la participación
#     a la participación vinculante
#     todas las ciudadanas y ciudadanos deben tener derecho a emitir su opinión sin estar sujeto a la opinión de nadie la opinión de las mayorías debe ser vinculante para el sistema de tal manera que las mayorías con su participación gobiernen a través de sus representantes con mandatos democráticos
#     policy
#   Acceso a la cultura
#     derecho de acceso a la cultura
#     el estado debe asegurar a través de sus polítcas que la cultura es parte de los derechos de las personas de todo segmento social y económico asegurando con ello la formación de un bagaje cultural propio basado en la identidad cultural que debenmos tener como sociedad chilena
#     policy
#   De propiedad
#     null
#
#     blank
#   A la vivienda digna
#     a vivienda
#      derecho a un lugar digno donde vivir independiente de la situación económica del sujeto
#     policy
#   A la salud
#     salud educación y vivienda digna
#     que sean dignas oportunas resolutivas universales de excelencia y calidad para todos los ciudadanos chilenos
#     policy
#   A la integridad física y psíquica
#     null
#
#     blank
#   No discriminación
#     identidad de género
#     el estado debe resguardar la igualdad de derechos en todos los ámbitos entre todos los sujetos sea cual sea la percepción subjetiva que un individuo tiene sobre sí mismo en cuanto a sentirse hombre mujer o de un género no binario sin considerar características físicas o biológicas
#     policy
#   Al salario equitativo
#     salario equitativo
#     reducir las brechas en los salarios para disminuir desigualdad social para tener acceso a salud vivienda educación etc
#     policy
#   A sufragio / Votar
#     al sufragio y la participación
#     derecho a votar sin discriminación mayor uso de los plebiscitos en decisiones sociales y de otras instancias de participación ciudadana
#     policy
#   A la identidad cultural
#     identidad cultural
#     el estado debe asegurar el derecho cultural identidad cultural e integración de los pueblos indígenas
#     policy
#   Ser elegido en cargos públicos
#     null
#     para promover pensamientos e ideas del pueblo evangélico al país
#     value
#   A la integración de discapacidad
#     null
#
#     blank
#   Libertad de expresión
#     libertad de expresión
#     todos tiene derecho a dar su opinión
#     fact
#   Privacidad e intimidad
#     derecho a la privacidad
#     n 5 este grupo agrega este derecho ya que hoy en d a somos vulnerados en multiples aspectos de la vida diaria perdiendo incluso el derecho a nuestra privacidad
#     blank
#   Igualdad de acceso a la justicia / Debido proceso
#     debido proceso y juicio justo
#     debido proceso y juicio justo
#     policy
#   A la honra / Al honor
#     a la dignidad
#     derecho a una vida digna y a una muerte digna concepto de dignidad es difícil de definir por eso el acuerdo parcial
#     policy
#   Igualdad ante la ley
#     justicia
#      como fin fundamental y prioritario del derecho que se supedite a los principios jurídicos de seguridad y bien común dar a cada cual lo que le corresponde distributiva y conmutativa
#     policy
#   Derechos del niño, niña y adolecente
#     derechos del ni o adolescente y adultos mayores
#     no existen derechos para estos grupos sobretodo para el adulto mayor
#     fact
#   Acceso a información pública
#     derecho al acceso y ejercicio de la información estatal privada y pública
#     además del acceso a la información estatal se debe garantizar el derecho del ejercicio de la comunicación e información privada y comunitaria independientemente de quién la ejerza
#     policy
#   Libertad de enseñanza
#     libertad de ense anza
#     libertad de elegir como educar a los hijos
#     policy
#   De los pueblos indígenas
#     a la autonomía de los pueblos indígenas reconocimiento y reparación
#     los pueblos indígenas deben ser reconocidos como naciones con derechos como tales lograr esto sería un gran avance para nuestro país tanto en su florecimiento productivo como en su convivencia pacífica
#     policy
#   A huelga
#     huelga real
#     los trabajadores debemos tener acceso a una huelga real y efectiva porque es un derecho humano y debe consagrarse como tal en nuestra carta fundamental
#     policy
#   Libertad personal
#     libertad personal
#     la libertad personas debe regularse para asegurar un ejercicio equilibrado de ésta
#     policy
#   Derecho de asociación
#     derecho a la asociación y sindicalización
#     mejoramiento de condiciones laborales y fortalecer las relaciones comunitarias y sociales que aborden temas de interés colectivo
#     policy
#   Igualdad ante las cargas públicas
#     deber de soportar las cargas públicas en la medida de las capacidades individuales
#     responsabilidad ante la comunidad y el bien social trato igualitario por parte del estado en reconocimiento de capacidad económica
#     policy
#   Igualdad ante los tributos
#     equidad ante los tributos salario
#     para salvaguardar la equidad en torno al cumplimiento de obligaciones fiscales que considere el salario de cada ciudadano de manera justa y proporcional a su actividad productiva ingresos y salidas de dinero y jornadas de trabajo
#     policy
#   Libertad ambulatoria
#     inmigracion
#     creemos que deberíamos tener una ley de migración en chile ya que esta no esta estipulada en la constitución
#     policy
#   A la nacionalidad
#     a pertenecer a la nación
#     que se garanticen los derechos a cualquier individuo que solicite nacionalidad
#     policy
#   De petición ante las autoridades
#     derecho a la iniciativa ciudadana en proyectos de ley
#     asegurar el derecho constitucional a la presentación de iniciativas de ley tanto individual como colectivamente
#     policy
#   Reunión pacífica
#     libertad de reunion
#     ha no ser discriminados por agruparse ni menos cabados
#     policy
# 3
#   Cumplimiento de obligaciones fiscales
#     deber de pagar los impuestos
#     es la base para asegurar derechos básicos como educación salud y protección social para todos
#     fact
#   Cumplimiento de las leyes y normas
#     respeto a las leyes y normas
#     que las leyes sean adecuadas a los tiempos y que se respeten
#     policy
#   Responsabilidad
#     responsabilidad social
#     responsabilizarnos del entorno social que nos convoca y promover la integración
#     policy
#   Deberes de protección de conservación de la naturaleza
#     promoción y protección de conservación de la naturaleza y recursos naturales
#     trabajo constante y efectivo para cuidar la naturaleza y usar responsablemente y con criterio los recursos naturales
#     policy
#   Servicio a la comunidad
#     null
#
#     blank
#   De satisfacer cargas públicas
#     subordinación de las fuerzas armadas al poder civil
#     nunca más las fuerzas armadas pueden tomar el control de la población civil se debe explicitar y contemplar castigos ejemplares para potenciales quiebres
#     policy
#   Ejercicio legítimo y no abusivo de los derechos
#     ejercicio responsable de derechos
#     deber y responsabilidad de no abusar de la práctica y espíritu de los distintos derechos que los ciudadanos poseemos
#     policy
#   De protección y conservación de patrimonio histórico y cultural
#     conservación y protección del patrimonio histórico y cultural
#     cada ciudadano de nuestro país debe sentirse responsable de proteger y conservar el patrimonio histórico y cultural de nuestra nación
#     policy
#   Protección, promoción y respeto de los derechos humanos y fundamentales
#     null
#     creemos que el estado debe hacer públicos los derechos fundamentales y educar a los miembros de la sociedad sobre la existencia y mecanismos de protección de estos derechos
#     policy
#   Cumplimiento de tratados y obligaciones internacionales
#     controlar el ingreso de inmigrantes al país
#     se hace sumamente importante poder incorporar este asunto debido al gran número de inmigrares bajan mano de obra en nuestro país
#     policy
#   Respeto de derechos de otros
#     respeto de derechos de otros
#     en la decisión de convivir sanamente el respeto es un deber fundamental
#     fact
#   Respeto por la constitución
#     respeto por la constitución
#     ley fundamental que define el régimen de los derecho y libertades de los ciudadanos y delimita los poderes e instituciones
#     fact
# 4
#   Fuerzas Armadas
#     democratizacion de las ffaa
#     unanimidad 14 acuerdos escalafon unico asencion meritoria fin de la doctrina de seguridad interior del estado y enemigo interno y no envio a escuela de las americas preeminencia del parlamento y la ley sobre las ordenes superiores fin a la institucion de los capellanes estado laico
#     policy
#   Gobierno local / Municipal
#     gobiernos locales
#     autonimía transparencia elección popular
#     policy
#   Gobierno nacional (estructura y funciones)
#     corfo
#     promoción de emprendimientos privados con carácter estatal y nacional
#     policy
#   Plebiscitos, referendos y consultas
#     democracia participativa
#     instauración de plebiscitos consultas iniciativa popular de ley mandato revocatorio todos vinculantes
#     policy
#   Justicia electoral
#     justicia electoral tricel y servel
#     además de mantener estos organismos fiscalizadores proponemos reelección limitada de los cargos de elección popular
#     policy
#   Cambio o reforma constitucional
#     una nueva constitución
#      estamos en pleno acuerdo con la necesidad de hacer una nueva constitución que nos reprente a todos que sea participativa e integradora que reconozca e incorpore los cambios que ha experimentado el país
#     policy
#   Forma de Estado
#     estado autonomía regional
#     co gobierno regional intendente elegido por presidente y cores fortalecidos elegidos por la región para desarrollo sustentable
#     policy
#   Presidencia de la República
#     reelección presidencial
#     en 4 a os no se logra cumplir con las políticas de gobierno
#     fact
#   Congreso o parlamento
#     parlamento
#     instancia donde se discutan los temas y no solo se vote
#     policy
#   Régimen de gobierno presidencial /Semi-presidencial / Parlamentario
#     regimen de gobierno presidencial
#     los períodos presidenciales hoy son demasiado cortos se proponen períodos de 4 a os con reelección
#     policy
#   División territorial
#     división territorial decentralizada territorial y funcionalmente
#     la realidad geográfica se contrapone con el modelo unitario existente igualdad con las regiones
#     fact
#   Contraloría general / Tribunales de cuentas
#     fiscalía de la gestión pública
#     crear esta entidad técnica para controlar el aprovechamiento de los recursos económicos humanos y técnicos existentes en el aparato estatal
#     value
#   Juicio político /acusación constitucional
#     mandato revocable
#     las autoridades actuan en representación de la sociedad civil por lo que deben representar los intereses legítimos de la ciudadanía
#     policy
#   Justicia constitucional
#     justiticia constitucional y electoral
#     conformación de un órgano que imparta justicia y garantice los procesos constitucionales y electorales oficiales del país
#     policy
#   Defensor del Pueblo / Ciudadano
#     defensor del pueblo
#     que se contemple la defensoria de los derechos humanos y políticos de parte del estado
#     policy
#   Ministerio Público / Defensoría Pública
#     fiscalización
#     es necesario fiscalizar a los parlamentarios pero no del mismo conglomerado sino de otras entidades externas
#     policy
#   Gobierno regional
#     gobierno regional
#     necesitan más autonomía para lograr resolver de mejor forma de resolver sus problemas
#     value
#   Poder judicial (estructura y funciones)
#     una sola justicia para todas os
#     constitucionalmente nuestro estado de derecho debe garantizar una sola justicia para todas os las os ciudadanos sin distinción de clases sociales o pertenencia a una determinada institución
#     policy
#   Estado de excepción
#     estados de excepción constitucional
#     es necesario que se traten
#     fact
#   Jefatura de gobierno
#     null
#
#     blank
#   Gobierno provincial
#     gobernacion
#     que cada una de las instituciones deben ser neutral imparcial deben trabajar por el bien común
#     policy

# %%
from sklearn.metrics.pairwise import cosine_similarity

w = "Identidad cultural"
w = re.sub('[^0-9a-zA-Záéíóú]+', ' ', w.lower())
print(w)

mean_vector = ConstitucionUtil.getMeanVector(all_words, wordvector)
print(mean_vector)

print(wordvector["justicia"])
# Out:
# identidad cultural
# [-1.13068007e-01 -2.09641784e-01  1.38618005e-02  4.99185994e-02
#  -5.07276040e-03  1.48699939e-01 -1.83658600e-01  1.15651205e-01
#  -1.65459991e-01  4.79028001e-02 -2.33515337e-01 -3.04633975e-02
#   4.71453965e-02  1.93538032e-02  1.41333610e-01  1.01976059e-01
#   1.43928006e-01  1.83187008e-01 -1.21099958e-02 -2.37280607e-01
#  -1.13470599e-01 -1.12639606e-01 -1.16323397e-01 -4.04377952e-02
#   5.75807914e-02 -2.54254013e-01  2.68996805e-01  3.35266208e-03
#  -9.37020034e-02  8.44514519e-02  1.21254012e-01 -7.29095936e-02
#  -2.17474818e-01  1.22853599e-01 -6.48937002e-02 -9.24280062e-02
#   8.01400107e-04 -1.29500404e-01 -1.20561801e-01  1.15683198e-01
#   1.00042403e-01  4.31943797e-02 -1.76595405e-01 -9.83397942e-03
#   5.91407940e-02  1.13249496e-01  6.72699958e-02 -1.23226598e-01
#   1.82327196e-01  8.81083980e-02 -3.41850035e-02  9.74552035e-02
#  -1.03685997e-01  8.71667042e-02 -5.71133979e-02 -2.13336617e-01
#  -1.83484599e-01 -9.83394012e-02  1.22291192e-01  1.18529974e-02
#  -4.82097976e-02 -4.71410044e-02  1.89661801e-01  1.62170008e-02
#   7.40234032e-02 -9.54700932e-02  1.18731603e-01  3.41560249e-03
#   1.66764185e-01 -1.40009196e-02  9.62717980e-02  4.52817380e-02
#   4.34656069e-02  2.08080001e-02  1.83350995e-01 -3.02431192e-02
#   9.89424065e-02  3.85600259e-03 -6.30254000e-02 -1.56845808e-01
#   2.35629171e-01 -6.22680411e-03 -5.77818044e-02  7.34923929e-02
#   4.59375978e-02  1.85114034e-02  8.25754032e-02  4.66647968e-02
#  -1.18820593e-01 -1.86116189e-01  1.15988012e-02  9.80258062e-02
#   3.04633193e-02  4.28114161e-02 -1.67383999e-02 -5.57790771e-02
#  -1.25359401e-01 -3.04043982e-02  1.38516396e-01  3.81033979e-02
#  -1.57271400e-01 -2.00351980e-02 -9.70111936e-02 -2.82904021e-02
#  -1.48131996e-01  1.01797804e-01  3.27315964e-02  9.69708562e-02
