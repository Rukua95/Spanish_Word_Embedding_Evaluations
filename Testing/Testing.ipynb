# %%
import os
import io
import json
import random

import numpy as np

from scipy.stats import spearmanr
from gensim.models.keyedvectors import KeyedVectors
from statistics import mean 

import Constant
import GlobalTest

import torch
import torch.nn as nn
import torch.nn.functional as F

from pytorchtools import EarlyStopping
from torch import LongTensor
from torch.nn import Embedding, LSTM
from torch.autograd import Variable
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler



# Path a carpeta principal
MAIN_FOLDER = Constant.MAIN_FOLDER

# Path a carpeta con los embeddings
EMBEDDING_FOLDER = Constant.EMBEDDING_FOLDER

# Lista con los nombres de los archivos de los embeddings
embedding_name_list = os.listdir(EMBEDDING_FOLDER)

# %%
print(">>> Embeddings a evaluar:")
for embedding in embedding_name_list:
    print("  > " + embedding)

def get_wordvector(file, cant=None):
    print("Cargando embedding " + file)
    wordvector_file = EMBEDDING_FOLDER / file
    word_vector = KeyedVectors.load_word2vec_format(wordvector_file, limit=cant)
    print("Carga lista")
    return word_vector
# Out:
# >>> Embeddings a evaluar:
#   > _fasttext_sbwc.vec
#   > _fasttext_suc.vec
#   > _fasttext_wiki.vec
#   > _glove_sbwc.vec
#   > _w2v_sbwc.txt

# %%
from ConstitucionRNNEval import RNNEvaluation

for emb in embedding_name_list:
    word_vector = get_wordvector(emb)
    word_vector_name = (emb).split('.')[0]
    test = RNNEvaluation()
    test.evaluate(word_vector, word_vector_name)
# Out:
# Cargando embedding _fasttext_sbwc.vec
# Carga lista
# Test de Constitucion
# Embedding size: 855380
# >>> Entrenamiento & test para task A y B
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 21% |
# > Obtencion de datos
# > train_task_A
# 1 37508
# 2 36346
# 3 33173
# 4 32780
# > dev_task_A
# 1 4690
# 2 4541
# 3 4145
# 4 4097
# > test_task_A
# 1 4705
# 2 4565
# 3 4154
# 4 4107
# > data_taskB
# 1 1964
# 2 3356
# 3 1820
# 4 3084
# Para topico 1 ya existen resultados para task A y B
# Para topico 2 ya existen resultados para task A y B
# Para topico 3 ya existen resultados para task A y B
#
# > Entrenando topico 4
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 21% |
#
# Ejemplos de datos
# ['debe ser una institución autónoma e independiente que se encargue de garantizar los derechos de los ciudadanos ante los abusos que puedan cometer los poderes políticos y administrativos y debe supervisar el pleno cumplimiento de los derechos humanos y fundamentales', 'defensor del pueblo ciudadano']
# ['que se cree un organismo que este mas cerca de las personas y pueda asesorarlos', 'defensor del pueblo ciudadano']
# ['que la constitución incorpore esta figura para la defensa de derechos colectivos potenciando las instancias de acceso a la justicia', 'defensor del pueblo ciudadano']
# ['debe existir un organismo que resguarde los derechos ciudadanos de forma real que sea intermediario entre las personas y los poderes del estado que se cumplan de verdad los derechos ciudadanos que existen en nuestra constitución', 'defensor del pueblo ciudadano']
# ['para defender a los ciudadanos de los abusos del sistema', 'defensor del pueblo ciudadano']
#
# Ejemplos de data limpio
# [['debe', 'ser', 'una', 'institución', 'autónoma', 'e', 'independiente', 'que', 'se', 'encargue', 'de', 'garantizar', 'los', 'derechos', 'de', 'los', 'ciudadanos', 'ante', 'los', 'abusos', 'que', 'puedan', 'cometer', 'los', 'poderes', 'políticos', 'y', 'administrativos', 'y', 'debe', 'supervisar', 'el', 'pleno', 'cumplimiento', 'de', 'los', 'derechos', 'humanos', 'y', 'fundamentales'], 'defensor del pueblo ciudadano']
# [['que', 'se', 'cree', 'un', 'organismo', 'que', 'este', 'mas', 'cerca', 'de', 'las', 'personas', 'y', 'pueda', 'asesorarlos'], 'defensor del pueblo ciudadano']
# [['que', 'la', 'constitución', 'incorpore', 'esta', 'figura', 'para', 'la', 'defensa', 'de', 'derechos', 'colectivos', 'potenciando', 'las', 'instancias', 'de', 'acceso', 'a', 'la', 'justicia'], 'defensor del pueblo ciudadano']
# [['debe', 'existir', 'un', 'organismo', 'que', 'resguarde', 'los', 'derechos', 'ciudadanos', 'de', 'forma', 'real', 'que', 'sea', 'intermediario', 'entre', 'las', 'personas', 'y', 'los', 'poderes', 'del', 'estado', 'que', 'se', 'cumplan', 'de', 'verdad', 'los', 'derechos', 'ciudadanos', 'que', 'existen', 'en', 'nuestra', 'constitución'], 'defensor del pueblo ciudadano']
# [['para', 'defender', 'a', 'los', 'ciudadanos', 'de', 'los', 'abusos', 'del', 'sistema'], 'defensor del pueblo ciudadano']
#
# Cantida de datos finales: 32744
# Ejemplos de datos formateados
# [[150, 47, 18, 1250, 2556, 52, 1148, 7, 13, 22133, 1, 708, 10, 67, 1, 10, 593, 122, 10, 3522, 7, 812, 5839, 10, 2615, 625, 6, 2482, 6, 150, 5006, 4, 1389, 912, 1, 10, 67, 114, 6, 1167], 0]
# [[7, 13, 1563, 15, 1006, 7, 31, 1664, 462, 1, 12, 75, 6, 745, 151685], 0]
# [[7, 2, 799, 17349, 35, 811, 17, 2, 585, 1, 67, 5370, 36966, 12, 5048, 1, 386, 9, 2, 362], 0]
# [[150, 4743, 15, 1006, 7, 139123, 10, 67, 593, 1, 103, 377, 7, 225, 15776, 32, 12, 75, 6, 10, 2615, 11, 50, 7, 13, 3991, 1, 1439, 10, 67, 593, 7, 828, 5, 428, 799], 0]
# [[17, 2886, 9, 10, 593, 1, 10, 3522, 11, 117], 0]
#
# Cantidad de clases: 21
# Informacion sobre clases: indice, nombre, cantidad de datos
# 0 defensor del pueblo ciudadano 2745
# 1 cambio o reforma constitucional 2028
# 2 plebiscitos referendos y consultas 4036
# 3 contraloría general tribunales de cuentas 1666
# 4 fuerzas armadas 2241
# 5 forma de estado 1665
# 6 poder judicial estructura y funciones  2353
# 7 justicia constitucional 841
# 8 gobierno local municipal 1921
# 9 régimen de gobierno presidencial semi presidencial parlamentario 2012
# 10 gobierno regional 2191
# 11 presidencia de la república 1639
# 12 congreso o parlamento 2958
# 13 división territorial 521
# 14 gobierno provincial 439
# 15 juicio político acusación constitucional 1067
# 16 justicia electoral 527
# 17 ministerio público defensoría pública 728
# 18 estado de excepción 360
# 19 gobierno nacional estructura y funciones  632
# 20 jefatura de gobierno 174
#
# Informacion del modelo
# ClassifierModel(
#   (embedding): Embedding(855381, 300)
#   (lstm): LSTM(300, 21, batch_first=True)
#   (logsoftmax): LogSoftmax()
# )
# Path guardado de modelo: D:\Documents\Memoria - Eval. Word Embeddings\Models\taskA_855380_4__fasttext_sbwc.pt
# Existe un modelo guardado, inicio de carga.
#   Entrenamiento
#
#   > Epoca: 1
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
#     > Using saved model, getting results from validation
# >>> Acc
# top1: 0.0
# top5: 0.0
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.4237163814180929
# top5: 0.773838630806846
#     > Epoca: 1
#     > Train loss nan
#     > Valid loss 2.3556545674800873
# Validation loss decreased (inf --> 2.355655).  Saving model ...
#
#   > Epoca: 2
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.5440080625458099
# top5: 0.8783288541412168
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.4322738386308069
# top5: 0.7770171149144254
#     > Epoca: 2
#     > Train loss 2.094083758071065
#     > Valid loss 2.354571744799614
# Validation loss decreased (2.355655 --> 2.354572).  Saving model ...
#
#   > Epoca: 3
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.5916198387490837
# top5: 0.8927131688248229
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.4383863080684597
# top5: 0.7799511002444988
#     > Epoca: 3
#     > Train loss 2.0059296414256096
#     > Valid loss 2.343095153570175
# Validation loss decreased (2.354572 --> 2.343095).  Saving model ...
#
#   > Epoca: 4
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.5930552162228194
# top5: 0.8934461275348156
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.4388753056234719
# top5: 0.7841075794621027
#     > Epoca: 4
#     > Train loss 1.9987696595489979
#     > Valid loss 2.3366502076387405
# Validation loss decreased (2.343095 --> 2.336650).  Saving model ...
#
#   > Epoca: 5
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.6023698998289763
# top5: 0.8970498411922795
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.4464547677261614
# top5: 0.7863080684596577
#     > Epoca: 5
#     > Train loss 1.9808647334575653
#     > Valid loss 2.330764204263687
# Validation loss decreased (2.336650 --> 2.330764).  Saving model ...
#
#   > Epoca: 6
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.6052711947226973
# top5: 0.8976606401172734
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.44621026894865523
# top5: 0.7867970660146699
#     > Epoca: 6
#     > Train loss 1.9744149409234524
#     > Valid loss 2.3230804204940796
# Validation loss decreased (2.330764 --> 2.323080).  Saving model ...
#
#   > Epoca: 7
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.611806743220132
# top5: 0.9006535548497434
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.45036674816625916
# top5: 0.7887530562347188
#     > Epoca: 7
#     > Train loss 1.96234992146492
#     > Valid loss 2.317680299282074
# Validation loss decreased (2.323080 --> 2.317680).  Saving model ...
#
#   > Epoca: 8
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.6160823356950892
# top5: 0.9019667725384803
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.454278728606357
# top5: 0.7909535452322738
#     > Epoca: 8
#     > Train loss 1.9528841897845268
#     > Valid loss 2.312537580728531
# Validation loss decreased (2.317680 --> 2.312538).  Saving model ...
#
#   > Epoca: 9
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 32% |
# >>> Acc
# top1: 0.6192584901050574
# top5: 0.9024859516247251
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.45061124694376525
# top5: 0.7916870415647922
#     > Epoca: 9
#     > Train loss 1.947241049259901
#     > Valid loss 2.3077789545059204
# Validation loss decreased (2.312538 --> 2.307779).  Saving model ...
#
#   > Epoca: 10
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.6291228927437088
# top5: 0.9055094063034449
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 32% |
# >>> Acc
# top1: 0.4572127139364303
# top5: 0.7941320293398533
#     > Epoca: 10
#     > Train loss 1.9320179522037506
#     > Valid loss 2.302039325237274
# Validation loss decreased (2.307779 --> 2.302039).  Saving model ...
#
#   > Epoca: 11
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 32% |
# >>> Acc
# top1: 0.6288785731737112
# top5: 0.9057231859271928
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.4555012224938875
# top5: 0.7970660146699267
#     > Epoca: 11
#     > Train loss 1.9299084320664406
#     > Valid loss 2.2993099838495255
# Validation loss decreased (2.302039 --> 2.299310).  Saving model ...
#
#   > Epoca: 12
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.6389872953823601
# top5: 0.9082885414121671
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.46161369193154034
# top5: 0.7982885085574573
#     > Epoca: 12
#     > Train loss 1.9156196899712086
#     > Valid loss 2.2951361536979675
# Validation loss decreased (2.299310 --> 2.295136).  Saving model ...
#
#   > Epoca: 13
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.6436293672123137
# top5: 0.9087771805521623
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.46185819070904643
# top5: 0.8
#     > Epoca: 13
#     > Train loss 1.9087178371846676
#     > Valid loss 2.288938120007515
# Validation loss decreased (2.295136 --> 2.288938).  Saving model ...
#
#   > Epoca: 14
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.6436293672123137
# top5: 0.9099682384559004
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.46430317848410757
# top5: 0.8014669926650366
#     > Epoca: 14
#     > Train loss 1.9048611707985401
#     > Valid loss 2.2884285300970078
# Validation loss decreased (2.288938 --> 2.288429).  Saving model ...
#
#   > Epoca: 15
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.6521500122159785
# top5: 0.9113119960908869
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 33% |
# >>> Acc
# top1: 0.4713936430317848
# top5: 0.8046454767726161
#     > Epoca: 15
#     > Train loss 1.8937856815755367
#     > Valid loss 2.2820359617471695
# Validation loss decreased (2.288429 --> 2.282036).  Saving model ...
#
#   > Epoca: 16
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.6564866845834352
# top5: 0.913297092597117
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.471638141809291
# top5: 0.8061124694376528
#     > Epoca: 16
#     > Train loss 1.8856707271188498
#     > Valid loss 2.278487354516983
# Validation loss decreased (2.282036 --> 2.278487).  Saving model ...
#
#   > Epoca: 17
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.6617090153921329
# top5: 0.9141522110921084
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.47726161369193154
# top5: 0.8070904645476773
#     > Epoca: 17
#     > Train loss 1.879113495349884
#     > Valid loss 2.2720863819122314
# Validation loss decreased (2.278487 --> 2.272086).  Saving model ...
#
#   > Epoca: 18
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.664701930124603
# top5: 0.9153738089420963
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 32% |
# >>> Acc
# top1: 0.4777506112469438
# top5: 0.8061124694376528
#     > Epoca: 18
#     > Train loss 1.8718832712620497
#     > Valid loss 2.2689628154039383
# Validation loss decreased (2.272086 --> 2.268963).  Saving model ...
#
#   > Epoca: 19
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.6701380405570486
# top5: 0.9157708282433423
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.48166259168704156
# top5: 0.8083129584352078
#     > Epoca: 19
#     > Train loss 1.863778555765748
#     > Valid loss 2.263798549771309
# Validation loss decreased (2.268963 --> 2.263799).  Saving model ...
#
#   > Epoca: 20
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.6706266796970437
# top5: 0.9165954067920841
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.48141809290953547
# top5: 0.8100244498777506
#     > Epoca: 20
#     > Train loss 1.8594119548797607
#     > Valid loss 2.2616969496011734
# Validation loss decreased (2.263799 --> 2.261697).  Saving model ...
#
#   > Epoca: 21
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.6764292694844857
# top5: 0.9175116051795749
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.48679706601466993
# top5: 0.810757946210269
#     > Epoca: 21
#     > Train loss 1.8504078704863787
#     > Valid loss 2.259504586458206
# Validation loss decreased (2.261697 --> 2.259505).  Saving model ...
#
#   > Epoca: 22
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.6819264598094308
# top5: 0.9193134620083069
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.4877750611246944
# top5: 0.8151589242053789
#     > Epoca: 22
#     > Train loss 1.8432659897953272
#     > Valid loss 2.253472685813904
# Validation loss decreased (2.259505 --> 2.253473).  Saving model ...
#
#   > Epoca: 23
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.6856523332518935
# top5: 0.9204739799657953
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.48973105134474326
# top5: 0.8171149144254278
#     > Epoca: 23
#     > Train loss 1.8362788949161768
#     > Valid loss 2.2510477751493454
# Validation loss decreased (2.253473 --> 2.251048).  Saving model ...
#
#   > Epoca: 24
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.689103347178109
# top5: 0.9215123381382849
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.4907090464547677
# top5: 0.8163814180929095
#     > Epoca: 24
#     > Train loss 1.8304191753268242
#     > Valid loss 2.247403919696808
# Validation loss decreased (2.251048 --> 2.247404).  Saving model ...
#
#   > Epoca: 25
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.6920657219643294
# top5: 0.9224896164182751
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.49437652811735944
# top5: 0.8188264058679706
#     > Epoca: 25
#     > Train loss 1.8244091011583805
#     > Valid loss 2.2473743855953217
# Validation loss decreased (2.247404 --> 2.247374).  Saving model ...
#
#   > Epoca: 26
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.6955167358905449
# top5: 0.9235890544832641
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.49339853300733494
# top5: 0.8180929095354523
#     > Epoca: 26
#     > Train loss 1.8185953740030527
#     > Valid loss 2.2440528869628906
# Validation loss decreased (2.247374 --> 2.244053).  Saving model ...
#
#   > Epoca: 27
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.6972269728805277
# top5: 0.9237722941607622
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.4921760391198044
# top5: 0.8193154034229829
#     > Epoca: 27
#     > Train loss 1.8140790984034538
#     > Valid loss 2.2434395253658295
# Validation loss decreased (2.244053 --> 2.243440).  Saving model ...
#
#   > Epoca: 28
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7018385047642316
# top5: 0.9250244319569998
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.4941320293398533
# top5: 0.819559902200489
#     > Epoca: 28
#     > Train loss 1.8073345199227333
#     > Valid loss 2.2391790598630905
# Validation loss decreased (2.243440 --> 2.239179).  Saving model ...
#
#   > Epoca: 29
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 34% |
# >>> Acc
# top1: 0.702602003420474
# top5: 0.9257268507207427
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.4919315403422983
# top5: 0.819559902200489
#     > Epoca: 29
#     > Train loss 1.804291371256113
#     > Valid loss 2.2397347390651703
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 30
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 12% | 34% |
# >>> Acc
# top1: 0.7067859760566821
# top5: 0.9268568287319814
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.49511002444987773
# top5: 0.8224938875305623
#     > Epoca: 30
#     > Train loss 1.797741251066327
#     > Valid loss 2.2345024049282074
# Validation loss decreased (2.239179 --> 2.234502).  Saving model ...
#
#   > Epoca: 31
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7104202296603958
# top5: 0.9275287075494747
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.4982885085574572
# top5: 0.821760391198044
#     > Epoca: 31
#     > Train loss 1.7927922438830137
#     > Valid loss 2.2332793623209
# Validation loss decreased (2.234502 --> 2.233279).  Saving model ...
#
#   > Epoca: 32
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7108783288541413
# top5: 0.9280478866357196
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.49706601466992667
# top5: 0.821760391198044
#     > Epoca: 32
#     > Train loss 1.78988934494555
#     > Valid loss 2.2299477458000183
# Validation loss decreased (2.233279 --> 2.229948).  Saving model ...
#
#   > Epoca: 33
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7116112875641338
# top5: 0.9279257268507207
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.4965770171149144
# top5: 0.821760391198044
#     > Epoca: 33
#     > Train loss 1.7887780852615833
#     > Valid loss 2.230139344930649
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 34
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.718207915954068
# top5: 0.9290862448082091
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.5
# top5: 0.8210268948655257
#     > Epoca: 34
#     > Train loss 1.7799884490668774
#     > Valid loss 2.2261463403701782
# Validation loss decreased (2.229948 --> 2.226146).  Saving model ...
#
#   > Epoca: 35
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7185438553628145
# top5: 0.9294832641094551
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.4997555012224939
# top5: 0.8224938875305623
#     > Epoca: 35
#     > Train loss 1.7769334372133017
#     > Valid loss 2.222469747066498
# Validation loss decreased (2.226146 --> 2.222470).  Saving model ...
#
#   > Epoca: 36
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7217505497190325
# top5: 0.9308881016369411
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.5024449877750611
# top5: 0.8224938875305623
#     > Epoca: 36
#     > Train loss 1.7704916950315237
#     > Valid loss 2.2180012464523315
# Validation loss decreased (2.222470 --> 2.218001).  Saving model ...
#
#   > Epoca: 37
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.722391888590276
# top5: 0.9302162228194478
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.5034229828850856
# top5: 0.8237163814180929
#     > Epoca: 37
#     > Train loss 1.7667565010488033
#     > Valid loss 2.2175115793943405
# Validation loss decreased (2.218001 --> 2.217512).  Saving model ...
#
#   > Epoca: 38
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.7224835084290252
# top5: 0.9308575616906914
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.5073349633251834
# top5: 0.8249388753056235
#     > Epoca: 38
#     > Train loss 1.7633359897881746
#     > Valid loss 2.2129189521074295
# Validation loss decreased (2.217512 --> 2.212919).  Saving model ...
#
#   > Epoca: 39
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.7249267041290007
# top5: 0.9321096994869289
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.5078239608801955
# top5: 0.8271393643031785
#     > Epoca: 39
#     > Train loss 1.7573817316442728
#     > Valid loss 2.211662322282791
# Validation loss decreased (2.212919 --> 2.211662).  Saving model ...
#
#   > Epoca: 40
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.7275531395064745
# top5: 0.9320791595406792
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.5132029339853301
# top5: 0.8242053789731051
#     > Epoca: 40
#     > Train loss 1.753962291404605
#     > Valid loss 2.2116985619068146
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 41
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 34% |
# >>> Acc
# top1: 0.7316760322501833
# top5: 0.9331175177131689
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.5166259168704157
# top5: 0.8254278728606357
#     > Epoca: 41
#     > Train loss 1.7460241951048374
#     > Valid loss 2.2107351273298264
# Validation loss decreased (2.211662 --> 2.210735).  Saving model ...
#
#   > Epoca: 42
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.7334778890789152
# top5: 0.9332396774981676
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.5163814180929095
# top5: 0.828117359413203
#     > Epoca: 42
#     > Train loss 1.7414596434682608
#     > Valid loss 2.2101293355226517
# Validation loss decreased (2.210735 --> 2.210129).  Saving model ...
#
#   > Epoca: 43
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.7361348644026386
# top5: 0.9338810163694112
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.5163814180929095
# top5: 0.8259168704156479
#     > Epoca: 43
#     > Train loss 1.73681228607893
#     > Valid loss 2.2082870453596115
# Validation loss decreased (2.210129 --> 2.208287).  Saving model ...
#
#   > Epoca: 44
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.7371732225751283
# top5: 0.9341253359394087
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.5188264058679707
# top5: 0.8261613691931541
#     > Epoca: 44
#     > Train loss 1.7335224505513906
#     > Valid loss 2.2067766040563583
# Validation loss decreased (2.208287 --> 2.206777).  Saving model ...
#
#   > Epoca: 45
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 34% |
# >>> Acc
# top1: 0.7377840215001221
# top5: 0.9341864158319081
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.5202933985330074
# top5: 0.8251833740831296
#     > Epoca: 45
#     > Train loss 1.7317084167152643
#     > Valid loss 2.2024808526039124
# Validation loss decreased (2.206777 --> 2.202481).  Saving model ...
#
#   > Epoca: 46
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 34% |
# >>> Acc
# top1: 0.7380283410701197
# top5: 0.9341558758856584
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.5188264058679707
# top5: 0.8276283618581907
#     > Epoca: 46
#     > Train loss 1.7300443146377802
#     > Valid loss 2.2008013278245926
# Validation loss decreased (2.202481 --> 2.200801).  Saving model ...
#
#   > Epoca: 47
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.738700219887613
# top5: 0.9345223552406547
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.5210268948655257
# top5: 0.8290953545232274
#     > Epoca: 47
#     > Train loss 1.729137072339654
#     > Valid loss 2.1980202049016953
# Validation loss decreased (2.200801 --> 2.198020).  Saving model ...
#
#   > Epoca: 48
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 32% |
# >>> Acc
# top1: 0.7397080381138529
# top5: 0.9348888345956511
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 32% |
# >>> Acc
# top1: 0.5215158924205379
# top5: 0.8308068459657701
#     > Epoca: 48
#     > Train loss 1.7245801351964474
#     > Valid loss 2.1954341381788254
# Validation loss decreased (2.198020 --> 2.195434).  Saving model ...
#
#   > Epoca: 49
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.7429758123625703
# top5: 0.9359271927681407
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 32% |
# >>> Acc
# top1: 0.5234718826405867
# top5: 0.8293398533007335
#     > Epoca: 49
#     > Train loss 1.7203163336962461
#     > Valid loss 2.1966717541217804
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 50
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 32% |
# >>> Acc
# top1: 0.7456327876862937
# top5: 0.9360493525531395
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.5193154034229829
# top5: 0.8298288508557458
#     > Epoca: 50
#     > Train loss 1.7169149033725262
#     > Valid loss 2.1933054476976395
# Validation loss decreased (2.195434 --> 2.193305).  Saving model ...
#
#   > Epoca: 51
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.7453884681162961
# top5: 0.936599071585634
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5180929095354523
# top5: 0.832762836185819
#     > Epoca: 51
#     > Train loss 1.7148093655705452
#     > Valid loss 2.1925651878118515
# Validation loss decreased (2.193305 --> 2.192565).  Saving model ...
#
#   > Epoca: 52
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.7424566332763254
# top5: 0.9352858538968971
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.519559902200489
# top5: 0.8308068459657701
#     > Epoca: 52
#     > Train loss 1.719783890992403
#     > Valid loss 2.1913652569055557
# Validation loss decreased (2.192565 --> 2.191365).  Saving model ...
#
#   > Epoca: 53
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.7452663083312974
# top5: 0.9363242120693868
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5183374083129584
# top5: 0.8310513447432762
#     > Epoca: 53
#     > Train loss 1.7163539342582226
#     > Valid loss 2.1866496205329895
# Validation loss decreased (2.191365 --> 2.186650).  Saving model ...
#
#   > Epoca: 54
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.7467322257512827
# top5: 0.9364158319081358
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5234718826405867
# top5: 0.8349633251833741
#     > Epoca: 54
#     > Train loss 1.7114372719079256
#     > Valid loss 2.188126787543297
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 55
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 32% |
# >>> Acc
# top1: 0.7489616418275103
# top5: 0.9377290495968728
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5259168704156479
# top5: 0.8339853300733496
#     > Epoca: 55
#     > Train loss 1.7064731568098068
#     > Valid loss 2.189919278025627
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 56
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 12% | 32% |
# >>> Acc
# top1: 0.7482286831175177
# top5: 0.9372709504031272
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5266503667481662
# top5: 0.8325183374083129
#     > Epoca: 56
#     > Train loss 1.704724894836545
#     > Valid loss 2.186978355050087
# EarlyStopping counter: 3 out of 10
#
#   > Epoca: 57
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 13% | 32% |
# >>> Acc
# top1: 0.7528707549474712
# top5: 0.9382787686293672
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.5300733496332518
# top5: 0.8322738386308068
#     > Epoca: 57
#     > Train loss 1.700587635859847
#     > Valid loss 2.1879252940416336
# EarlyStopping counter: 4 out of 10
#
#   > Epoca: 58
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 32% |
# >>> Acc
# top1: 0.7541228927437088
# top5: 0.9377901294893721
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.5254278728606357
# top5: 0.8347188264058679
#     > Epoca: 58
#     > Train loss 1.6974875051528215
#     > Valid loss 2.1845213770866394
# Validation loss decreased (2.186650 --> 2.184521).  Saving model ...
#
#   > Epoca: 59
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.7556193501099439
# top5: 0.9385536281456145
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5278728606356968
# top5: 0.8322738386308068
#     > Epoca: 59
#     > Train loss 1.6940436381846666
#     > Valid loss 2.182232588529587
# Validation loss decreased (2.184521 --> 2.182233).  Saving model ...
#
#   > Epoca: 60
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.7577571463474224
# top5: 0.938797947715612
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.526161369193154
# top5: 0.8322738386308068
#     > Epoca: 60
#     > Train loss 1.6910621151328087
#     > Valid loss 2.1824903190135956
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 61
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 33% |
# >>> Acc
# top1: 0.7571158074761788
# top5: 0.9389811873931102
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5268948655256723
# top5: 0.8334963325183374
#     > Epoca: 61
#     > Train loss 1.689597388729453
#     > Valid loss 2.184147611260414
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 62
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.75800146591742
# top5: 0.9386757879306132
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 33% |
# >>> Acc
# top1: 0.5232273838630807
# top5: 0.8325183374083129
#     > Epoca: 62
#     > Train loss 1.6883397363126278
#     > Valid loss 2.1873770654201508
# EarlyStopping counter: 3 out of 10
#
#   > Epoca: 63
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 33% |
# >>> Acc
# top1: 0.7561690691424383
# top5: 0.9383093085756169
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.523960880195599
# top5: 0.8354523227383863
#     > Epoca: 63
#     > Train loss 1.6918853782117367
#     > Valid loss 2.1847464740276337
# EarlyStopping counter: 4 out of 10
#
#   > Epoca: 64
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.7574212069386758
# top5: 0.9382787686293672
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 33% |
# >>> Acc
# top1: 0.5232273838630807
# top5: 0.8349633251833741
#     > Epoca: 64
#     > Train loss 1.6889374423772097
#     > Valid loss 2.184758633375168
# EarlyStopping counter: 5 out of 10
#
#   > Epoca: 65
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 33% |
# >>> Acc
# top1: 0.7601698021011483
# top5: 0.9386147080381139
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.523716381418093
# top5: 0.8315403422982885
#     > Epoca: 65
#     > Train loss 1.6856152713298798
#     > Valid loss 2.18349888920784
# EarlyStopping counter: 6 out of 10
#
#   > Epoca: 66
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 10% | 33% |
# >>> Acc
# top1: 0.7593452235524065
# top5: 0.9381260688981188
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.5249388753056234
# top5: 0.8298288508557458
#     > Epoca: 66
#     > Train loss 1.6840084418654442
#     > Valid loss 2.18418850004673
# EarlyStopping counter: 7 out of 10
#
#   > Epoca: 67
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 33% |
# >>> Acc
# top1: 0.7602614219398974
# top5: 0.9387368678231126
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 32% |
# >>> Acc
# top1: 0.5234718826405867
# top5: 0.8317848410757946
#     > Epoca: 67
#     > Train loss 1.68200602568686
#     > Valid loss 2.18427574634552
# EarlyStopping counter: 8 out of 10
#
#   > Epoca: 68
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 32% |
# >>> Acc
# top1: 0.7621548986073785
# top5: 0.9389506474468605
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5210268948655257
# top5: 0.8312958435207825
#     > Epoca: 68
#     > Train loss 1.682259675115347
#     > Valid loss 2.179169699549675
# Validation loss decreased (2.182233 --> 2.179170).  Saving model ...
#
#   > Epoca: 69
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 32% |
# >>> Acc
# top1: 0.761696799413633
# top5: 0.9394087466406059
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5220048899755502
# top5: 0.8322738386308068
#     > Epoca: 69
#     > Train loss 1.6820950116962194
#     > Valid loss 2.1806331872940063
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 70
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 32% |
# >>> Acc
# top1: 0.7616357195211336
# top5: 0.9399279257268507
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5190709046454768
# top5: 0.8330073349633251
#     > Epoca: 70
#     > Train loss 1.6818081811070442
#     > Valid loss 2.1810318529605865
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 71
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 32% |
# >>> Acc
# top1: 0.7624297581236257
# top5: 0.9407830442218422
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 32% |
# >>> Acc
# top1: 0.5246943765281173
# top5: 0.8330073349633251
#     > Epoca: 71
#     > Train loss 1.6793665178120136
#     > Valid loss 2.1798817068338394
# EarlyStopping counter: 3 out of 10
#
#   > Epoca: 72
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  8% | 32% |
# >>> Acc
# top1: 0.7647507940386025
# top5: 0.94099682384559
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 32% |
# >>> Acc
# top1: 0.5256723716381418
# top5: 0.8310513447432762
#     > Epoca: 72
#     > Train loss 1.674557588994503
#     > Valid loss 2.179430663585663
# EarlyStopping counter: 4 out of 10
#
#   > Epoca: 73
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 32% |
# >>> Acc
# top1: 0.7686599071585634
# top5: 0.941393843146836
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5276283618581907
# top5: 0.8290953545232274
#     > Epoca: 73
#     > Train loss 1.6697501689195633
#     > Valid loss 2.18183334171772
# EarlyStopping counter: 5 out of 10
#
#   > Epoca: 74
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 32% |
# >>> Acc
# top1: 0.7691485462985586
# top5: 0.9414854629855851
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.523960880195599
# top5: 0.8312958435207825
#     > Epoca: 74
#     > Train loss 1.6678837481886148
#     > Valid loss 2.182803377509117
# EarlyStopping counter: 6 out of 10
#
#   > Epoca: 75
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 13% | 32% |
# >>> Acc
# top1: 0.7696371854385536
# top5: 0.9411189836305888
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5278728606356968
# top5: 0.8283618581907091
#     > Epoca: 75
#     > Train loss 1.6672959718853235
#     > Valid loss 2.180560290813446
# EarlyStopping counter: 7 out of 10
#
#   > Epoca: 76
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% | 32% |
# >>> Acc
# top1: 0.7701258245785487
# top5: 0.9416687026630833
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5254278728606357
# top5: 0.8295843520782397
#     > Epoca: 76
#     > Train loss 1.666442658752203
#     > Valid loss 2.177816167473793
# Validation loss decreased (2.179170 --> 2.177816).  Saving model ...
#
#   > Epoca: 77
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.77000366479355
# top5: 0.9410884436843391
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5281173594132029
# top5: 0.8300733496332519
#     > Epoca: 77
#     > Train loss 1.667446682229638
#     > Valid loss 2.1796649992465973
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 78
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.7651783532860982
# top5: 0.9414854629855851
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5276283618581907
# top5: 0.8286063569682152
#     > Epoca: 78
#     > Train loss 1.673204181715846
#     > Valid loss 2.1735871732234955
# Validation loss decreased (2.177816 --> 2.173587).  Saving model ...
#
#   > Epoca: 79
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.769606645492304
# top5: 0.9414243830930857
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5242053789731052
# top5: 0.8288508557457213
#     > Epoca: 79
#     > Train loss 1.667737266048789
#     > Valid loss 2.1740654706954956
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 80
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.7690874664060591
# top5: 0.9418519423405814
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.5290953545232274
# top5: 0.8278728606356969
#     > Epoca: 80
#     > Train loss 1.6653796657919884
#     > Valid loss 2.176510527729988
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 81
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 | 13% | 32% |
# >>> Acc
# top1: 0.7705839237722941
# top5: 0.9422489616418275
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.532518337408313
# top5: 0.8278728606356969
#     > Epoca: 81
#     > Train loss 1.6622989252209663
#     > Valid loss 2.1778411269187927
# EarlyStopping counter: 3 out of 10
#
#   > Epoca: 82
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 33% |
# >>> Acc
# top1: 0.774798436354752
# top5: 0.9427681407280724
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.5308068459657702
# top5: 0.8271393643031785
#     > Epoca: 82
#     > Train loss 1.658552959561348
#     > Valid loss 2.1781627535820007
# EarlyStopping counter: 4 out of 10
#
#   > Epoca: 83
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.7741265575372588
# top5: 0.942096261910579
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.5315403422982885
# top5: 0.8264058679706602
#     > Epoca: 83
#     > Train loss 1.6589685659855604
#     > Valid loss 2.173612505197525
# EarlyStopping counter: 5 out of 10
#
#   > Epoca: 84
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.7659723918885902
# top5: 0.9422795015880772
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.5288508557457213
# top5: 0.8261613691931541
#     > Epoca: 84
#     > Train loss 1.6654133331030607
#     > Valid loss 2.167241871356964
# Validation loss decreased (2.173587 --> 2.167242).  Saving model ...
#
#   > Epoca: 85
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.7728438797947715
# top5: 0.9425849010505741
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 32% |
# >>> Acc
# top1: 0.5330073349633252
# top5: 0.8288508557457213
#     > Epoca: 85
#     > Train loss 1.6613741051405668
#     > Valid loss 2.1719465404748917
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 86
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 32% |
# >>> Acc
# top1: 0.7748900561935012
# top5: 0.9428292206205717
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.5320293398533007
# top5: 0.8273838630806846
#     > Epoca: 86
#     > Train loss 1.657426031306386
#     > Valid loss 2.1712951213121414
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 87
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.7779440508184705
# top5: 0.9429819203518202
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.530562347188264
# top5: 0.8278728606356969
#     > Epoca: 87
#     > Train loss 1.653326876461506
#     > Valid loss 2.175165042281151
# EarlyStopping counter: 3 out of 10
#
#   > Epoca: 88
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 33% |
# >>> Acc
# top1: 0.7768446127534816
# top5: 0.9431651600293184
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 33% |
# >>> Acc
# top1: 0.5352078239608802
# top5: 0.8254278728606357
#     > Epoca: 88
#     > Train loss 1.6532294172793627
#     > Valid loss 2.1710889786481857
# EarlyStopping counter: 4 out of 10
#
#   > Epoca: 89
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 33% |
# >>> Acc
# top1: 0.775195455655998
# top5: 0.9431956999755681
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.530562347188264
# top5: 0.8254278728606357
#     > Epoca: 89
#     > Train loss 1.6543376874178648
#     > Valid loss 2.1736925542354584
# EarlyStopping counter: 5 out of 10
#
#   > Epoca: 90
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 33% |
# >>> Acc
# top1: 0.7771500122159785
# top5: 0.943501099438065
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  3% | 33% |
# >>> Acc
# top1: 0.5303178484107579
# top5: 0.8273838630806846
#     > Epoca: 90
#     > Train loss 1.6526066679507494
#     > Valid loss 2.173739805817604
# EarlyStopping counter: 6 out of 10
#
#   > Epoca: 91
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% | 33% |
# >>> Acc
# top1: 0.7796848277547032
# top5: 0.9439286586855608
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.5330073349633252
# top5: 0.8278728606356969
#     > Epoca: 91
#     > Train loss 1.649397924542427
#     > Valid loss 2.1769826859235764
# EarlyStopping counter: 7 out of 10
#
#   > Epoca: 92
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 33% |
# >>> Acc
# top1: 0.7784632299047154
# top5: 0.9437454190080625
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.5320293398533007
# top5: 0.8278728606356969
#     > Epoca: 92
#     > Train loss 1.650596845895052
#     > Valid loss 2.174825742840767
# EarlyStopping counter: 8 out of 10
#
#   > Epoca: 93
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 33% |
# >>> Acc
# top1: 0.7801429269484486
# top5: 0.9442645980943074
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.5300733496332518
# top5: 0.8254278728606357
#     > Epoca: 93
#     > Train loss 1.646358048543334
#     > Valid loss 2.180051401257515
# EarlyStopping counter: 9 out of 10
#
#   > Epoca: 94
#
# Entrenamiento - Numero de batchs: 64
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.7754703151722453
# top5: 0.9435621793305644
#
# Validacion - Numero de batchs: 8
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 33% |
# >>> Acc
# top1: 0.5298288508557457
# top5: 0.8227383863080685
#     > Epoca: 94
#     > Train loss 1.6508162878453732
#     > Valid loss 2.169352486729622
# EarlyStopping counter: 10 out of 10
# >>> Early stopping
#
# > Evaluando modelo para task A
#
# Test - Numero de batchs: 9
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 33% |
# >>> Acc
# Top1: 0.5364367535949306
# ...
# | ID | GPU | MEM |
# ------------------
# |  0 | 17% | 32% |
# >>> Acc
# top1: 0.7625709472943628
# top5: 0.7625709472943628
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 32% |
# >>> Acc
# top1: 0.729801396179447
# top5: 0.729801396179447
#     > Epoca: 52
#     > Train loss 0.6534581034859984
#     > Valid loss 0.7240154372679221
# Validation loss decreased (0.725383 --> 0.724015).  Saving model ...
#
#   > Epoca: 53
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 32% |
# >>> Acc
# top1: 0.7622124055445437
# top5: 0.7622124055445437
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.7261215433735592
# top5: 0.7261215433735592
#     > Epoca: 53
#     > Train loss 0.6532256617678078
#     > Valid loss 0.7292181092339594
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 54
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 18% | 32% |
# >>> Acc
# top1: 0.7620703418323513
# top5: 0.7620703418323513
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 32% |
# >>> Acc
# top1: 0.7309919367931165
# top5: 0.7309919367931165
#     > Epoca: 54
#     > Train loss 0.6520791050678306
#     > Valid loss 0.7225323166396167
# Validation loss decreased (0.724015 --> 0.722532).  Saving model ...
#
#   > Epoca: 55
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 32% |
# >>> Acc
# top1: 0.7625506524783353
# top5: 0.7625506524783353
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  1% | 34% |
# >>> Acc
# top1: 0.7314789761350723
# top5: 0.7314789761350723
#     > Epoca: 55
#     > Train loss 0.6496467580019809
#     > Valid loss 0.7200114034317635
# Validation loss decreased (0.722532 --> 0.720011).  Saving model ...
#
#   > Epoca: 56
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.766765209273378
# top5: 0.766765209273378
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.7334271335028951
# top5: 0.7334271335028951
#     > Epoca: 56
#     > Train loss 0.64431971022827
#     > Valid loss 0.7294199160627417
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 57
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 12% | 34% |
# >>> Acc
# top1: 0.7569966378254781
# top5: 0.7569966378254781
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.7318577845121489
# top5: 0.7318577845121489
#     > Epoca: 57
#     > Train loss 0.6566902002042553
#     > Valid loss 0.7193197221369356
# Validation loss decreased (0.720011 --> 0.719320).  Saving model ...
#
#   > Epoca: 58
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.767245519919362
# top5: 0.767245519919362
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.7321283619243466
# top5: 0.7321283619243466
#     > Epoca: 58
#     > Train loss 0.6436254752342264
#     > Valid loss 0.7194705234991537
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 59
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 13% | 34% |
# >>> Acc
# top1: 0.7684970335743907
# top5: 0.7684970335743907
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.7314248606526327
# top5: 0.7314248606526327
#     > Epoca: 59
#     > Train loss 0.6405622376496404
#     > Valid loss 0.7182865142822266
# Validation loss decreased (0.719320 --> 0.718287).  Saving model ...
#
#   > Epoca: 60
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 34% |
# >>> Acc
# top1: 0.7697553121680952
# top5: 0.7697553121680952
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 35% |
# >>> Acc
# top1: 0.7334271335028951
# top5: 0.7334271335028951
#     > Epoca: 60
#     > Train loss 0.6378626804863293
#     > Valid loss 0.7172819190734142
# Validation loss decreased (0.718287 --> 0.717282).  Saving model ...
#
#   > Epoca: 61
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 35% |
# >>> Acc
# top1: 0.7703303319555408
# top5: 0.7703303319555408
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 36% |
# >>> Acc
# top1: 0.7337518263975323
# top5: 0.7337518263975323
#     > Epoca: 61
#     > Train loss 0.6367312879092141
#     > Valid loss 0.7144791387222909
# Validation loss decreased (0.717282 --> 0.714479).  Saving model ...
#
#   > Epoca: 62
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 36% |
# >>> Acc
# top1: 0.7705265151771399
# top5: 0.7705265151771399
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 36% |
# >>> Acc
# top1: 0.7344012121868067
# top5: 0.7344012121868067
#     > Epoca: 62
#     > Train loss 0.6359222274544329
#     > Valid loss 0.715307765715831
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 63
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 11% | 36% |
# >>> Acc
# top1: 0.7722718693555043
# top5: 0.7722718693555043
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 36% |
# >>> Acc
# top1: 0.7356999837653553
# top5: 0.7356999837653553
#     > Epoca: 63
#     > Train loss 0.6327263502513661
#     > Valid loss 0.7115107073977187
# Validation loss decreased (0.714479 --> 0.711511).  Saving model ...
#
#   > Epoca: 64
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 36% |
# >>> Acc
# top1: 0.7735301479492088
# top5: 0.7735301479492088
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 37% |
# >>> Acc
# top1: 0.7339682883272904
# top5: 0.7339682883272904
#     > Epoca: 64
#     > Train loss 0.6312350514232081
#     > Valid loss 0.7145835886130462
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 65
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 17% | 37% |
# >>> Acc
# top1: 0.7751266734767049
# top5: 0.7751266734767049
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 37% |
# >>> Acc
# top1: 0.734130634774609
# top5: 0.734130634774609
#     > Epoca: 65
#     > Train loss 0.6288091468151052
#     > Valid loss 0.7144644123476904
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 66
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 17% | 37% |
# >>> Acc
# top1: 0.7757828725282605
# top5: 0.7757828725282605
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 37% |
# >>> Acc
# top1: 0.7338600573624113
# top5: 0.7338600573624113
#     > Epoca: 66
#     > Train loss 0.6276006663546843
#     > Valid loss 0.715052250269297
# EarlyStopping counter: 3 out of 10
#
#   > Epoca: 67
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 11% | 37% |
# >>> Acc
# top1: 0.7759587609338321
# top5: 0.7759587609338321
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 37% |
# >>> Acc
# top1: 0.7357540992477948
# top5: 0.7357540992477948
#     > Epoca: 67
#     > Train loss 0.6261776666121499
#     > Valid loss 0.713177208159421
# EarlyStopping counter: 4 out of 10
#
#   > Epoca: 68
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 17% | 37% |
# >>> Acc
# top1: 0.777284688914295
# top5: 0.777284688914295
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 40% |
# >>> Acc
# top1: 0.736187023107311
# top5: 0.736187023107311
#     > Epoca: 68
#     > Train loss 0.6241806485661173
#     > Valid loss 0.7125599408471907
# EarlyStopping counter: 5 out of 10
#
#   > Epoca: 69
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 12% | 40% |
# >>> Acc
# top1: 0.7760737648913213
# top5: 0.7760737648913213
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  8% | 39% |
# >>> Acc
# top1: 0.7340224038097299
# top5: 0.7340224038097299
#     > Epoca: 69
#     > Train loss 0.6252436789468085
#     > Valid loss 0.7124675294837436
# EarlyStopping counter: 6 out of 10
#
#   > Epoca: 70
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 18% | 39% |
# >>> Acc
# top1: 0.7775282267066249
# top5: 0.7775282267066249
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 38% |
# >>> Acc
# top1: 0.7339141728448509
# top5: 0.7339141728448509
#     > Epoca: 70
#     > Train loss 0.6235639484902155
#     > Valid loss 0.7118597948873365
# EarlyStopping counter: 7 out of 10
#
#   > Epoca: 71
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 16% | 38% |
# >>> Acc
# top1: 0.7793615250877751
# top5: 0.7793615250877751
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 38% |
# >>> Acc
# top1: 0.7345094431516856
# top5: 0.7345094431516856
#     > Epoca: 71
#     > Train loss 0.6210685254793266
#     > Valid loss 0.7120667969858324
# EarlyStopping counter: 8 out of 10
#
#   > Epoca: 72
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 15% | 38% |
# >>> Acc
# top1: 0.7805183296013422
# top5: 0.7805183296013422
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 38% |
# >>> Acc
# top1: 0.7358082147302343
# top5: 0.7358082147302343
#     > Epoca: 72
#     > Train loss 0.6189013592718382
#     > Valid loss 0.7105233991468275
# Validation loss decreased (0.711511 --> 0.710523).  Saving model ...
#
#   > Epoca: 73
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 38% |
# >>> Acc
# top1: 0.7809039311058645
# top5: 0.7809039311058645
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 38% |
# >>> Acc
# top1: 0.7371069863087829
# top5: 0.7371069863087829
#     > Epoca: 73
#     > Train loss 0.6180113400348742
#     > Valid loss 0.7095890649267145
# Validation loss decreased (0.710523 --> 0.709589).  Saving model ...
#
#   > Epoca: 74
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 38% |
# >>> Acc
# top1: 0.7800786085874132
# top5: 0.7800786085874132
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 39% |
# >>> Acc
# top1: 0.7358082147302343
# top5: 0.7358082147302343
#     > Epoca: 74
#     > Train loss 0.6195998325892386
#     > Valid loss 0.7107629510196479
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 75
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 13% | 39% |
# >>> Acc
# top1: 0.7833325440904878
# top5: 0.7833325440904878
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 39% |
# >>> Acc
# top1: 0.7391092591590454
# top5: 0.7391092591590454
#     > Epoca: 75
#     > Train loss 0.6144921310426454
#     > Valid loss 0.711253313599406
# EarlyStopping counter: 2 out of 10
#
#   > Epoca: 76
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 13% | 39% |
# >>> Acc
# top1: 0.7801868476062265
# top5: 0.7801868476062265
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 39% |
# >>> Acc
# top1: 0.7374316792034201
# top5: 0.7374316792034201
#     > Epoca: 76
#     > Train loss 0.6177338760823115
#     > Valid loss 0.708487621030292
# Validation loss decreased (0.709589 --> 0.708488).  Saving model ...
#
#   > Epoca: 77
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 39% |
# >>> Acc
# top1: 0.7847193565190331
# top5: 0.7847193565190331
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  7% | 39% |
# >>> Acc
# top1: 0.7378646030629363
# top5: 0.7378646030629363
#     > Epoca: 77
#     > Train loss 0.612339892911251
#     > Valid loss 0.7076042552252073
# Validation loss decreased (0.708488 --> 0.707604).  Saving model ...
#
#   > Epoca: 78
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 39% |
# >>> Acc
# top1: 0.7838128547364718
# top5: 0.7838128547364718
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 39% |
# >>> Acc
# top1: 0.739163374641485
# top5: 0.739163374641485
#     > Epoca: 78
#     > Train loss 0.6127863902740412
#     > Valid loss 0.7073998998951267
# Validation loss decreased (0.707604 --> 0.707400).  Saving model ...
#
#   > Epoca: 79
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 39% |
# >>> Acc
# top1: 0.7850981930848797
# top5: 0.7850981930848797
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% | 39% |
# >>> Acc
# top1: 0.7395421830185616
# top5: 0.7395421830185616
#     > Epoca: 79
#     > Train loss 0.6103915228769441
#     > Valid loss 0.7067270697774114
# Validation loss decreased (0.707400 --> 0.706727).  Saving model ...
#
#   > Epoca: 80
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 39% |
# >>> Acc
# top1: 0.7854364400186712
# top5: 0.7854364400186712
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 40% |
# >>> Acc
# top1: 0.7385139888522106
# top5: 0.7385139888522106
#     > Epoca: 80
#     > Train loss 0.6099504453088173
#     > Valid loss 0.707456653182571
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 81
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 16% | 40% |
# >>> Acc
# top1: 0.7861941131503642
# top5: 0.7861941131503642
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 40% |
# >>> Acc
# top1: 0.7386763352995291
# top5: 0.7386763352995291
#     > Epoca: 81
#     > Train loss 0.6093147145423097
#     > Valid loss 0.706507272011525
# Validation loss decreased (0.706727 --> 0.706507).  Saving model ...
#
#   > Epoca: 82
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 40% |
# >>> Acc
# top1: 0.787445626805393
# top5: 0.787445626805393
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 40% |
# >>> Acc
# top1: 0.7394880675361221
# top5: 0.7394880675361221
#     > Epoca: 82
#     > Train loss 0.6074646712380709
#     > Valid loss 0.706927889102214
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 83
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 14% | 40% |
# >>> Acc
# top1: 0.7890083276395099
# top5: 0.7890083276395099
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 39% |
# >>> Acc
# top1: 0.7406244926673521
# top5: 0.7406244926673521
#     > Epoca: 83
#     > Train loss 0.6062379681527821
#     > Valid loss 0.7059784813507183
# Validation loss decreased (0.706507 --> 0.705978).  Saving model ...
#
#   > Epoca: 84
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 39% |
# >>> Acc
# top1: 0.7897727657098789
# top5: 0.7897727657098789
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 39% |
# >>> Acc
# top1: 0.7405162617024731
# top5: 0.7405162617024731
#     > Epoca: 84
#     > Train loss 0.6050487349396346
#     > Valid loss 0.7051804291235434
# Validation loss decreased (0.705978 --> 0.705180).  Saving model ...
#
#   > Epoca: 85
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 |  5% | 39% |
# >>> Acc
# top1: 0.7907536818178743
# top5: 0.7907536818178743
#
# Validacion - Numero de batchs: 37
# | ID | GPU | MEM |
# ------------------
# |  0 |  6% | 39% |
# >>> Acc
# top1: 0.7386222198170896
# top5: 0.7386222198170896
#     > Epoca: 85
#     > Train loss 0.6036914083784427
#     > Valid loss 0.7077335167575527
# EarlyStopping counter: 1 out of 10
#
#   > Epoca: 86
#
# Entrenamiento - Numero de batchs: 289
# | ID | GPU | MEM |
# ------------------
# |  0 | 16% | 39% |
# d:\documents\memoria - eval. word embeddings\env\lib\site-packages\numpy\lib\function_base.py:390: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# d:\documents\memoria - eval. word embeddings\env\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
